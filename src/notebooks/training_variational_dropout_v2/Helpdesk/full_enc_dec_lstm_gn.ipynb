# %% [markdown]
# # Imports

# %%
import importlib
import sys

# performance imports for torch: torch kernel uses one core only.
import os
os.environ["OMP_NUM_THREADS"] = "1"
os.environ["MKL_NUM_THREADS"] = "1"
os.environ["TORCH_NUM_THREADS"] = "1" 

import torch

sys.path.insert(0, '..')
sys.path.insert(0, '../..')
sys.path.insert(0, '../../..')

# %% [markdown]
# # Data

# %% [markdown]
# ### Load Data Files

# %%
# Path to your pickle file (saved with torch.save)
file_path_train = '../../../../encoded_data_conformal/Helpdesk/helpdesk_all_5_train.pkl'
# Load the dataset using torch.load
helpdesk_train_dataset = torch.load(file_path_train, weights_only=False)

# Path to your pickle file (saved with torch.save)
file_path_val = '../../../../encoded_data_conformal/Helpdesk/helpdesk_all_5_val.pkl'
# Load the dataset using torch.load
helpdesk_val_dataset = torch.load(file_path_val, weights_only=False)

# %% [markdown]
# ### Train Data Insights

# %%
# Helpdesk dataset dynamic categories, features:
helpdesk_all_categories = helpdesk_train_dataset.all_categories

helpdesk_all_categories_cat = helpdesk_all_categories[0]
# print(helpdesk_all_categories_cat)
helpdesk_all_categories_num = helpdesk_all_categories[1]
# print(helpdesk_all_categories_num)
for i, cat in enumerate(helpdesk_all_categories_cat):
     print(f"Helpdesk dynamic categorical feature: {cat[0]}, Index position in categorical data list: {i}")
     print(f"Helpdesk amount of category labels: {cat[1]}")
print('\n')    
for i, num in enumerate(helpdesk_all_categories_num):
     print(f"Helpdesk dynamic numerical feature: {num[0]}, Index position in categorical data list: {i}")
     print(f"Helpdesk amount of numerical: {num[1]}")
print('\n')
     
# Helpdesk dataset static categories, features:
helpdesk_all_stat_categories = helpdesk_train_dataset.all_static_categories

helpdesk_all_stat_categories_cat = helpdesk_all_stat_categories[0]
# print(helpdesk_all_stat_categories_cat)
helpdesk_all_stat_categories_num = helpdesk_all_stat_categories[1]
# print(helpdesk_all_stat_categories_num)
for i, cat in enumerate(helpdesk_all_stat_categories_cat):
     print(f"Helpdesk static categorical feature: {cat[0]}, Index position in categorical data list: {i}")
     print(f"Helpdesk amount of category labels: {cat[1]}")
print('\n')    
for i, num in enumerate(helpdesk_all_stat_categories_num):
     print(f"Helpdesk static numerical feature: {num[0]}, Index position in categorical data list: {i}")
     print(f"Helpdesk amount of numerical: {num[1]}")
# Out:
# Helpdesk dynamic categorical feature: Activity, Index position in categorical data list: 0
# Helpdesk amount of category labels: 16
# Helpdesk dynamic categorical feature: Resource, Index position in categorical data list: 1
# Helpdesk amount of category labels: 24
#
#
# Helpdesk dynamic numerical feature: case_elapsed_time, Index position in categorical data list: 0
# Helpdesk amount of numerical: 1
# Helpdesk dynamic numerical feature: event_elapsed_time, Index position in categorical data list: 1
# Helpdesk amount of numerical: 1
# Helpdesk dynamic numerical feature: day_in_week, Index position in categorical data list: 2
# Helpdesk amount of numerical: 1
# Helpdesk dynamic numerical feature: seconds_in_day, Index position in categorical data list: 3
# Helpdesk amount of numerical: 1
#
#
# Helpdesk static categorical feature: VariantIndex, Index position in categorical data list: 0
# Helpdesk amount of category labels: 179
# Helpdesk static categorical feature: seriousness, Index position in categorical data list: 1
# Helpdesk amount of category labels: 2
# Helpdesk static categorical feature: customer, Index position in categorical data list: 2
# Helpdesk amount of category labels: 363
# Helpdesk static categorical feature: product, Index position in categorical data list: 3
# Helpdesk amount of category labels: 22
# Helpdesk static categorical feature: responsible_section, Index position in categorical data list: 4
# Helpdesk amount of category labels: 8
# Helpdesk static categorical feature: service_level, Index position in categorical data list: 5
# Helpdesk amount of category labels: 5
# Helpdesk static categorical feature: service_type, Index position in categorical data list: 6
# Helpdesk amount of category labels: 5
# Helpdesk static categorical feature: support_section, Index position in categorical data list: 7
# Helpdesk amount of category labels: 7
# Helpdesk static categorical feature: workgroup, Index position in categorical data list: 8
# Helpdesk amount of category labels: 5

# %% [markdown]
# ### Input Features for Encoder and Decoder

# %%
# Create lists with name of Encoder features (input) and decoder features (input & output)
# Encoder features:
enc_feat_cat = []
enc_feat_num = []
for cat in helpdesk_all_categories_cat:
    enc_feat_cat.append(cat[0])
for num in helpdesk_all_categories_num:
    enc_feat_num.append(num[0])
enc_feat = [enc_feat_cat, enc_feat_num]
print("Input features encoder: ", enc_feat)

# Static encoder features:
stat_enc_feat_cat = []
stat_enc_feat_num = []
for cat in helpdesk_all_stat_categories_cat:
     stat_enc_feat_cat.append(cat[0])
for num in helpdesk_all_stat_categories_num:
     stat_enc_feat_num.append(num[0])
stat_enc_feat = [stat_enc_feat_cat, stat_enc_feat_num]
print("Input features static encoder: ", stat_enc_feat)

# Decoder features:
dec_feat_cat = ['Activity']
dec_feat_num = ['case_elapsed_time', 'event_elapsed_time']
dec_feat = [dec_feat_cat, dec_feat_num]
print("Features decoder: ", dec_feat)
# Out:
# Input features encoder:  [['Activity', 'Resource'], ['case_elapsed_time', 'event_elapsed_time', 'day_in_week', 'seconds_in_day']]
# Input features static encoder:  [['VariantIndex', 'seriousness', 'customer', 'product', 'responsible_section', 'service_level', 'service_type', 'support_section', 'workgroup'], []]
# Features decoder:  [['Activity'], ['case_elapsed_time', 'event_elapsed_time']]

# %% [markdown]
# # Model

# %%
import model.dropout_uncertainty_enc_dec_LSTM.dropout_uncertainty_model
importlib.reload(model.dropout_uncertainty_enc_dec_LSTM.dropout_uncertainty_model)
from model.dropout_uncertainty_enc_dec_LSTM.dropout_uncertainty_model import DropoutUncertaintyEncoderDecoderLSTM

# Prediction decoder output sequence length
seq_len_pred = helpdesk_train_dataset.min_suffix_size

# Size hidden layer
hidden_size = 128

# Number of cells
num_layers = 4

# Fixed Dropout probability 
# Experiment with different values but be carefull with exploiting gradients:
dropout = 0.1

# Encoder Decoder model initialization
model = DropoutUncertaintyEncoderDecoderLSTM(data_set_categories=helpdesk_all_categories,
                                             enc_feat=enc_feat,
                                             dec_feat=dec_feat,
                                             seq_len_pred=seq_len_pred,
                                             hidden_size=hidden_size,
                                             num_layers=num_layers,
                                             dropout=dropout,
                                             # static attributes
                                             static_data_set_categories=helpdesk_all_stat_categories,
                                             static_enc_feat=stat_enc_feat
                                             )
# Out:
# Dynamic data set categories:  ([('Activity', 16, {'Assign seriousness': 1, 'Closed': 2, 'Create SW anomaly': 3, 'DUPLICATE': 4, 'EOS': 5, 'INVALID': 6, 'Insert ticket': 7, 'RESOLVED': 8, 'Require upgrade': 9, 'Resolve SW anomaly': 10, 'Resolve ticket': 11, 'Schedule intervention': 12, 'Take in charge ticket': 13, 'VERIFIED': 14, 'Wait': 15}), ('Resource', 24, {'EOS': 1, 'Value 1': 2, 'Value 10': 3, 'Value 11': 4, 'Value 12': 5, 'Value 13': 6, 'Value 14': 7, 'Value 15': 8, 'Value 16': 9, 'Value 17': 10, 'Value 18': 11, 'Value 19': 12, 'Value 2': 13, 'Value 20': 14, 'Value 21': 15, 'Value 22': 16, 'Value 3': 17, 'Value 4': 18, 'Value 5': 19, 'Value 6': 20, 'Value 7': 21, 'Value 8': 22, 'Value 9': 23})], [('case_elapsed_time', 1, {}), ('event_elapsed_time', 1, {}), ('day_in_week', 1, {}), ('seconds_in_day', 1, {})])
# Data set static categories:  ([('VariantIndex', 179, {1.0: 1, 2.0: 2, 3.0: 3, 4.0: 4, 5.0: 5, 6.0: 6, 7.0: 7, 8.0: 8, 9.0: 9, 10.0: 10, 11.0: 11, 12.0: 12, 13.0: 13, 14.0: 14, 15.0: 15, 16.0: 16, 17.0: 17, 18.0: 18, 19.0: 19, 20.0: 20, 21.0: 21, 22.0: 22, 23.0: 23, 24.0: 24, 25.0: 25, 26.0: 26, 27.0: 27, 28.0: 28, 29.0: 29, 30.0: 30, 31.0: 31, 32.0: 32, 33.0: 33, 34.0: 34, 35.0: 35, 36.0: 36, 37.0: 37, 38.0: 38, 39.0: 39, 40.0: 40, 41.0: 41, 42.0: 42, 43.0: 43, 44.0: 44, 45.0: 45, 46.0: 46, 47.0: 47, 48.0: 48, 49.0: 49, 50.0: 50, 51.0: 51, 52.0: 52, 53.0: 53, 54.0: 54, 55.0: 55, 56.0: 56, 57.0: 57, 58.0: 58, 59.0: 59, 60.0: 60, 61.0: 61, 62.0: 62, 63.0: 63, 64.0: 64, 65.0: 65, 66.0: 66, 67.0: 67, 68.0: 68, 69.0: 69, 70.0: 70, 71.0: 71, 72.0: 72, 73.0: 73, 74.0: 74, 75.0: 75, 76.0: 76, 77.0: 77, 78.0: 78, 79.0: 79, 81.0: 80, 83.0: 81, 84.0: 82, 85.0: 83, 86.0: 84, 87.0: 85, 88.0: 86, 89.0: 87, 90.0: 88, 91.0: 89, 93.0: 90, 94.0: 91, 95.0: 92, 97.0: 93, 99.0: 94, 100.0: 95, 103.0: 96, 104.0: 97, 107.0: 98, 109.0: 99, 110.0: 100, 112.0: 101, 113.0: 102, 114.0: 103, 115.0: 104, 117.0: 105, 118.0: 106, 120.0: 107, 122.0: 108, 123.0: 109, 124.0: 110, 125.0: 111, 126.0: 112, 127.0: 113, 129.0: 114, 130.0: 115, 131.0: 116, 134.0: 117, 135.0: 118, 137.0: 119, 138.0: 120, 139.0: 121, 140.0: 122, 141.0: 123, 143.0: 124, 144.0: 125, 145.0: 126, 147.0: 127, 149.0: 128, 150.0: 129, 151.0: 130, 152.0: 131, 153.0: 132, 154.0: 133, 155.0: 134, 156.0: 135, 157.0: 136, 158.0: 137, 162.0: 138, 163.0: 139, 164.0: 140, 165.0: 141, 167.0: 142, 168.0: 143, 169.0: 144, 170.0: 145, 171.0: 146, 172.0: 147, 173.0: 148, 174.0: 149, 175.0: 150, 176.0: 151, 178.0: 152, 179.0: 153, 180.0: 154, 181.0: 155, 182.0: 156, 183.0: 157, 188.0: 158, 192.0: 159, 193.0: 160, 194.0: 161, 195.0: 162, 197.0: 163, 199.0: 164, 202.0: 165, 203.0: 166, 204.0: 167, 205.0: 168, 207.0: 169, 208.0: 170, 211.0: 171, 212.0: 172, 214.0: 173, 217.0: 174, 220.0: 175, 222.0: 176, 225.0: 177, 226.0: 178}), ('seriousness', 2, {'Value 1': 1}), ('customer', 363, {'Value 1': 1, 'Value 10': 2, 'Value 100': 3, 'Value 101': 4, 'Value 102': 5, 'Value 103': 6, 'Value 104': 7, 'Value 105': 8, 'Value 106': 9, 'Value 107': 10, 'Value 108': 11, 'Value 11': 12, 'Value 110': 13, 'Value 111': 14, 'Value 112': 15, 'Value 113': 16, 'Value 114': 17, 'Value 115': 18, 'Value 116': 19, 'Value 117': 20, 'Value 118': 21, 'Value 119': 22, 'Value 12': 23, 'Value 120': 24, 'Value 121': 25, 'Value 122': 26, 'Value 123': 27, 'Value 124': 28, 'Value 125': 29, 'Value 126': 30, 'Value 127': 31, 'Value 129': 32, 'Value 13': 33, 'Value 131': 34, 'Value 132': 35, 'Value 133': 36, 'Value 134': 37, 'Value 135': 38, 'Value 136': 39, 'Value 137': 40, 'Value 138': 41, 'Value 139': 42, 'Value 14': 43, 'Value 140': 44, 'Value 142': 45, 'Value 143': 46, 'Value 144': 47, 'Value 145': 48, 'Value 146': 49, 'Value 147': 50, 'Value 148': 51, 'Value 149': 52, 'Value 15': 53, 'Value 150': 54, 'Value 151': 55, 'Value 152': 56, 'Value 153': 57, 'Value 154': 58, 'Value 155': 59, 'Value 156': 60, 'Value 157': 61, 'Value 158': 62, 'Value 16': 63, 'Value 160': 64, 'Value 161': 65, 'Value 162': 66, 'Value 163': 67, 'Value 164': 68, 'Value 165': 69, 'Value 166': 70, 'Value 167': 71, 'Value 168': 72, 'Value 169': 73, 'Value 17': 74, 'Value 171': 75, 'Value 172': 76, 'Value 173': 77, 'Value 174': 78, 'Value 175': 79, 'Value 176': 80, 'Value 177': 81, 'Value 178': 82, 'Value 179': 83, 'Value 18': 84, 'Value 180': 85, 'Value 181': 86, 'Value 182': 87, 'Value 183': 88, 'Value 184': 89, 'Value 185': 90, 'Value 186': 91, 'Value 187': 92, 'Value 188': 93, 'Value 189': 94, 'Value 19': 95, 'Value 190': 96, 'Value 191': 97, 'Value 192': 98, 'Value 193': 99, 'Value 194': 100, 'Value 195': 101, 'Value 196': 102, 'Value 197': 103, 'Value 198': 104, 'Value 199': 105, 'Value 2': 106, 'Value 20': 107, 'Value 200': 108, 'Value 201': 109, 'Value 202': 110, 'Value 203': 111, 'Value 204': 112, 'Value 205': 113, 'Value 206': 114, 'Value 207': 115, 'Value 208': 116, ...
# Encoder dynamic input features:  [['Activity', 'Resource'], ['case_elapsed_time', 'event_elapsed_time', 'day_in_week', 'seconds_in_day']]
# Encoder static input features:  [['VariantIndex', 'seriousness', 'customer', 'product', 'responsible_section', 'service_level', 'service_type', 'support_section', 'workgroup'], []]
# Decoder input and output features:  [['Activity'], ['case_elapsed_time', 'event_elapsed_time']]
# Sequence length of decoder output:  5
#
#
# LSTM cells and FC hidden size:  128
# Number of LSTM layer:  4
# Dropout rate:  0.1
#
#
# Encoder dynamic:
# Encoder number of labels for each input feature (categorical, numerical):  [[16, 24], [1, 1, 1, 1]]
# Encoder indices of tensors in dataset used as input:  [[0, 1], [0, 1, 2, 3]]
# Embeddings encoder:  ModuleList(
#   (0): Embedding(16, 8)
#   (1): Embedding(24, 9)
# )
# Total embedding feature size encoder:  17
# Total numerical feature size encoder:  4
# Input feature size encoder:  21
#
#
# Encoder static:
# Encoder number of labels for each input feature (categorical, numerical):  [[179, 2, 363, 22, 8, 5, 5, 7, 5], []]
# Encoder indices of tensors in dataset used as input (static):  [[0, 1, 2, 3, 4, 5, 6, 7, 8], []]
# Static encoder categorical embeddings:  ModuleList(
#   (0): Embedding(179, 29)
#   (1): Embedding(2, 2)
#   (2): Embedding(363, 43)
#   (3): Embedding(22, 9)
#   (4): Embedding(8, 5)
#   (5-6): 2 x Embedding(5, 4)
#   (7): Embedding(7, 5)
#   (8): Embedding(5, 4)
# )
# Total embedding feature size encoder (static):  105
# Total numerical feature size encoder (static):  0
# Static encoder feature size:  105
# Encoder initialized!
#
# Decoder label values size for each categorical input feature:  [16]
# Decoder label values size for each numerical input feature:  [1, 1]
# Decoder indices of tensors in dataset used as input:  [[0], [0, 1]]
# Embeddings decoder:  ModuleList(
#   (0): Embedding(16, 8)
# )
# Total embedding feature size decoder:  8
# Total numerical feature size decoder:  2
# Input feature size decoder:  10
# Output feature list of dicts (featue name, feature output size) of decoder:  [{'Activity': 16}, {'case_elapsed_time': 1, 'event_elapsed_time': 1}]
# Decoder initialized!

# %% [markdown]
# # Loss Object Creation

# %%
import loss.losses
importlib.reload(loss.losses)
from loss.losses import Loss

loss_obj = Loss()

# %% [markdown]
# # Training Configuration

# %%
import trainer.trainer
importlib.reload(trainer.trainer)
from trainer.trainer import Trainer
from torch.optim.lr_scheduler import ReduceLROnPlateau
from torch.utils.tensorboard import SummaryWriter

writer = SummaryWriter(comment="Full_Helpdesk_grad_conf")

# device
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Start learning rate
learning_rate = 1e-5
weight_decay = 0

# Optimizer and Scheduler
optimizer = torch.optim.AdamW(params=model.parameters(), lr=learning_rate, weight_decay=weight_decay)
scheduler = ReduceLROnPlateau(optimizer, mode='min', factor=0.1, patience=15, min_lr=1e-8)

# Epochs
num_epochs = 100

# Batches
batch_size = 128

# lambda for L2 (weight, bias, dropout) regularization
# regularization_term = 1.0/(2.0*batch_size)
regularization_term = 1e-4

# shuffle data
shuffle = True

# teacher forcing
max_teacher_forcing_value = 1.0
min_teacher_forcing_value = 0.0

optimize_values = {"regularization_term":regularization_term,
                   "optimizer":optimizer,
                   "scheduler": scheduler,
                   "epochs":num_epochs,
                   "mini_batches":batch_size,
                   "shuffle": shuffle,
                   "min_teacher_forcing_value":min_teacher_forcing_value,
                   "max_teacher_forcing_value":max_teacher_forcing_value}

suffix_data_split_value = helpdesk_train_dataset.min_suffix_size
print("Train seq length: ", suffix_data_split_value)

"""
GradNorm:
We disable it here to establish a baseline. Complexity (GradNorm) should only be added if the  baseline fails to learn certain tasks.
"""
# GradNorm parameter: 
use_gradnorm = True
# use_gradnorm = False
# task to be balanced for teacher forcing
number_tasks = len(dec_feat[0]) + len(dec_feat[1])
# Grdanorm hyperparams
# alpha: tasks/ alpha value (rule of thumb): 2-3: 1.0-1.5, 4-6: 0.7-1.0, 7-10: 0.4-0.7
# Formula approx: 2/sqrt(tasks)
gn_alpha = 1.5
# learning rate: Adjust relative to model learning rate.
gn_learning_rate = 1e-4

gradNorm = {"use_gradnorm":use_gradnorm,
            "number_tasks": number_tasks,
            "gn_alpha":gn_alpha,
            "gn_learning_rate": gn_learning_rate}
# gradNorm = None

trainer = Trainer(device=device,
                  model=model,
                  data_train=helpdesk_train_dataset,
                  data_val=helpdesk_val_dataset,
                  loss_obj=loss_obj,
                  log_normal_loss_num_feature = [],
                  optimize_values=optimize_values,
                  suffix_data_split_value=suffix_data_split_value,
                  writer=writer,
                  gradnorm_values=gradNorm,
                  save_model_n_th_epoch = 1,
                  saving_path = 'Helpdesk_full_grad_norm_conformal_v2.pkl')

# Train the model:
# - use stattics: (tensor) tensor of seperate encoded static attributes which is merged with dynmaics beforehand
# - use zero padd masking: (True) mask the left padded zeros in the encoder
# - use EOS padd masking: (True) mask the right padded unwanted EOS tokens in the loss
train_attenuated_losses, val_losses, val_attenuated_losses = trainer.train_model(use_statics=True,
                                                                                 use_zero_padd_masking=True,
                                                                                 use_eos_padd_masking=True)
# Out:
# Train seq length:  5
# Device:  cuda
# Model:  DropoutUncertaintyEncoderDecoderLSTM(
#   (embeddings_enc): ModuleList(
#     (0): Embedding(16, 8)
#     (1): Embedding(24, 9)
#   )
#   (embeddings_static_enc): ModuleList(
#     (0): Embedding(179, 29)
#     (1): Embedding(2, 2)
#     (2): Embedding(363, 43)
#     (3): Embedding(22, 9)
#     (4): Embedding(8, 5)
#     (5-6): 2 x Embedding(5, 4)
#     (7): Embedding(7, 5)
#     (8): Embedding(5, 4)
#   )
#   (encoder): DropoutUncertaintyLSTMEncoder(
#     (embeddings): ModuleList(
#       (0): Embedding(16, 8)
#       (1): Embedding(24, 9)
#     )
#     (static_embeddings): ModuleList(
#       (0): Embedding(179, 29)
#       (1): Embedding(2, 2)
#       (2): Embedding(363, 43)
#       (3): Embedding(22, 9)
#       (4): Embedding(8, 5)
#       (5-6): 2 x Embedding(5, 4)
#       (7): Embedding(7, 5)
#       (8): Embedding(5, 4)
#     )
#     (input_proj): Linear(in_features=126, out_features=128, bias=True)
#     (layernorm): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#     (act): ReLU()
#     (first_layer): DropoutUncertaintyLSTMCell(
#       (Wi): Linear(in_features=128, out_features=128, bias=True)
#       (Ui): Linear(in_features=128, out_features=128, bias=True)
#       (Wf): Linear(in_features=128, out_features=128, bias=True)
#       (Uf): Linear(in_features=128, out_features=128, bias=True)
#       (Wc): Linear(in_features=128, out_features=128, bias=True)
#       (Uc): Linear(in_features=128, out_features=128, bias=True)
#       (Wo): Linear(in_features=128, out_features=128, bias=True)
#       (Uo): Linear(in_features=128, out_features=128, bias=True)
#     )
#     (hidden_layers): ModuleList(
#       (0-2): 3 x DropoutUncertaintyLSTMCell(
#         (Wi): Linear(in_features=128, out_features=128, bias=True)
#         (Ui): Linear(in_features=128, out_features=128, bias=True)
#         (Wf): Linear(in_features=128, out_features=128, bias=True)
#         (Uf): Linear(in_features=128, out_features=128, bias=True)
#         (Wc): Linear(in_features=128, out_features=128, bias=True)
#         (Uc): Linear(in_features=128, out_features=128, bias=True)
#         (Wo): Linear(in_features=128, out_features=128, bias=True)
#         (Uo): Linear(in_features=128, out_features=128, bias=True)
#       )
#     )
#   )
#   (embeddings_dec): ModuleList(
#     (0): Embedding(16, 8)
#   )
#   (decoder): DropoutUncertaintyLSTMDecoder(
#     (embeddings): ModuleList(
#       (0): Embedding(16, 8)
#     )
#     (input_proj): Linear(in_features=10, out_features=128, bias=True)
#     (layernorm): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#     (act): ReLU()
#     (first_layer): DropoutUncertaintyLSTMCell(
#       (Wi): Linear(in_features=128, out_features=128, bias=True)
#       (Ui): Linear(in_features=128, out_features=128, bias=True)
#       (Wf): Linear(in_features=128, out_features=128, bias=True)
#       (Uf): Linear(in_features=128, out_features=128, bias=True)
#       (Wc): Linear(in_features=128, out_features=128, bias=True)
#       (Uc): Linear(in_features=128, out_features=128, bias=True)
#       (Wo): Linear(in_features=128, out_features=128, bias=True)
#       (Uo): Linear(in_features=128, out_features=128, bias=True)
#     )
#     (hidden_layers): ModuleList(
#       (0-2): 3 x DropoutUncertaintyLSTMCell(
#         (Wi): Linear(in_features=128, out_features=128, bias=True)
#         (Ui): Linear(in_features=128, out_features=128, bias=True)
#         (Wf): Linear(in_features=128, out_features=128, bias=True)
#         (Uf): Linear(in_features=128, out_features=128, bias=True)
#         (Wc): Linear(in_features=128, out_features=128, bias=True)
#         (Uc): Linear(in_features=128, out_features=128, bias=True)
#         (Wo): Linear(in_features=128, out_features=128, bias=True)
#         (Uo): Linear(in_features=128, out_features=128, bias=True)
#       )
#     )
#     (output_layers): ModuleDict(
#       (Activity_mean): Linear(in_features=128, out_features=16, bias=True)
#       (Activity_var): Linear(in_features=128, out_features=16, bias=True)
#       (case_elapsed_time_mean): Linear(in_features=128, out_features=1, bias=True)
#       (case_elapsed_time_var): Linear(in_features=128, out_features=1, bias=True)
#       (event_elapsed_time_mean): Linear(in_features=128, out_features=1, bias=True)
#       (event_elapsed_time_var): Linear(in_features=128, out_features=1, bias=True)
#     )
#   )
# )
# Train Dataset:  <event_log_loader.new_event_log_loader_v2.EventLogDataset object at 0x7ff4dcba8d70>
# Validation Dataset:  <event_log_loader.new_event_log_loader_v2.EventLogDataset object at 0x7ff3a5d728d0>
# Loss object for method calling:  <loss.losses.Loss object at 0x7ff3a0b9f050>
# Num. feautures that follow log-normal PDF:  []
# regularization:  0.0001
# Optimizer:  AdamW (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     capturable: False
#     decoupled_weight_decay: True
#     differentiable: False
#     eps: 1e-08
#     foreach: None
#     fused: None
#     lr: 1e-05
#     maximize: False
#     weight_decay: 0
# )
# Scheduler:  <torch.optim.lr_scheduler.ReduceLROnPlateau object at 0x7ff3a0952ba0>
# Epochs:  100
# Mini baches:  128
# Shuffle batched dataset:  True
# Use GradNorm:  True
# GradNorm alpha:  1.5
# GradNorm learning rate:  0.0001
# Initial GradNorm loss weights:  Parameter containing:
# tensor([1., 1., 1.], device='cuda:0', requires_grad=True)
# Initial loss values:  None
# GradNorm optimizer:  AdamW (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     capturable: False
#     decoupled_weight_decay: True
#     differentiable: False
#     eps: 1e-08
#     foreach: None
#     fused: None
#     lr: 0.0001
#     maximize: False
#     weight_decay: 0.01
# )
# Epoch [1/100], Learning Rate: 1e-05, Teacher forcing ratio: 1.0
# Training: Avg Attenuated Training Loss: 5.4352
# Validation: Avg Standard Validation Loss: 6.6650
# Validation: Avg Attenuated Validation Loss: 5.0949
# Validation Loss for Scheduler: 6.6650
# saving model
# Epoch [2/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.98
# Training: Avg Attenuated Training Loss: 5.3497
# Validation: Avg Standard Validation Loss: 6.5715
# Validation: Avg Attenuated Validation Loss: 4.9791
# Validation Loss for Scheduler: 6.5715
# saving model
# Epoch [3/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.96
# Training: Avg Attenuated Training Loss: 5.1831
# Validation: Avg Standard Validation Loss: 6.3491
# Validation: Avg Attenuated Validation Loss: 4.7661
# Validation Loss for Scheduler: 6.3491
# saving model
# Epoch [4/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.94
# Training: Avg Attenuated Training Loss: 4.7870
# Validation: Avg Standard Validation Loss: 6.0306
# Validation: Avg Attenuated Validation Loss: 4.4930
# Validation Loss for Scheduler: 6.0306
# saving model
# Epoch [5/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.92
# Training: Avg Attenuated Training Loss: 4.2475
# Validation: Avg Standard Validation Loss: 5.6440
# Validation: Avg Attenuated Validation Loss: 4.1405
# Validation Loss for Scheduler: 5.6440
# saving model
# Epoch [6/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.9
# Training: Avg Attenuated Training Loss: 3.8324
# Validation: Avg Standard Validation Loss: 5.2260
# Validation: Avg Attenuated Validation Loss: 3.7149
# Validation Loss for Scheduler: 5.2260
# saving model
# Epoch [7/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.88
# Training: Avg Attenuated Training Loss: 3.3589
# Validation: Avg Standard Validation Loss: 4.9165
# Validation: Avg Attenuated Validation Loss: 3.3885
# Validation Loss for Scheduler: 4.9165
# saving model
# Epoch [8/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.86
# Training: Avg Attenuated Training Loss: 2.9281
# Validation: Avg Standard Validation Loss: 4.6363
# Validation: Avg Attenuated Validation Loss: 3.1387
# Validation Loss for Scheduler: 4.6363
# saving model
# Epoch [9/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.84
# Training: Avg Attenuated Training Loss: 2.5605
# Validation: Avg Standard Validation Loss: 4.5296
# Validation: Avg Attenuated Validation Loss: 3.1523
# Validation Loss for Scheduler: 4.5296
# saving model
# Epoch [10/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.8200000000000001
# Training: Avg Attenuated Training Loss: 2.2443
# Validation: Avg Standard Validation Loss: 4.5302
# Validation: Avg Attenuated Validation Loss: 3.3427
# Validation Loss for Scheduler: 4.5302
# saving model
# Epoch [11/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.8
# Training: Avg Attenuated Training Loss: 2.0406
# Validation: Avg Standard Validation Loss: 4.5265
# Validation: Avg Attenuated Validation Loss: 3.5592
# Validation Loss for Scheduler: 4.5265
# saving model
# Epoch [12/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.78
# Training: Avg Attenuated Training Loss: 1.9395
# Validation: Avg Standard Validation Loss: 4.5229
# Validation: Avg Attenuated Validation Loss: 3.7780
# Validation Loss for Scheduler: 4.5229
# saving model
# Epoch [13/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.76
# Training: Avg Attenuated Training Loss: 1.8881
# Validation: Avg Standard Validation Loss: 4.4858
# Validation: Avg Attenuated Validation Loss: 3.9550
# Validation Loss for Scheduler: 4.4858
# saving model
# Epoch [14/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.74
# Training: Avg Attenuated Training Loss: 1.7724
# Validation: Avg Standard Validation Loss: 4.4945
# Validation: Avg Attenuated Validation Loss: 4.2542
# Validation Loss for Scheduler: 4.4945
# saving model
# Epoch [15/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.72
# Training: Avg Attenuated Training Loss: 1.6960
# Validation: Avg Standard Validation Loss: 4.5152
# Validation: Avg Attenuated Validation Loss: 4.6247
# Validation Loss for Scheduler: 4.5152
# saving model
# Epoch [16/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.7
# Training: Avg Attenuated Training Loss: 1.7556
# Validation: Avg Standard Validation Loss: 4.4335
# Validation: Avg Attenuated Validation Loss: 4.7428
# Validation Loss for Scheduler: 4.4335
# saving model
# Epoch [17/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.6799999999999999
# Training: Avg Attenuated Training Loss: 1.6819
# Validation: Avg Standard Validation Loss: 4.0853
# Validation: Avg Attenuated Validation Loss: 4.2034
# Validation Loss for Scheduler: 4.0853
# saving model
# Epoch [18/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.6599999999999999
# Training: Avg Attenuated Training Loss: 1.7033
# Validation: Avg Standard Validation Loss: 3.7618
# Validation: Avg Attenuated Validation Loss: 3.5651
# Validation Loss for Scheduler: 3.7618
# saving model
# Epoch [19/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.64
# Training: Avg Attenuated Training Loss: 1.6547
# Validation: Avg Standard Validation Loss: 3.6809
# Validation: Avg Attenuated Validation Loss: 3.4172
# Validation Loss for Scheduler: 3.6809
# saving model
# Epoch [20/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.62
# Training: Avg Attenuated Training Loss: 1.7307
# Validation: Avg Standard Validation Loss: 3.6451
# Validation: Avg Attenuated Validation Loss: 3.2105
# Validation Loss for Scheduler: 3.6451
# saving model
# Epoch [21/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.6
# Training: Avg Attenuated Training Loss: 1.6140
# Validation: Avg Standard Validation Loss: 3.6632
# Validation: Avg Attenuated Validation Loss: 3.2945
# Validation Loss for Scheduler: 3.6632
# saving model
# Epoch [22/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.5800000000000001
# Training: Avg Attenuated Training Loss: 1.6547
# Validation: Avg Standard Validation Loss: 3.5853
# Validation: Avg Attenuated Validation Loss: 2.9914
# Validation Loss for Scheduler: 3.5853
# saving model
# Epoch [23/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.56
# Training: Avg Attenuated Training Loss: 1.6294
# Validation: Avg Standard Validation Loss: 3.5256
# Validation: Avg Attenuated Validation Loss: 2.8193
# Validation Loss for Scheduler: 3.5256
# saving model
# Epoch [24/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.54
# Training: Avg Attenuated Training Loss: 1.5145
# Validation: Avg Standard Validation Loss: 3.4962
# Validation: Avg Attenuated Validation Loss: 2.8357
# Validation Loss for Scheduler: 3.4962
# saving model
# Epoch [25/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.52
# Training: Avg Attenuated Training Loss: 1.5969
# Validation: Avg Standard Validation Loss: 3.4372
# Validation: Avg Attenuated Validation Loss: 2.5080
# Validation Loss for Scheduler: 3.4372
# saving model
# Epoch [26/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.5
# Training: Avg Attenuated Training Loss: 1.5518
# Validation: Avg Standard Validation Loss: 3.3671
# Validation: Avg Attenuated Validation Loss: 2.3346
# Validation Loss for Scheduler: 3.3671
# saving model
# Epoch [27/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.48
# Training: Avg Attenuated Training Loss: 1.5317
# Validation: Avg Standard Validation Loss: 3.3348
# Validation: Avg Attenuated Validation Loss: 2.1727
# Validation Loss for Scheduler: 3.3348
# saving model
# Epoch [28/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.45999999999999996
# Training: Avg Attenuated Training Loss: 1.5519
# Validation: Avg Standard Validation Loss: 3.2286
# Validation: Avg Attenuated Validation Loss: 1.9474
# Validation Loss for Scheduler: 3.2286
# saving model
# Epoch [29/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.43999999999999995
# Training: Avg Attenuated Training Loss: 1.4574
# Validation: Avg Standard Validation Loss: 3.1481
# Validation: Avg Attenuated Validation Loss: 1.8350
# Validation Loss for Scheduler: 3.1481
# saving model
# Epoch [30/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.42000000000000004
# Training: Avg Attenuated Training Loss: 1.4728
# Validation: Avg Standard Validation Loss: 3.1241
# Validation: Avg Attenuated Validation Loss: 1.7381
# Validation Loss for Scheduler: 3.1241
# saving model
# Epoch [31/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.4
# Training: Avg Attenuated Training Loss: 1.3747
# Validation: Avg Standard Validation Loss: 3.0470
# Validation: Avg Attenuated Validation Loss: 1.7051
# Validation Loss for Scheduler: 3.0470
# saving model
# Epoch [32/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.38
# Training: Avg Attenuated Training Loss: 1.3260
# Validation: Avg Standard Validation Loss: 2.9971
# Validation: Avg Attenuated Validation Loss: 1.6260
# Validation Loss for Scheduler: 2.9971
# saving model
# Epoch [33/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.36
# Training: Avg Attenuated Training Loss: 1.3346
# Validation: Avg Standard Validation Loss: 2.9574
# Validation: Avg Attenuated Validation Loss: 1.5584
# Validation Loss for Scheduler: 2.9574
# saving model
# Epoch [34/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.33999999999999997
# Training: Avg Attenuated Training Loss: 1.3021
# Validation: Avg Standard Validation Loss: 2.8922
# Validation: Avg Attenuated Validation Loss: 1.4671
# Validation Loss for Scheduler: 2.8922
# saving model
# Epoch [35/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.31999999999999995
# Training: Avg Attenuated Training Loss: 1.2948
# Validation: Avg Standard Validation Loss: 2.8906
# Validation: Avg Attenuated Validation Loss: 1.4305
# Validation Loss for Scheduler: 2.8906
# saving model
# Epoch [36/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.30000000000000004
# Training: Avg Attenuated Training Loss: 1.2348
# Validation: Avg Standard Validation Loss: 2.8165
# Validation: Avg Attenuated Validation Loss: 1.4181
# Validation Loss for Scheduler: 2.8165
# saving model
# Epoch [37/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.28
# Training: Avg Attenuated Training Loss: 1.2303
# Validation: Avg Standard Validation Loss: 2.7983
# Validation: Avg Attenuated Validation Loss: 1.3626
# Validation Loss for Scheduler: 2.7983
# saving model
# Epoch [38/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.26
# Training: Avg Attenuated Training Loss: 1.2321
# Validation: Avg Standard Validation Loss: 2.7661
# Validation: Avg Attenuated Validation Loss: 1.2904
# Validation Loss for Scheduler: 2.7661
# saving model
# Epoch [39/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.24
# Training: Avg Attenuated Training Loss: 1.1958
# Validation: Avg Standard Validation Loss: 2.7559
# Validation: Avg Attenuated Validation Loss: 1.2733
# Validation Loss for Scheduler: 2.7559
# saving model
# Epoch [40/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.21999999999999997
# Training: Avg Attenuated Training Loss: 1.1994
# Validation: Avg Standard Validation Loss: 2.7150
# Validation: Avg Attenuated Validation Loss: 1.2178
# Validation Loss for Scheduler: 2.7150
# saving model
# Epoch [41/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.19999999999999996
# Training: Avg Attenuated Training Loss: 1.1338
# Validation: Avg Standard Validation Loss: 2.6929
# Validation: Avg Attenuated Validation Loss: 1.2268
# Validation Loss for Scheduler: 2.6929
# saving model
# Epoch [42/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.18000000000000005
# Training: Avg Attenuated Training Loss: 1.1526
# Validation: Avg Standard Validation Loss: 2.6812
# Validation: Avg Attenuated Validation Loss: 1.2090
# Validation Loss for Scheduler: 2.6812
# saving model
# Epoch [43/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.16000000000000003
# Training: Avg Attenuated Training Loss: 1.1224
# Validation: Avg Standard Validation Loss: 2.6999
# Validation: Avg Attenuated Validation Loss: 1.1839
# Validation Loss for Scheduler: 2.6999
# saving model
# Epoch [44/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.14
# Training: Avg Attenuated Training Loss: 1.0915
# Validation: Avg Standard Validation Loss: 2.6966
# Validation: Avg Attenuated Validation Loss: 1.1188
# Validation Loss for Scheduler: 2.6966
# saving model
# Epoch [45/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.12
# Training: Avg Attenuated Training Loss: 1.0811
# Validation: Avg Standard Validation Loss: 2.6440
# Validation: Avg Attenuated Validation Loss: 1.0545
# Validation Loss for Scheduler: 2.6440
# saving model
# Epoch [46/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.09999999999999998
# Training: Avg Attenuated Training Loss: 1.0702
# Validation: Avg Standard Validation Loss: 2.6490
# Validation: Avg Attenuated Validation Loss: 1.0599
# Validation Loss for Scheduler: 2.6490
# saving model
# Epoch [47/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.07999999999999996
# Training: Avg Attenuated Training Loss: 1.0419
# Validation: Avg Standard Validation Loss: 2.6043
# Validation: Avg Attenuated Validation Loss: 0.9881
# Validation Loss for Scheduler: 2.6043
# saving model
# Epoch [48/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.06000000000000005
# Training: Avg Attenuated Training Loss: 1.0177
# Validation: Avg Standard Validation Loss: 2.5834
# Validation: Avg Attenuated Validation Loss: 0.9898
# Validation Loss for Scheduler: 2.5834
# saving model
# Epoch [49/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.040000000000000036
# Training: Avg Attenuated Training Loss: 0.9898
# Validation: Avg Standard Validation Loss: 2.5746
# Validation: Avg Attenuated Validation Loss: 0.9339
# Validation Loss for Scheduler: 2.5746
# saving model
# Epoch [50/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.020000000000000018
# Training: Avg Attenuated Training Loss: 0.9955
# Validation: Avg Standard Validation Loss: 2.5529
# Validation: Avg Attenuated Validation Loss: 0.9483
# Validation Loss for Scheduler: 2.5529
# saving model
# Epoch [51/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.0
# Training: Avg Attenuated Training Loss: 0.9434
# Validation: Avg Standard Validation Loss: 2.5832
# Validation: Avg Attenuated Validation Loss: 0.9149
# Validation Loss for Scheduler: 2.5832
# saving model
# Epoch [52/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.0
# Training: Avg Attenuated Training Loss: 0.9161
# Validation: Avg Standard Validation Loss: 2.5401
# Validation: Avg Attenuated Validation Loss: 0.9028
# Validation Loss for Scheduler: 2.5401
# saving model
# Epoch [53/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.0
# Training: Avg Attenuated Training Loss: 0.9072
# Validation: Avg Standard Validation Loss: 2.5161
# Validation: Avg Attenuated Validation Loss: 0.8883
# Validation Loss for Scheduler: 2.5161
# saving model
# Epoch [54/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.0
# Training: Avg Attenuated Training Loss: 0.8774
# Validation: Avg Standard Validation Loss: 2.4912
# Validation: Avg Attenuated Validation Loss: 0.8170
# Validation Loss for Scheduler: 2.4912
# saving model
# Epoch [55/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.0
# Training: Avg Attenuated Training Loss: 0.8536
# Validation: Avg Standard Validation Loss: 2.4635
# Validation: Avg Attenuated Validation Loss: 0.9750
# Validation Loss for Scheduler: 2.4635
# saving model
# Epoch [56/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.0
# Training: Avg Attenuated Training Loss: 0.8281
# Validation: Avg Standard Validation Loss: 2.4826
# Validation: Avg Attenuated Validation Loss: 0.9619
# Validation Loss for Scheduler: 2.4826
# saving model
# Epoch [57/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.0
# Training: Avg Attenuated Training Loss: 0.8293
# Validation: Avg Standard Validation Loss: 2.5064
# Validation: Avg Attenuated Validation Loss: 0.8278
# Validation Loss for Scheduler: 2.5064
# saving model
# Epoch [58/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.0
# Training: Avg Attenuated Training Loss: 0.7987
# Validation: Avg Standard Validation Loss: 2.5246
# Validation: Avg Attenuated Validation Loss: 0.7494
# Validation Loss for Scheduler: 2.5246
# saving model
# Epoch [59/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.0
# Training: Avg Attenuated Training Loss: 0.7867
# Validation: Avg Standard Validation Loss: 2.4720
# Validation: Avg Attenuated Validation Loss: 0.8341
# Validation Loss for Scheduler: 2.4720
# saving model
# Epoch [60/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.0
# Training: Avg Attenuated Training Loss: 0.7518
# Validation: Avg Standard Validation Loss: 2.4780
# Validation: Avg Attenuated Validation Loss: 0.9136
# Validation Loss for Scheduler: 2.4780
# saving model
# Epoch [61/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.0
# Training: Avg Attenuated Training Loss: 0.7017
# Validation: Avg Standard Validation Loss: 2.4506
# Validation: Avg Attenuated Validation Loss: 0.8129
# Validation Loss for Scheduler: 2.4506
# saving model
# Epoch [62/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.0
# Training: Avg Attenuated Training Loss: 0.6891
# Validation: Avg Standard Validation Loss: 2.4874
# Validation: Avg Attenuated Validation Loss: 0.8116
# Validation Loss for Scheduler: 2.4874
# saving model
# Epoch [63/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.0
# Training: Avg Attenuated Training Loss: 0.6446
# Validation: Avg Standard Validation Loss: 2.4188
# Validation: Avg Attenuated Validation Loss: 0.9889
# Validation Loss for Scheduler: 2.4188
# saving model
# Epoch [64/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.0
# Training: Avg Attenuated Training Loss: 0.6994
# Validation: Avg Standard Validation Loss: 2.4453
# Validation: Avg Attenuated Validation Loss: 0.7797
# Validation Loss for Scheduler: 2.4453
# saving model
# Epoch [65/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.0
# Training: Avg Attenuated Training Loss: 0.6450
# Validation: Avg Standard Validation Loss: 2.4349
# Validation: Avg Attenuated Validation Loss: 0.8368
# Validation Loss for Scheduler: 2.4349
# saving model
# Epoch [66/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.0
# Training: Avg Attenuated Training Loss: 0.6701
# Validation: Avg Standard Validation Loss: 2.4307
# Validation: Avg Attenuated Validation Loss: 0.7599
# Validation Loss for Scheduler: 2.4307
# saving model
# Epoch [67/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.0
# Training: Avg Attenuated Training Loss: 0.5684
# Validation: Avg Standard Validation Loss: 2.4850
# Validation: Avg Attenuated Validation Loss: 0.8463
# Validation Loss for Scheduler: 2.4850
# saving model
# Epoch [68/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.0
# Training: Avg Attenuated Training Loss: 0.6006
# Validation: Avg Standard Validation Loss: 2.3923
# Validation: Avg Attenuated Validation Loss: 0.8172
# Validation Loss for Scheduler: 2.3923
# saving model
# Epoch [69/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.0
# Training: Avg Attenuated Training Loss: 0.5188
# Validation: Avg Standard Validation Loss: 2.4438
# Validation: Avg Attenuated Validation Loss: 0.8979
# Validation Loss for Scheduler: 2.4438
# saving model
# Epoch [70/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.0
# Training: Avg Attenuated Training Loss: 0.5251
# Validation: Avg Standard Validation Loss: 2.4105
# Validation: Avg Attenuated Validation Loss: 1.0423
# Validation Loss for Scheduler: 2.4105
# saving model
# Epoch [71/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.0
# Training: Avg Attenuated Training Loss: 0.6563
# Validation: Avg Standard Validation Loss: 2.4271
# Validation: Avg Attenuated Validation Loss: 0.9082
# Validation Loss for Scheduler: 2.4271
# saving model
# Epoch [72/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.0
# Training: Avg Attenuated Training Loss: 0.5747
# Validation: Avg Standard Validation Loss: 2.3913
# Validation: Avg Attenuated Validation Loss: 0.7954
# Validation Loss for Scheduler: 2.3913
# saving model
# Epoch [73/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.0
# Training: Avg Attenuated Training Loss: 0.5347
# Validation: Avg Standard Validation Loss: 2.4254
# Validation: Avg Attenuated Validation Loss: 0.7552
# Validation Loss for Scheduler: 2.4254
# saving model
# Epoch [74/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.0
# Training: Avg Attenuated Training Loss: 0.5191
# Validation: Avg Standard Validation Loss: 2.4152
# Validation: Avg Attenuated Validation Loss: 1.0540
# Validation Loss for Scheduler: 2.4152
# saving model
# Epoch [75/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.0
# Training: Avg Attenuated Training Loss: 0.5291
# Validation: Avg Standard Validation Loss: 2.3617
# Validation: Avg Attenuated Validation Loss: 1.2689
# Validation Loss for Scheduler: 2.3617
# saving model
# Epoch [76/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.0
# Training: Avg Attenuated Training Loss: 0.6085
# Validation: Avg Standard Validation Loss: 2.3509
# Validation: Avg Attenuated Validation Loss: 1.3335
# Validation Loss for Scheduler: 2.3509
# saving model
# Epoch [77/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.0
# Training: Avg Attenuated Training Loss: 0.4575
# Validation: Avg Standard Validation Loss: 2.3911
# Validation: Avg Attenuated Validation Loss: 1.3346
# Validation Loss for Scheduler: 2.3911
# saving model
# Epoch [78/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.0
# Training: Avg Attenuated Training Loss: 0.5456
# Validation: Avg Standard Validation Loss: 2.4143
# Validation: Avg Attenuated Validation Loss: 0.8973
# Validation Loss for Scheduler: 2.4143
# saving model
# Epoch [79/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.0
# Training: Avg Attenuated Training Loss: 0.4198
# Validation: Avg Standard Validation Loss: 2.4291
# Validation: Avg Attenuated Validation Loss: 0.7565
# Validation Loss for Scheduler: 2.4291
# saving model
# Epoch [80/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.0
# Training: Avg Attenuated Training Loss: 0.4227
# Validation: Avg Standard Validation Loss: 2.4040
# Validation: Avg Attenuated Validation Loss: 0.8224
# Validation Loss for Scheduler: 2.4040
# saving model
# Epoch [81/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.0
# Training: Avg Attenuated Training Loss: 0.4474
# Validation: Avg Standard Validation Loss: 2.3580
# Validation: Avg Attenuated Validation Loss: 1.0496
# Validation Loss for Scheduler: 2.3580
# saving model
# Epoch [82/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.0
# Training: Avg Attenuated Training Loss: 0.5619
# Validation: Avg Standard Validation Loss: 2.3745
# Validation: Avg Attenuated Validation Loss: 0.9061
# Validation Loss for Scheduler: 2.3745
# saving model
# Epoch [83/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.0
# Training: Avg Attenuated Training Loss: 0.4390
# Validation: Avg Standard Validation Loss: 2.3572
# Validation: Avg Attenuated Validation Loss: 1.7036
# Validation Loss for Scheduler: 2.3572
# saving model
# Epoch [84/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.0
# Training: Avg Attenuated Training Loss: 0.3852
# Validation: Avg Standard Validation Loss: 2.3758
# Validation: Avg Attenuated Validation Loss: 1.2463
# Validation Loss for Scheduler: 2.3758
# saving model
# Epoch [85/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.0
# Training: Avg Attenuated Training Loss: 0.4560
# Validation: Avg Standard Validation Loss: 2.3333
# Validation: Avg Attenuated Validation Loss: 2.2249
# Validation Loss for Scheduler: 2.3333
# saving model
# Epoch [86/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.0
# Training: Avg Attenuated Training Loss: 0.5739
# Validation: Avg Standard Validation Loss: 2.3495
# Validation: Avg Attenuated Validation Loss: 2.0148
# Validation Loss for Scheduler: 2.3495
# saving model
# Epoch [87/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.0
# Training: Avg Attenuated Training Loss: 0.6600
# Validation: Avg Standard Validation Loss: 2.3272
# Validation: Avg Attenuated Validation Loss: 2.0000
# Validation Loss for Scheduler: 2.3272
# saving model
# Epoch [88/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.0
# Training: Avg Attenuated Training Loss: 0.5221
# Validation: Avg Standard Validation Loss: 2.3678
# Validation: Avg Attenuated Validation Loss: 1.4791
# Validation Loss for Scheduler: 2.3678
# saving model
# Epoch [89/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.0
# Training: Avg Attenuated Training Loss: 0.6253
# Validation: Avg Standard Validation Loss: 2.3126
# Validation: Avg Attenuated Validation Loss: 2.0237
# Validation Loss for Scheduler: 2.3126
# saving model
# Epoch [90/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.0
# Training: Avg Attenuated Training Loss: 0.5022
# Validation: Avg Standard Validation Loss: 2.3113
# Validation: Avg Attenuated Validation Loss: 1.9121
# Validation Loss for Scheduler: 2.3113
# saving model
# Epoch [91/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.0
# Training: Avg Attenuated Training Loss: 0.5736
# Validation: Avg Standard Validation Loss: 2.2997
# Validation: Avg Attenuated Validation Loss: 2.1531
# Validation Loss for Scheduler: 2.2997
# saving model
# Epoch [92/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.0
# Training: Avg Attenuated Training Loss: 0.6705
# Validation: Avg Standard Validation Loss: 2.3121
# Validation: Avg Attenuated Validation Loss: 2.3304
# Validation Loss for Scheduler: 2.3121
# saving model
# Epoch [93/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.0
# Training: Avg Attenuated Training Loss: 0.6251
# Validation: Avg Standard Validation Loss: 2.3186
# Validation: Avg Attenuated Validation Loss: 2.1542
# Validation Loss for Scheduler: 2.3186
# saving model
# Epoch [94/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.0
# Training: Avg Attenuated Training Loss: 0.7558
# Validation: Avg Standard Validation Loss: 2.2840
# Validation: Avg Attenuated Validation Loss: 3.1201
# Validation Loss for Scheduler: 2.2840
# saving model
# Epoch [95/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.0
# Training: Avg Attenuated Training Loss: 0.7707
# Validation: Avg Standard Validation Loss: 2.2957
# Validation: Avg Attenuated Validation Loss: 3.1218
# Validation Loss for Scheduler: 2.2957
# saving model
# Epoch [96/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.0
# Training: Avg Attenuated Training Loss: 0.8133
# Validation: Avg Standard Validation Loss: 2.2902
# Validation: Avg Attenuated Validation Loss: 2.2912
# Validation Loss for Scheduler: 2.2902
# saving model
# Epoch [97/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.0
# Training: Avg Attenuated Training Loss: 0.8513
# Validation: Avg Standard Validation Loss: 2.2872
# Validation: Avg Attenuated Validation Loss: 2.2329
# Validation Loss for Scheduler: 2.2872
# saving model
# Epoch [98/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.0
# Training: Avg Attenuated Training Loss: 0.6477
# Validation: Avg Standard Validation Loss: 2.2772
# Validation: Avg Attenuated Validation Loss: 2.4750
# Validation Loss for Scheduler: 2.2772
# saving model
# Epoch [99/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.0
# Training: Avg Attenuated Training Loss: 0.6558
# Validation: Avg Standard Validation Loss: 2.2718
# Validation: Avg Attenuated Validation Loss: 5.4905
# Validation Loss for Scheduler: 2.2718
# saving model
# Epoch [100/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.0
# Training: Avg Attenuated Training Loss: 0.9231
# Validation: Avg Standard Validation Loss: 2.2919
# Validation: Avg Attenuated Validation Loss: 2.7715
# Validation Loss for Scheduler: 2.2919
# saving model
# Training complete.
# Model saved to path: Helpdesk_full_grad_norm_conformal_v2.pkl

# %% [markdown]
# # Training Visualization

# %%
import matplotlib.pyplot as plt

# After training is finished, plot the loss curves
plt.plot(range(1, num_epochs+1), train_attenuated_losses, label='Training Attenuated Loss', color='blue')
plt.plot(range(1, num_epochs+1), val_losses, label='Validation Loss', color='orange')
plt.plot(range(1, num_epochs+1), val_attenuated_losses, label='Validation Attenuated Loss', color='green')
# Labeling x and y axes
plt.xlabel('Epochs', fontsize=12)
plt.ylabel('Loss', fontsize=12)
# Adding title
plt.title('Training and Validation Loss Curve', fontsize=14)
# Adding legend
plt.legend()
# Show the plot
plt.show()
