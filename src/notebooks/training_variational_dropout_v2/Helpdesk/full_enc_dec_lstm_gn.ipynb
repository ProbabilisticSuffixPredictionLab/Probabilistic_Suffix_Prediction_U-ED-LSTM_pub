# %% [markdown]
# # Imports

# %%
import importlib
import sys

# performance imports for torch: torch kernel uses one core only.
import os
os.environ["OMP_NUM_THREADS"] = "1"
os.environ["MKL_NUM_THREADS"] = "1"
os.environ["TORCH_NUM_THREADS"] = "1" 

import torch

sys.path.insert(0, '..')
sys.path.insert(0, '../..')
sys.path.insert(0, '../../..')

# %% [markdown]
# # Data

# %% [markdown]
# ### Load Data Files

# %%
# Path to your pickle file (saved with torch.save)
file_path_train = '../../../../encoded_data_v2/helpdesk_all_5_train.pkl'
# Load the dataset using torch.load
helpdesk_train_dataset = torch.load(file_path_train, weights_only=False)

# Path to your pickle file (saved with torch.save)
file_path_val = '../../../../encoded_data_v2/helpdesk_all_5_val.pkl'
# Load the dataset using torch.load
helpdesk_val_dataset = torch.load(file_path_val, weights_only=False)

# %% [markdown]
# ### Train Data Insights

# %%
# Helpdesk dataset dynamic categories, features:
helpdesk_all_categories = helpdesk_train_dataset.all_categories

helpdesk_all_categories_cat = helpdesk_all_categories[0]
# print(helpdesk_all_categories_cat)
helpdesk_all_categories_num = helpdesk_all_categories[1]
# print(helpdesk_all_categories_num)
for i, cat in enumerate(helpdesk_all_categories_cat):
     print(f"Helpdesk dynamic categorical feature: {cat[0]}, Index position in categorical data list: {i}")
     print(f"Helpdesk amount of category labels: {cat[1]}")
print('\n')    
for i, num in enumerate(helpdesk_all_categories_num):
     print(f"Helpdesk dynamic numerical feature: {num[0]}, Index position in categorical data list: {i}")
     print(f"Helpdesk amount of numerical: {num[1]}")
print('\n')
     
# Helpdesk dataset static categories, features:
helpdesk_all_stat_categories = helpdesk_train_dataset.all_static_categories

helpdesk_all_stat_categories_cat = helpdesk_all_stat_categories[0]
# print(helpdesk_all_stat_categories_cat)
helpdesk_all_stat_categories_num = helpdesk_all_stat_categories[1]
# print(helpdesk_all_stat_categories_num)
for i, cat in enumerate(helpdesk_all_stat_categories_cat):
     print(f"Helpdesk static categorical feature: {cat[0]}, Index position in categorical data list: {i}")
     print(f"Helpdesk amount of category labels: {cat[1]}")
print('\n')    
for i, num in enumerate(helpdesk_all_stat_categories_num):
     print(f"Helpdesk static numerical feature: {num[0]}, Index position in categorical data list: {i}")
     print(f"Helpdesk amount of numerical: {num[1]}")
# Out:
# Helpdesk dynamic categorical feature: Activity, Index position in categorical data list: 0
# Helpdesk amount of category labels: 16
# Helpdesk dynamic categorical feature: Resource, Index position in categorical data list: 1
# Helpdesk amount of category labels: 24
#
#
# Helpdesk dynamic numerical feature: case_elapsed_time, Index position in categorical data list: 0
# Helpdesk amount of numerical: 1
# Helpdesk dynamic numerical feature: event_elapsed_time, Index position in categorical data list: 1
# Helpdesk amount of numerical: 1
# Helpdesk dynamic numerical feature: day_in_week, Index position in categorical data list: 2
# Helpdesk amount of numerical: 1
# Helpdesk dynamic numerical feature: seconds_in_day, Index position in categorical data list: 3
# Helpdesk amount of numerical: 1
#
#
# Helpdesk static categorical feature: product, Index position in categorical data list: 0
# Helpdesk amount of category labels: 22
# Helpdesk static categorical feature: responsible_section, Index position in categorical data list: 1
# Helpdesk amount of category labels: 8
# Helpdesk static categorical feature: service_level, Index position in categorical data list: 2
# Helpdesk amount of category labels: 5
# Helpdesk static categorical feature: service_type, Index position in categorical data list: 3
# Helpdesk amount of category labels: 5
# Helpdesk static categorical feature: support_section, Index position in categorical data list: 4
# Helpdesk amount of category labels: 7
# Helpdesk static categorical feature: workgroup, Index position in categorical data list: 5
# Helpdesk amount of category labels: 5

# %% [markdown]
# ### Input Features for Encoder and Decoder

# %%
# Create lists with name of Encoder features (input) and decoder features (input & output)
# Encoder features:
enc_feat_cat = []
enc_feat_num = []
for cat in helpdesk_all_categories_cat:
    enc_feat_cat.append(cat[0])
for num in helpdesk_all_categories_num:
    enc_feat_num.append(num[0])
enc_feat = [enc_feat_cat, enc_feat_num]
print("Input features encoder: ", enc_feat)

# Static encoder features:
stat_enc_feat_cat = []
stat_enc_feat_num = []
for cat in helpdesk_all_stat_categories_cat:
    stat_enc_feat_cat.append(cat[0])
for num in helpdesk_all_stat_categories_num:
    stat_enc_feat_num.append(num[0])
stat_enc_feat = [stat_enc_feat_cat, stat_enc_feat_num]
print("Input features static encoder: ", stat_enc_feat)

# Decoder features:
dec_feat_cat = ['Activity', 'Resource']
dec_feat_num = ['case_elapsed_time', 'event_elapsed_time']
dec_feat = [dec_feat_cat, dec_feat_num]
print("Features decoder: ", dec_feat)
# Out:
# Input features encoder:  [['Activity', 'Resource'], ['case_elapsed_time', 'event_elapsed_time', 'day_in_week', 'seconds_in_day']]
# Input features static encoder:  [['product', 'responsible_section', 'service_level', 'service_type', 'support_section', 'workgroup'], []]
# Features decoder:  [['Activity', 'Resource'], ['case_elapsed_time', 'event_elapsed_time']]

# %% [markdown]
# # Model

# %%
import model.dropout_uncertainty_enc_dec_LSTM.dropout_uncertainty_model
importlib.reload(model.dropout_uncertainty_enc_dec_LSTM.dropout_uncertainty_model)
from model.dropout_uncertainty_enc_dec_LSTM.dropout_uncertainty_model import DropoutUncertaintyEncoderDecoderLSTM

# Prediction decoder output sequence length
seq_len_pred = helpdesk_train_dataset.min_suffix_size

# Size hidden layer
hidden_size = 128

# Number of cells
num_layers = 4

# Fixed Dropout probability 
dropout = 0.15
# dropout = 0.25

# Encoder Decoder model initialization
model = DropoutUncertaintyEncoderDecoderLSTM(data_set_categories=helpdesk_all_categories,
                                             enc_feat=enc_feat,
                                             dec_feat=dec_feat,
                                             seq_len_pred=seq_len_pred,
                                             hidden_size=hidden_size,
                                             num_layers=num_layers,
                                             dropout=dropout,
                                             # static attributes
                                             static_data_set_categories=helpdesk_all_stat_categories,
                                             static_enc_feat=stat_enc_feat)
# Out:
# Dynamic data set categories:  ([('Activity', 16, {'Assign seriousness': 1, 'Closed': 2, 'Create SW anomaly': 3, 'DUPLICATE': 4, 'EOS': 5, 'INVALID': 6, 'Insert ticket': 7, 'RESOLVED': 8, 'Require upgrade': 9, 'Resolve SW anomaly': 10, 'Resolve ticket': 11, 'Schedule intervention': 12, 'Take in charge ticket': 13, 'VERIFIED': 14, 'Wait': 15}), ('Resource', 24, {'EOS': 1, 'Value 1': 2, 'Value 10': 3, 'Value 11': 4, 'Value 12': 5, 'Value 13': 6, 'Value 14': 7, 'Value 15': 8, 'Value 16': 9, 'Value 17': 10, 'Value 18': 11, 'Value 19': 12, 'Value 2': 13, 'Value 20': 14, 'Value 21': 15, 'Value 22': 16, 'Value 3': 17, 'Value 4': 18, 'Value 5': 19, 'Value 6': 20, 'Value 7': 21, 'Value 8': 22, 'Value 9': 23})], [('case_elapsed_time', 1, {}), ('event_elapsed_time', 1, {}), ('day_in_week', 1, {}), ('seconds_in_day', 1, {})])
# Data set static categories:  ([('product', 22, {'Value 1': 1, 'Value 10': 2, 'Value 11': 3, 'Value 12': 4, 'Value 13': 5, 'Value 14': 6, 'Value 15': 7, 'Value 16': 8, 'Value 17': 9, 'Value 18': 10, 'Value 19': 11, 'Value 2': 12, 'Value 20': 13, 'Value 21': 14, 'Value 3': 15, 'Value 4': 16, 'Value 5': 17, 'Value 6': 18, 'Value 7': 19, 'Value 8': 20, 'Value 9': 21}), ('responsible_section', 8, {'Value 1': 1, 'Value 2': 2, 'Value 3': 3, 'Value 4': 4, 'Value 5': 5, 'Value 6': 6, 'Value 7': 7}), ('service_level', 5, {'Value 1': 1, 'Value 2': 2, 'Value 3': 3, 'Value 4': 4}), ('service_type', 5, {'Value 1': 1, 'Value 2': 2, 'Value 3': 3, 'Value 4': 4}), ('support_section', 7, {'Value 1': 1, 'Value 2': 2, 'Value 3': 3, 'Value 4': 4, 'Value 5': 5, 'Value 6': 6}), ('workgroup', 5, {'Value 1': 1, 'Value 2': 2, 'Value 3': 3, 'Value 4': 4})], [])
# Encoder dynamic input features:  [['Activity', 'Resource'], ['case_elapsed_time', 'event_elapsed_time', 'day_in_week', 'seconds_in_day']]
# Encoder static input features:  [['product', 'responsible_section', 'service_level', 'service_type', 'support_section', 'workgroup'], []]
# Decoder input and output features:  [['Activity', 'Resource'], ['case_elapsed_time', 'event_elapsed_time']]
# Sequence length of decoder output:  5
#
#
# LSTM cells and FC hidden size:  128
# Number of LSTM layer:  4
# Dropout rate:  0.15
#
#
# Encoder dynamic:
# Encoder number of labels for each input feature (categorical, numerical):  [[16, 24], [1, 1, 1, 1]]
# Encoder indices of tensors in dataset used as input:  [[0, 1], [0, 1, 2, 3]]
# Embeddings encoder:  ModuleList(
#   (0): Embedding(16, 8)
#   (1): Embedding(24, 9)
# )
# Total embedding feature size encoder:  17
# Total numerical feature size encoder:  4
# Input feature size encoder:  21
#
#
# Encoder static:
# Encoder number of labels for each input feature (categorical, numerical):  [[22, 8, 5, 5, 7, 5], []]
# Encoder indices of tensors in dataset used as input (static):  [[0, 1, 2, 3, 4, 5], []]
# Static encoder categorical embeddings:  ModuleList(
#   (0): Embedding(22, 9)
#   (1): Embedding(8, 5)
#   (2-3): 2 x Embedding(5, 4)
#   (4): Embedding(7, 5)
#   (5): Embedding(5, 4)
# )
# Total embedding feature size encoder (static):  31
# Total numerical feature size encoder (static):  0
# Static encoder feature size:  31
# Encoder initialized!
#
# Decoder label values size for each categorical input feature:  [16, 24]
# Decoder label values size for each numerical input feature:  [1, 1]
# Decoder indices of tensors in dataset used as input:  [[0, 1], [0, 1]]
# Embeddings decoder:  ModuleList(
#   (0): Embedding(16, 8)
#   (1): Embedding(24, 9)
# )
# Total embedding feature size decoder:  17
# Total numerical feature size decoder:  2
# Input feature size decoder:  19
# Output feature list of dicts (featue name, feature output size) of decoder:  [{'Activity': 16, 'Resource': 24}, {'case_elapsed_time': 1, 'event_elapsed_time': 1}]
# Decoder initialized!

# %% [markdown]
# # Loss Object Creation

# %%
import loss.losses
importlib.reload(loss.losses)
from loss.losses import Loss

loss_obj = Loss()

# %% [markdown]
# # Training Configuration

# %%
import trainer.trainer
importlib.reload(trainer.trainer)
from trainer.trainer import Trainer
from torch.optim.lr_scheduler import ReduceLROnPlateau

from torch.utils.tensorboard import SummaryWriter

writer = SummaryWriter(comment="Full_Helpdesk_grad")

# device
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
# device = torch.device("cpu")

# Start learning rate
learning_rate = 1e-5
# weight_decay = 5e-4
weight_decay = 0

# Optimizer and Scheduler
optimizer = torch.optim.AdamW(params=model.parameters(), lr=learning_rate, weight_decay=weight_decay)
scheduler = ReduceLROnPlateau(optimizer, mode='min', factor=0.1, patience=5, min_lr=1e-10)

# Epochs
num_epochs = 100

# Batches
batch_size = 64

# lambda for L2 (weight, bias, dropout) regularization: According to formula: 1/2N
# regularization_term = 1.0/(2.0*batch_size)
regularization_term = 1e-4

# shuffle data
shuffle = True

min_teacher_forcing_ratio = 0.0

optimize_values = {"regularization_term":regularization_term,
                   "optimizer":optimizer,
                   "scheduler": scheduler,
                   "epochs":num_epochs,
                   "mini_batches":batch_size,
                   "shuffle": shuffle,
                   "min_teacher_forcing_ratio":min_teacher_forcing_ratio,}

suffix_data_split_value = helpdesk_train_dataset.min_suffix_size
print("Train seq length: ", suffix_data_split_value)

# GradNorm parameter
use_gradnorm = True
# Grdanorm hyperparams
gn_alpha = 1.0
gn_learning_rate = 1e-4

number_tasks = len(dec_feat[0]) + len(dec_feat[1])

gradNorm = {"use_gradnorm":use_gradnorm,
            "number_tasks": number_tasks,
            "gn_alpha":gn_alpha,
            "gn_learning_rate": gn_learning_rate}

trainer = Trainer(device=device,
                  model=model,
                  data_train=helpdesk_train_dataset,
                  data_val=helpdesk_val_dataset,
                  loss_obj=loss_obj,
                  log_normal_loss_num_feature = [],
                  optimize_values=optimize_values,
                  suffix_data_split_value=suffix_data_split_value,
                  writer=writer,
                  gradnorm_values=gradNorm,
                  save_model_n_th_epoch = 1,
                  saving_path = 'Helpdesk_full_grad_norm_new_v2.pkl')

# Train the model:
train_attenuated_losses, val_losses, val_attenuated_losses = trainer.train_model()
# Out:
# Train seq length:  5
# Device:  cuda
# Model:  DropoutUncertaintyEncoderDecoderLSTM(
#   (embeddings_enc): ModuleList(
#     (0): Embedding(16, 8)
#     (1): Embedding(24, 9)
#   )
#   (embeddings_static_enc): ModuleList(
#     (0): Embedding(22, 9)
#     (1): Embedding(8, 5)
#     (2-3): 2 x Embedding(5, 4)
#     (4): Embedding(7, 5)
#     (5): Embedding(5, 4)
#   )
#   (encoder): DropoutUncertaintyLSTMEncoder(
#     (embeddings): ModuleList(
#       (0): Embedding(16, 8)
#       (1): Embedding(24, 9)
#     )
#     (static_embeddings): ModuleList(
#       (0): Embedding(22, 9)
#       (1): Embedding(8, 5)
#       (2-3): 2 x Embedding(5, 4)
#       (4): Embedding(7, 5)
#       (5): Embedding(5, 4)
#     )
#     (static_fc): Sequential(
#       (0): Linear(in_features=31, out_features=128, bias=True)
#       (1): ReLU()
#     )
#     (static_merger): Linear(in_features=256, out_features=128, bias=True)
#     (input_proj): Linear(in_features=21, out_features=128, bias=True)
#     (first_layer): DropoutUncertaintyLSTMCell(
#       (Wi): Linear(in_features=128, out_features=128, bias=True)
#       (Ui): Linear(in_features=128, out_features=128, bias=True)
#       (Wf): Linear(in_features=128, out_features=128, bias=True)
#       (Uf): Linear(in_features=128, out_features=128, bias=True)
#       (Wc): Linear(in_features=128, out_features=128, bias=True)
#       (Uc): Linear(in_features=128, out_features=128, bias=True)
#       (Wo): Linear(in_features=128, out_features=128, bias=True)
#       (Uo): Linear(in_features=128, out_features=128, bias=True)
#     )
#     (hidden_layers): ModuleList(
#       (0-2): 3 x DropoutUncertaintyLSTMCell(
#         (Wi): Linear(in_features=128, out_features=128, bias=True)
#         (Ui): Linear(in_features=128, out_features=128, bias=True)
#         (Wf): Linear(in_features=128, out_features=128, bias=True)
#         (Uf): Linear(in_features=128, out_features=128, bias=True)
#         (Wc): Linear(in_features=128, out_features=128, bias=True)
#         (Uc): Linear(in_features=128, out_features=128, bias=True)
#         (Wo): Linear(in_features=128, out_features=128, bias=True)
#         (Uo): Linear(in_features=128, out_features=128, bias=True)
#       )
#     )
#   )
#   (embeddings_dec): ModuleList(
#     (0): Embedding(16, 8)
#     (1): Embedding(24, 9)
#   )
#   (decoder): DropoutUncertaintyLSTMDecoder(
#     (embeddings): ModuleList(
#       (0): Embedding(16, 8)
#       (1): Embedding(24, 9)
#     )
#     (input_proj): Linear(in_features=19, out_features=128, bias=True)
#     (first_layer): DropoutUncertaintyLSTMCell(
#       (Wi): Linear(in_features=128, out_features=128, bias=True)
#       (Ui): Linear(in_features=128, out_features=128, bias=True)
#       (Wf): Linear(in_features=128, out_features=128, bias=True)
#       (Uf): Linear(in_features=128, out_features=128, bias=True)
#       (Wc): Linear(in_features=128, out_features=128, bias=True)
#       (Uc): Linear(in_features=128, out_features=128, bias=True)
#       (Wo): Linear(in_features=128, out_features=128, bias=True)
#       (Uo): Linear(in_features=128, out_features=128, bias=True)
#     )
#     (hidden_layers): ModuleList(
#       (0-2): 3 x DropoutUncertaintyLSTMCell(
#         (Wi): Linear(in_features=128, out_features=128, bias=True)
#         (Ui): Linear(in_features=128, out_features=128, bias=True)
#         (Wf): Linear(in_features=128, out_features=128, bias=True)
#         (Uf): Linear(in_features=128, out_features=128, bias=True)
#         (Wc): Linear(in_features=128, out_features=128, bias=True)
#         (Uc): Linear(in_features=128, out_features=128, bias=True)
#         (Wo): Linear(in_features=128, out_features=128, bias=True)
#         (Uo): Linear(in_features=128, out_features=128, bias=True)
#       )
#     )
#     (output_layers): ModuleDict(
#       (Activity_mean): Linear(in_features=128, out_features=16, bias=True)
#       (Activity_var): Linear(in_features=128, out_features=16, bias=True)
#       (Resource_mean): Linear(in_features=128, out_features=24, bias=True)
#       (Resource_var): Linear(in_features=128, out_features=24, bias=True)
#       (case_elapsed_time_mean): Linear(in_features=128, out_features=1, bias=True)
#       (case_elapsed_time_var): Linear(in_features=128, out_features=1, bias=True)
#       (event_elapsed_time_mean): Linear(in_features=128, out_features=1, bias=True)
#       (event_elapsed_time_var): Linear(in_features=128, out_features=1, bias=True)
#     )
#   )
# )
# Train Dataset:  <event_log_loader.new_event_log_loader_v2.EventLogDataset object at 0x7f284420e900>
# Validation Dataset:  <event_log_loader.new_event_log_loader_v2.EventLogDataset object at 0x7f2704b62060>
# Loss object for method calling:  <loss.losses.Loss object at 0x7f26ffb12660>
# Num. feautures that follow log-normal PDF:  []
# regularization:  0.0001
# Optimizer:  AdamW (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     capturable: False
#     decoupled_weight_decay: True
#     differentiable: False
#     eps: 1e-08
#     foreach: None
#     fused: None
#     lr: 1e-05
#     maximize: False
#     weight_decay: 0
# )
# Scheduler:  <torch.optim.lr_scheduler.ReduceLROnPlateau object at 0x7f26f6d31a90>
# Epochs:  100
# Mini baches:  64
# Shuffle batched dataset:  True
# Min. Teacher forcing ratio:  0.0
# Use GradNorm:  True
# GradNorm alpha:  1.0
# GradNorm learning rate:  0.0001
# Initial GradNorm loss weights:  Parameter containing:
# tensor([1., 1., 1., 1.], device='cuda:0', requires_grad=True)
# Initial loss values:  None
# GradNorm optimizer:  AdamW (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     capturable: False
#     decoupled_weight_decay: True
#     differentiable: False
#     eps: 1e-08
#     foreach: None
#     fused: None
#     lr: 0.0001
#     maximize: False
#     weight_decay: 0.01
# )
# Epoch [1/100], Learning Rate: 1e-05, Teacher forcing ratio: 1.0
# Training: Avg Attenuated Training Loss: 9.2984
# Validation: Avg Standard Validation Loss: 9.8831
# Validation: Avg Attenuated Validation Loss: 8.8449
# Validation Loss for Scheduler: 9.8831
# saving model
# Epoch [2/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.98
# Training: Avg Attenuated Training Loss: 9.1275
# Validation: Avg Standard Validation Loss: 9.6086
# Validation: Avg Attenuated Validation Loss: 8.5830
# Validation Loss for Scheduler: 9.6086
# saving model
# Epoch [3/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.96
# Training: Avg Attenuated Training Loss: 8.2973
# Validation: Avg Standard Validation Loss: 8.8820
# Validation: Avg Attenuated Validation Loss: 7.5749
# Validation Loss for Scheduler: 8.8820
# saving model
# Epoch [4/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.94
# Training: Avg Attenuated Training Loss: 6.9756
# Validation: Avg Standard Validation Loss: 7.9676
# Validation: Avg Attenuated Validation Loss: 6.5544
# Validation Loss for Scheduler: 7.9676
# saving model
# Epoch [5/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.92
# Training: Avg Attenuated Training Loss: 5.9080
# Validation: Avg Standard Validation Loss: 7.3727
# Validation: Avg Attenuated Validation Loss: 5.8959
# Validation Loss for Scheduler: 7.3727
# saving model
# Epoch [6/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.9
# Training: Avg Attenuated Training Loss: 5.1308
# Validation: Avg Standard Validation Loss: 6.9397
# Validation: Avg Attenuated Validation Loss: 5.5761
# Validation Loss for Scheduler: 6.9397
# saving model
# Epoch [7/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.88
# Training: Avg Attenuated Training Loss: 4.6536
# Validation: Avg Standard Validation Loss: 6.8273
# Validation: Avg Attenuated Validation Loss: 5.5713
# Validation Loss for Scheduler: 6.8273
# saving model
# Epoch [8/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.86
# Training: Avg Attenuated Training Loss: 4.2769
# Validation: Avg Standard Validation Loss: 6.0893
# Validation: Avg Attenuated Validation Loss: 4.8917
# Validation Loss for Scheduler: 6.0893
# saving model
# Epoch [9/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.84
# Training: Avg Attenuated Training Loss: 3.8392
# Validation: Avg Standard Validation Loss: 5.5969
# Validation: Avg Attenuated Validation Loss: 4.5878
# Validation Loss for Scheduler: 5.5969
# saving model
# Epoch [10/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.8200000000000001
# Training: Avg Attenuated Training Loss: 3.5370
# Validation: Avg Standard Validation Loss: 5.5170
# Validation: Avg Attenuated Validation Loss: 4.6997
# Validation Loss for Scheduler: 5.5170
# saving model
# Epoch [11/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.8
# Training: Avg Attenuated Training Loss: 3.3114
# Validation: Avg Standard Validation Loss: 5.4059
# Validation: Avg Attenuated Validation Loss: 4.9492
# Validation Loss for Scheduler: 5.4059
# saving model
# Epoch [12/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.78
# Training: Avg Attenuated Training Loss: 3.2001
# Validation: Avg Standard Validation Loss: 5.3610
# Validation: Avg Attenuated Validation Loss: 5.0072
# Validation Loss for Scheduler: 5.3610
# saving model
# Epoch [13/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.76
# Training: Avg Attenuated Training Loss: 3.2222
# Validation: Avg Standard Validation Loss: 5.2744
# Validation: Avg Attenuated Validation Loss: 4.6079
# Validation Loss for Scheduler: 5.2744
# saving model
# Epoch [14/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.74
# Training: Avg Attenuated Training Loss: 3.0927
# Validation: Avg Standard Validation Loss: 5.1843
# Validation: Avg Attenuated Validation Loss: 4.6858
# Validation Loss for Scheduler: 5.1843
# saving model
# Epoch [15/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.72
# Training: Avg Attenuated Training Loss: 3.0010
# Validation: Avg Standard Validation Loss: 5.2390
# Validation: Avg Attenuated Validation Loss: 4.8578
# Validation Loss for Scheduler: 5.2390
# saving model
# Epoch [16/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.7
# Training: Avg Attenuated Training Loss: 3.0500
# Validation: Avg Standard Validation Loss: 5.2648
# Validation: Avg Attenuated Validation Loss: 4.8011
# Validation Loss for Scheduler: 5.2648
# saving model
# Epoch [17/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.6799999999999999
# Training: Avg Attenuated Training Loss: 3.0701
# Validation: Avg Standard Validation Loss: 4.9318
# Validation: Avg Attenuated Validation Loss: 4.3730
# Validation Loss for Scheduler: 4.9318
# saving model
# Epoch [18/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.6599999999999999
# Training: Avg Attenuated Training Loss: 3.0300
# Validation: Avg Standard Validation Loss: 5.0361
# Validation: Avg Attenuated Validation Loss: 4.5561
# Validation Loss for Scheduler: 5.0361
# saving model
# Epoch [19/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.64
# Training: Avg Attenuated Training Loss: 2.8990
# Validation: Avg Standard Validation Loss: 5.0156
# Validation: Avg Attenuated Validation Loss: 4.7275
# Validation Loss for Scheduler: 5.0156
# saving model
# Epoch [20/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.62
# Training: Avg Attenuated Training Loss: 2.9826
# Validation: Avg Standard Validation Loss: 5.0726
# Validation: Avg Attenuated Validation Loss: 4.3520
# Validation Loss for Scheduler: 5.0726
# saving model
# Epoch [21/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.6
# Training: Avg Attenuated Training Loss: 3.0047
# Validation: Avg Standard Validation Loss: 4.9071
# Validation: Avg Attenuated Validation Loss: 4.2382
# Validation Loss for Scheduler: 4.9071
# saving model
# Epoch [22/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.5800000000000001
# Training: Avg Attenuated Training Loss: 3.0220
# Validation: Avg Standard Validation Loss: 4.8905
# Validation: Avg Attenuated Validation Loss: 4.0563
# Validation Loss for Scheduler: 4.8905
# saving model
# Epoch [23/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.56
# Training: Avg Attenuated Training Loss: 2.9442
# Validation: Avg Standard Validation Loss: 4.7035
# Validation: Avg Attenuated Validation Loss: 3.7624
# Validation Loss for Scheduler: 4.7035
# saving model
# Epoch [24/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.54
# Training: Avg Attenuated Training Loss: 3.0305
# Validation: Avg Standard Validation Loss: 4.8542
# Validation: Avg Attenuated Validation Loss: 3.6809
# Validation Loss for Scheduler: 4.8542
# saving model
# Epoch [25/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.52
# Training: Avg Attenuated Training Loss: 2.9860
# Validation: Avg Standard Validation Loss: 4.7099
# Validation: Avg Attenuated Validation Loss: 3.6218
# Validation Loss for Scheduler: 4.7099
# saving model
# Epoch [26/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.5
# Training: Avg Attenuated Training Loss: 3.0161
# Validation: Avg Standard Validation Loss: 4.6838
# Validation: Avg Attenuated Validation Loss: 3.5478
# Validation Loss for Scheduler: 4.6838
# saving model
# Epoch [27/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.48
# Training: Avg Attenuated Training Loss: 3.0686
# Validation: Avg Standard Validation Loss: 4.7518
# Validation: Avg Attenuated Validation Loss: 3.5331
# Validation Loss for Scheduler: 4.7518
# saving model
# Epoch [28/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.45999999999999996
# Training: Avg Attenuated Training Loss: 3.0209
# Validation: Avg Standard Validation Loss: 4.7376
# Validation: Avg Attenuated Validation Loss: 3.4577
# Validation Loss for Scheduler: 4.7376
# saving model
# Epoch [29/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.43999999999999995
# Training: Avg Attenuated Training Loss: 3.0229
# Validation: Avg Standard Validation Loss: 4.7139
# Validation: Avg Attenuated Validation Loss: 3.4869
# Validation Loss for Scheduler: 4.7139
# saving model
# Epoch [30/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.42000000000000004
# Training: Avg Attenuated Training Loss: 3.0126
# Validation: Avg Standard Validation Loss: 4.8125
# Validation: Avg Attenuated Validation Loss: 3.4768
# Validation Loss for Scheduler: 4.8125
# saving model
# Epoch [31/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.4
# Training: Avg Attenuated Training Loss: 3.0512
# Validation: Avg Standard Validation Loss: 4.8479
# Validation: Avg Attenuated Validation Loss: 3.4803
# Validation Loss for Scheduler: 4.8479
# saving model
# Epoch [32/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.38
# Training: Avg Attenuated Training Loss: 3.0772
# Validation: Avg Standard Validation Loss: 4.9467
# Validation: Avg Attenuated Validation Loss: 3.5403
# Validation Loss for Scheduler: 4.9467
# saving model
# Epoch [33/100], Learning Rate: 1.0000000000000002e-06, Teacher forcing ratio: 0.36
# Training: Avg Attenuated Training Loss: 3.0784
# Validation: Avg Standard Validation Loss: 4.9441
# Validation: Avg Attenuated Validation Loss: 3.5639
# Validation Loss for Scheduler: 4.9441
# saving model
# Epoch [34/100], Learning Rate: 1.0000000000000002e-06, Teacher forcing ratio: 0.33999999999999997
# Training: Avg Attenuated Training Loss: 3.0943
# Validation: Avg Standard Validation Loss: 4.8388
# Validation: Avg Attenuated Validation Loss: 3.4774
# Validation Loss for Scheduler: 4.8388
# saving model
# Epoch [35/100], Learning Rate: 1.0000000000000002e-06, Teacher forcing ratio: 0.31999999999999995
# Training: Avg Attenuated Training Loss: 3.1623
# Validation: Avg Standard Validation Loss: 4.9006
# Validation: Avg Attenuated Validation Loss: 3.5085
# Validation Loss for Scheduler: 4.9006
# saving model
# Epoch [36/100], Learning Rate: 1.0000000000000002e-06, Teacher forcing ratio: 0.30000000000000004
# Training: Avg Attenuated Training Loss: 3.1693
# Validation: Avg Standard Validation Loss: 4.9073
# Validation: Avg Attenuated Validation Loss: 3.4697
# Validation Loss for Scheduler: 4.9073
# saving model
# Epoch [37/100], Learning Rate: 1.0000000000000002e-06, Teacher forcing ratio: 0.28
# Training: Avg Attenuated Training Loss: 3.2000
# Validation: Avg Standard Validation Loss: 4.9054
# Validation: Avg Attenuated Validation Loss: 3.4979
# Validation Loss for Scheduler: 4.9054
# saving model
# Epoch [38/100], Learning Rate: 1.0000000000000002e-06, Teacher forcing ratio: 0.26
# Training: Avg Attenuated Training Loss: 3.2324
# Validation: Avg Standard Validation Loss: 4.9081
# Validation: Avg Attenuated Validation Loss: 3.4632
# Validation Loss for Scheduler: 4.9081
# saving model
# Epoch [39/100], Learning Rate: 1.0000000000000002e-07, Teacher forcing ratio: 0.24
# Training: Avg Attenuated Training Loss: 3.2659
# Validation: Avg Standard Validation Loss: 5.0550
# Validation: Avg Attenuated Validation Loss: 3.5798
# Validation Loss for Scheduler: 5.0550
# saving model
# Epoch [40/100], Learning Rate: 1.0000000000000002e-07, Teacher forcing ratio: 0.21999999999999997
# Training: Avg Attenuated Training Loss: 3.2874
# Validation: Avg Standard Validation Loss: 4.9658
# Validation: Avg Attenuated Validation Loss: 3.5544
# Validation Loss for Scheduler: 4.9658
# saving model
# Epoch [41/100], Learning Rate: 1.0000000000000002e-07, Teacher forcing ratio: 0.19999999999999996
# Training: Avg Attenuated Training Loss: 3.3453
# Validation: Avg Standard Validation Loss: 4.9861
# Validation: Avg Attenuated Validation Loss: 3.5338
# Validation Loss for Scheduler: 4.9861
# saving model
# Epoch [42/100], Learning Rate: 1.0000000000000002e-07, Teacher forcing ratio: 0.18000000000000005
# Training: Avg Attenuated Training Loss: 3.3803
# Validation: Avg Standard Validation Loss: 5.0014
# Validation: Avg Attenuated Validation Loss: 3.5653
# Validation Loss for Scheduler: 5.0014
# saving model
# Epoch [43/100], Learning Rate: 1.0000000000000002e-07, Teacher forcing ratio: 0.16000000000000003
# Training: Avg Attenuated Training Loss: 3.4193
# Validation: Avg Standard Validation Loss: 4.9942
# Validation: Avg Attenuated Validation Loss: 3.5532
# Validation Loss for Scheduler: 4.9942
# saving model
# Epoch [44/100], Learning Rate: 1.0000000000000002e-07, Teacher forcing ratio: 0.14
# Training: Avg Attenuated Training Loss: 3.4432
# Validation: Avg Standard Validation Loss: 4.9497
# Validation: Avg Attenuated Validation Loss: 3.5098
# Validation Loss for Scheduler: 4.9497
# saving model
# Epoch [45/100], Learning Rate: 1.0000000000000004e-08, Teacher forcing ratio: 0.12
# Training: Avg Attenuated Training Loss: 3.4354
# Validation: Avg Standard Validation Loss: 5.0294
# Validation: Avg Attenuated Validation Loss: 3.6117
# Validation Loss for Scheduler: 5.0294
# saving model
# Epoch [46/100], Learning Rate: 1.0000000000000004e-08, Teacher forcing ratio: 0.09999999999999998
# Training: Avg Attenuated Training Loss: 3.5542
# Validation: Avg Standard Validation Loss: 4.9929
# Validation: Avg Attenuated Validation Loss: 3.5701
# Validation Loss for Scheduler: 4.9929
# saving model
# Epoch [47/100], Learning Rate: 1.0000000000000004e-08, Teacher forcing ratio: 0.07999999999999996
# Training: Avg Attenuated Training Loss: 3.5846
# Validation: Avg Standard Validation Loss: 5.0302
# Validation: Avg Attenuated Validation Loss: 3.5796
# Validation Loss for Scheduler: 5.0302
# saving model
# Epoch [48/100], Learning Rate: 1.0000000000000004e-08, Teacher forcing ratio: 0.06000000000000005
# Training: Avg Attenuated Training Loss: 3.5941
# Validation: Avg Standard Validation Loss: 5.1157
# Validation: Avg Attenuated Validation Loss: 3.6872
# Validation Loss for Scheduler: 5.1157
# saving model
# Epoch [49/100], Learning Rate: 1.0000000000000004e-08, Teacher forcing ratio: 0.040000000000000036
# Training: Avg Attenuated Training Loss: 3.6324
# Validation: Avg Standard Validation Loss: 4.8973
# Validation: Avg Attenuated Validation Loss: 3.4801
# Validation Loss for Scheduler: 4.8973
# saving model
# Epoch [50/100], Learning Rate: 1.0000000000000004e-08, Teacher forcing ratio: 0.020000000000000018
# Training: Avg Attenuated Training Loss: 3.6824
# Validation: Avg Standard Validation Loss: 4.9767
# Validation: Avg Attenuated Validation Loss: 3.5456
# Validation Loss for Scheduler: 4.9767
# saving model
# Epoch [51/100], Learning Rate: 1.0000000000000004e-08, Teacher forcing ratio: 0.0
# Training: Avg Attenuated Training Loss: 3.7095
# Validation: Avg Standard Validation Loss: 5.0931
# Validation: Avg Attenuated Validation Loss: 3.6674
# Validation Loss for Scheduler: 5.0931
# saving model
# Epoch [52/100], Learning Rate: 1.0000000000000004e-08, Teacher forcing ratio: 0.0
# Training: Avg Attenuated Training Loss: 3.7289
# Validation: Avg Standard Validation Loss: 5.0063
# Validation: Avg Attenuated Validation Loss: 3.5758
# Validation Loss for Scheduler: 5.0063
# saving model
# Epoch [53/100], Learning Rate: 1.0000000000000004e-08, Teacher forcing ratio: 0.0
# Training: Avg Attenuated Training Loss: 3.7434
# Validation: Avg Standard Validation Loss: 5.0169
# Validation: Avg Attenuated Validation Loss: 3.5831
# Validation Loss for Scheduler: 5.0169
# saving model
# Epoch [54/100], Learning Rate: 1.0000000000000004e-08, Teacher forcing ratio: 0.0
# Training: Avg Attenuated Training Loss: 3.7509
# Validation: Avg Standard Validation Loss: 4.9815
# Validation: Avg Attenuated Validation Loss: 3.5665
# Validation Loss for Scheduler: 4.9815
# saving model
# Epoch [55/100], Learning Rate: 1.0000000000000004e-08, Teacher forcing ratio: 0.0
# Training: Avg Attenuated Training Loss: 3.7546
# Validation: Avg Standard Validation Loss: 5.0242
# Validation: Avg Attenuated Validation Loss: 3.5776
# Validation Loss for Scheduler: 5.0242
# saving model
# Epoch [56/100], Learning Rate: 1.0000000000000004e-08, Teacher forcing ratio: 0.0
# Training: Avg Attenuated Training Loss: 3.7522
# Validation: Avg Standard Validation Loss: 5.0411
# Validation: Avg Attenuated Validation Loss: 3.6121
# Validation Loss for Scheduler: 5.0411
# saving model
# Epoch [57/100], Learning Rate: 1.0000000000000004e-08, Teacher forcing ratio: 0.0
# Training: Avg Attenuated Training Loss: 3.7820
# Validation: Avg Standard Validation Loss: 5.0547
# Validation: Avg Attenuated Validation Loss: 3.6041
# Validation Loss for Scheduler: 5.0547
# saving model
# Epoch [58/100], Learning Rate: 1.0000000000000004e-08, Teacher forcing ratio: 0.0
# Training: Avg Attenuated Training Loss: 3.7857
# Validation: Avg Standard Validation Loss: 4.9708
# Validation: Avg Attenuated Validation Loss: 3.5457
# Validation Loss for Scheduler: 4.9708
# saving model
# Epoch [59/100], Learning Rate: 1.0000000000000004e-08, Teacher forcing ratio: 0.0
# Training: Avg Attenuated Training Loss: 3.7977
# Validation: Avg Standard Validation Loss: 5.0554
# Validation: Avg Attenuated Validation Loss: 3.6039
# Validation Loss for Scheduler: 5.0554
# saving model
# Epoch [60/100], Learning Rate: 1.0000000000000004e-08, Teacher forcing ratio: 0.0
# Training: Avg Attenuated Training Loss: 3.8015
# Validation: Avg Standard Validation Loss: 5.0875
# Validation: Avg Attenuated Validation Loss: 3.6805
# Validation Loss for Scheduler: 5.0875
# saving model
# Epoch [61/100], Learning Rate: 1.0000000000000004e-08, Teacher forcing ratio: 0.0
# Training: Avg Attenuated Training Loss: 3.8179
# Validation: Avg Standard Validation Loss: 5.0441
# Validation: Avg Attenuated Validation Loss: 3.5603
# Validation Loss for Scheduler: 5.0441
# saving model
# Epoch [62/100], Learning Rate: 1.0000000000000004e-08, Teacher forcing ratio: 0.0
# Training: Avg Attenuated Training Loss: 3.8300
# Validation: Avg Standard Validation Loss: 5.0818
# Validation: Avg Attenuated Validation Loss: 3.6402
# Validation Loss for Scheduler: 5.0818
# saving model
# Epoch [63/100], Learning Rate: 1.0000000000000004e-08, Teacher forcing ratio: 0.0
# Training: Avg Attenuated Training Loss: 3.8340
# Validation: Avg Standard Validation Loss: 4.9841
# Validation: Avg Attenuated Validation Loss: 3.5439
# Validation Loss for Scheduler: 4.9841
# saving model
# Epoch [64/100], Learning Rate: 1.0000000000000004e-08, Teacher forcing ratio: 0.0
# Training: Avg Attenuated Training Loss: 3.8414
# Validation: Avg Standard Validation Loss: 5.0674
# Validation: Avg Attenuated Validation Loss: 3.6278
# Validation Loss for Scheduler: 5.0674
# saving model
# Epoch [65/100], Learning Rate: 1.0000000000000004e-08, Teacher forcing ratio: 0.0
# Training: Avg Attenuated Training Loss: 3.8664
# Validation: Avg Standard Validation Loss: 4.9716
# Validation: Avg Attenuated Validation Loss: 3.5148
# Validation Loss for Scheduler: 4.9716
# saving model
# Epoch [66/100], Learning Rate: 1.0000000000000004e-08, Teacher forcing ratio: 0.0
# Training: Avg Attenuated Training Loss: 3.8711
# Validation: Avg Standard Validation Loss: 5.0082
# Validation: Avg Attenuated Validation Loss: 3.5625
# Validation Loss for Scheduler: 5.0082
# saving model
# Epoch [67/100], Learning Rate: 1.0000000000000004e-08, Teacher forcing ratio: 0.0
# Training: Avg Attenuated Training Loss: 3.8720
# Validation: Avg Standard Validation Loss: 5.0123
# Validation: Avg Attenuated Validation Loss: 3.5979
# Validation Loss for Scheduler: 5.0123
# saving model
# Epoch [68/100], Learning Rate: 1.0000000000000004e-08, Teacher forcing ratio: 0.0
# Training: Avg Attenuated Training Loss: 3.8895
# Validation: Avg Standard Validation Loss: 4.9443
# Validation: Avg Attenuated Validation Loss: 3.5074
# Validation Loss for Scheduler: 4.9443
# saving model
# Epoch [69/100], Learning Rate: 1.0000000000000004e-08, Teacher forcing ratio: 0.0
# Training: Avg Attenuated Training Loss: 3.8923
# Validation: Avg Standard Validation Loss: 5.0322
# Validation: Avg Attenuated Validation Loss: 3.5633
# Validation Loss for Scheduler: 5.0322
# saving model
# Epoch [70/100], Learning Rate: 1.0000000000000004e-08, Teacher forcing ratio: 0.0
# Training: Avg Attenuated Training Loss: 3.8862
# Validation: Avg Standard Validation Loss: 5.0562
# Validation: Avg Attenuated Validation Loss: 3.6066
# Validation Loss for Scheduler: 5.0562
# saving model
# Epoch [71/100], Learning Rate: 1.0000000000000004e-08, Teacher forcing ratio: 0.0
# Training: Avg Attenuated Training Loss: 3.9106
# Validation: Avg Standard Validation Loss: 5.0135
# Validation: Avg Attenuated Validation Loss: 3.5895
# Validation Loss for Scheduler: 5.0135
# saving model
# Epoch [72/100], Learning Rate: 1.0000000000000004e-08, Teacher forcing ratio: 0.0
# Training: Avg Attenuated Training Loss: 3.9147
# Validation: Avg Standard Validation Loss: 4.9834
# Validation: Avg Attenuated Validation Loss: 3.5640
# Validation Loss for Scheduler: 4.9834
# saving model
# Epoch [73/100], Learning Rate: 1.0000000000000004e-08, Teacher forcing ratio: 0.0
# Training: Avg Attenuated Training Loss: 3.9148
# Validation: Avg Standard Validation Loss: 4.9663
# Validation: Avg Attenuated Validation Loss: 3.5263
# Validation Loss for Scheduler: 4.9663
# saving model
# Epoch [74/100], Learning Rate: 1.0000000000000004e-08, Teacher forcing ratio: 0.0
# Training: Avg Attenuated Training Loss: 3.9291
# Validation: Avg Standard Validation Loss: 4.9784
# Validation: Avg Attenuated Validation Loss: 3.5651
# Validation Loss for Scheduler: 4.9784
# saving model
# Epoch [75/100], Learning Rate: 1.0000000000000004e-08, Teacher forcing ratio: 0.0
# Training: Avg Attenuated Training Loss: 3.9411
# Validation: Avg Standard Validation Loss: 4.9556
# Validation: Avg Attenuated Validation Loss: 3.5404
# Validation Loss for Scheduler: 4.9556
# saving model
# Epoch [76/100], Learning Rate: 1.0000000000000004e-08, Teacher forcing ratio: 0.0
# Training: Avg Attenuated Training Loss: 3.9374
# Validation: Avg Standard Validation Loss: 4.9959
# Validation: Avg Attenuated Validation Loss: 3.5810
# Validation Loss for Scheduler: 4.9959
# saving model
# Epoch [77/100], Learning Rate: 1.0000000000000004e-08, Teacher forcing ratio: 0.0
# Training: Avg Attenuated Training Loss: 3.9499
# Validation: Avg Standard Validation Loss: 5.0762
# Validation: Avg Attenuated Validation Loss: 3.6018
# Validation Loss for Scheduler: 5.0762
# saving model
# Epoch [78/100], Learning Rate: 1.0000000000000004e-08, Teacher forcing ratio: 0.0
# Training: Avg Attenuated Training Loss: 3.9566
# Validation: Avg Standard Validation Loss: 5.0171
# Validation: Avg Attenuated Validation Loss: 3.5446
# Validation Loss for Scheduler: 5.0171
# saving model
# Epoch [79/100], Learning Rate: 1.0000000000000004e-08, Teacher forcing ratio: 0.0
# Training: Avg Attenuated Training Loss: 3.9662
# Validation: Avg Standard Validation Loss: 4.9620
# Validation: Avg Attenuated Validation Loss: 3.5139
# Validation Loss for Scheduler: 4.9620
# saving model
# Epoch [80/100], Learning Rate: 1.0000000000000004e-08, Teacher forcing ratio: 0.0
# Training: Avg Attenuated Training Loss: 3.9762
# Validation: Avg Standard Validation Loss: 5.0239
# Validation: Avg Attenuated Validation Loss: 3.5510
# Validation Loss for Scheduler: 5.0239
# saving model
# Epoch [81/100], Learning Rate: 1.0000000000000004e-08, Teacher forcing ratio: 0.0
# Training: Avg Attenuated Training Loss: 3.9812
# Validation: Avg Standard Validation Loss: 5.0379
# Validation: Avg Attenuated Validation Loss: 3.6012
# Validation Loss for Scheduler: 5.0379
# saving model
# Epoch [82/100], Learning Rate: 1.0000000000000004e-08, Teacher forcing ratio: 0.0
# Training: Avg Attenuated Training Loss: 3.9867
# Validation: Avg Standard Validation Loss: 4.9983
# Validation: Avg Attenuated Validation Loss: 3.5772
# Validation Loss for Scheduler: 4.9983
# saving model
# Epoch [83/100], Learning Rate: 1.0000000000000004e-08, Teacher forcing ratio: 0.0
# Training: Avg Attenuated Training Loss: 4.0025
# Validation: Avg Standard Validation Loss: 4.9807
# Validation: Avg Attenuated Validation Loss: 3.5176
# Validation Loss for Scheduler: 4.9807
# saving model
# Epoch [84/100], Learning Rate: 1.0000000000000004e-08, Teacher forcing ratio: 0.0
# Training: Avg Attenuated Training Loss: 4.0044
# Validation: Avg Standard Validation Loss: 5.0723
# Validation: Avg Attenuated Validation Loss: 3.5948
# Validation Loss for Scheduler: 5.0723
# saving model
# Epoch [85/100], Learning Rate: 1.0000000000000004e-08, Teacher forcing ratio: 0.0
# Training: Avg Attenuated Training Loss: 4.0035
# Validation: Avg Standard Validation Loss: 5.0430
# Validation: Avg Attenuated Validation Loss: 3.5903
# Validation Loss for Scheduler: 5.0430
# saving model
# Epoch [86/100], Learning Rate: 1.0000000000000004e-08, Teacher forcing ratio: 0.0
# Training: Avg Attenuated Training Loss: 4.0088
# Validation: Avg Standard Validation Loss: 5.0126
# Validation: Avg Attenuated Validation Loss: 3.5714
# Validation Loss for Scheduler: 5.0126
# saving model
# Epoch [87/100], Learning Rate: 1.0000000000000004e-08, Teacher forcing ratio: 0.0
# Training: Avg Attenuated Training Loss: 4.0211
# Validation: Avg Standard Validation Loss: 5.0513
# Validation: Avg Attenuated Validation Loss: 3.6477
# Validation Loss for Scheduler: 5.0513
# saving model
# Epoch [88/100], Learning Rate: 1.0000000000000004e-08, Teacher forcing ratio: 0.0
# Training: Avg Attenuated Training Loss: 4.0287
# Validation: Avg Standard Validation Loss: 5.0032
# Validation: Avg Attenuated Validation Loss: 3.5600
# Validation Loss for Scheduler: 5.0032
# saving model
# Epoch [89/100], Learning Rate: 1.0000000000000004e-08, Teacher forcing ratio: 0.0
# Training: Avg Attenuated Training Loss: 4.0269
# Validation: Avg Standard Validation Loss: 5.0649
# Validation: Avg Attenuated Validation Loss: 3.6037
# Validation Loss for Scheduler: 5.0649
# saving model
# Epoch [90/100], Learning Rate: 1.0000000000000004e-08, Teacher forcing ratio: 0.0
# Training: Avg Attenuated Training Loss: 4.0446
# Validation: Avg Standard Validation Loss: 5.0603
# Validation: Avg Attenuated Validation Loss: 3.5607
# Validation Loss for Scheduler: 5.0603
# saving model
# Epoch [91/100], Learning Rate: 1.0000000000000004e-08, Teacher forcing ratio: 0.0
# Training: Avg Attenuated Training Loss: 4.0449
# Validation: Avg Standard Validation Loss: 5.0408
# Validation: Avg Attenuated Validation Loss: 3.5983
# Validation Loss for Scheduler: 5.0408
# saving model
# Epoch [92/100], Learning Rate: 1.0000000000000004e-08, Teacher forcing ratio: 0.0
# Training: Avg Attenuated Training Loss: 4.0522
# Validation: Avg Standard Validation Loss: 5.0553
# Validation: Avg Attenuated Validation Loss: 3.5895
# Validation Loss for Scheduler: 5.0553
# saving model
# Epoch [93/100], Learning Rate: 1.0000000000000004e-08, Teacher forcing ratio: 0.0
# Training: Avg Attenuated Training Loss: 4.0501
# Validation: Avg Standard Validation Loss: 5.1023
# Validation: Avg Attenuated Validation Loss: 3.6948
# Validation Loss for Scheduler: 5.1023
# saving model
# Epoch [94/100], Learning Rate: 1.0000000000000004e-08, Teacher forcing ratio: 0.0
# Training: Avg Attenuated Training Loss: 4.0629
# Validation: Avg Standard Validation Loss: 5.1145
# Validation: Avg Attenuated Validation Loss: 3.5769
# Validation Loss for Scheduler: 5.1145
# saving model
# Epoch [95/100], Learning Rate: 1.0000000000000004e-08, Teacher forcing ratio: 0.0
# Training: Avg Attenuated Training Loss: 4.0561
# Validation: Avg Standard Validation Loss: 5.1077
# Validation: Avg Attenuated Validation Loss: 3.7776
# Validation Loss for Scheduler: 5.1077
# saving model
# Epoch [96/100], Learning Rate: 1.0000000000000004e-08, Teacher forcing ratio: 0.0
# Training: Avg Attenuated Training Loss: 4.0754
# Validation: Avg Standard Validation Loss: 5.0909
# Validation: Avg Attenuated Validation Loss: 3.6369
# Validation Loss for Scheduler: 5.0909
# saving model
# Epoch [97/100], Learning Rate: 1.0000000000000004e-08, Teacher forcing ratio: 0.0
# Training: Avg Attenuated Training Loss: 4.0740
# Validation: Avg Standard Validation Loss: 5.0138
# Validation: Avg Attenuated Validation Loss: 3.5652
# Validation Loss for Scheduler: 5.0138
# saving model
# Epoch [98/100], Learning Rate: 1.0000000000000004e-08, Teacher forcing ratio: 0.0
# Training: Avg Attenuated Training Loss: 4.0885
# Validation: Avg Standard Validation Loss: 5.0157
# Validation: Avg Attenuated Validation Loss: 3.5554
# Validation Loss for Scheduler: 5.0157
# saving model
# Epoch [99/100], Learning Rate: 1.0000000000000004e-08, Teacher forcing ratio: 0.0
# Training: Avg Attenuated Training Loss: 4.0834
# Validation: Avg Standard Validation Loss: 5.1049
# Validation: Avg Attenuated Validation Loss: 3.6672
# Validation Loss for Scheduler: 5.1049
# saving model
# Epoch [100/100], Learning Rate: 1.0000000000000004e-08, Teacher forcing ratio: 0.0
# Training: Avg Attenuated Training Loss: 4.0858
# Validation: Avg Standard Validation Loss: 5.0604
# Validation: Avg Attenuated Validation Loss: 3.6333
# Validation Loss for Scheduler: 5.0604
# saving model
# Training complete.
# Model saved to path: Helpdesk_full_grad_norm_new_v2.pkl

# %% [markdown]
# # Training Visualization

# %%
import matplotlib.pyplot as plt

# After training is finished, plot the loss curves
plt.plot(range(1, num_epochs+1), train_attenuated_losses, label='Training Attenuated Loss', color='blue')
plt.plot(range(1, num_epochs+1), val_losses, label='Validation Loss', color='orange')
plt.plot(range(1, num_epochs+1), val_attenuated_losses, label='Validation Attenuated Loss', color='green')
# Labeling x and y axes
plt.xlabel('Epochs', fontsize=12)
plt.ylabel('Loss', fontsize=12)
# Adding title
plt.title('Training and Validation Loss Curve', fontsize=14)
# Adding legend
plt.legend()
# Show the plot
plt.show()
