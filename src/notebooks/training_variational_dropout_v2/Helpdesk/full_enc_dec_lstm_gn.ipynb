# %% [markdown]
# # Imports

# %%
import importlib
import sys

# performance imports for torch: torch kernel uses one core only.
import os
os.environ["OMP_NUM_THREADS"] = "1"
os.environ["MKL_NUM_THREADS"] = "1"
os.environ["TORCH_NUM_THREADS"] = "1" 

import torch

sys.path.insert(0, '..')
sys.path.insert(0, '../..')
sys.path.insert(0, '../../..')

# %% [markdown]
# # Data

# %% [markdown]
# ### Load Data Files

# %%
# Path to your pickle file (saved with torch.save)
file_path_train = '../../../../encoded_data_conformal/Helpdesk/helpdesk_all_5_train.pkl'
# Load the dataset using torch.load
helpdesk_train_dataset = torch.load(file_path_train, weights_only=False)

# Path to your pickle file (saved with torch.save)
file_path_val = '../../../../encoded_data_conformal/Helpdesk/helpdesk_all_5_val.pkl'
# Load the dataset using torch.load
helpdesk_val_dataset = torch.load(file_path_val, weights_only=False)

# %% [markdown]
# ### Train Data Insights

# %%
# Helpdesk dataset dynamic categories, features:
helpdesk_all_categories = helpdesk_train_dataset.all_categories

helpdesk_all_categories_cat = helpdesk_all_categories[0]
# print(helpdesk_all_categories_cat)
helpdesk_all_categories_num = helpdesk_all_categories[1]
# print(helpdesk_all_categories_num)
for i, cat in enumerate(helpdesk_all_categories_cat):
     print(f"Helpdesk dynamic categorical feature: {cat[0]}, Index position in categorical data list: {i}")
     print(f"Helpdesk amount of category labels: {cat[1]}")
print('\n')    
for i, num in enumerate(helpdesk_all_categories_num):
     print(f"Helpdesk dynamic numerical feature: {num[0]}, Index position in categorical data list: {i}")
     print(f"Helpdesk amount of numerical: {num[1]}")
print('\n')
     
# Helpdesk dataset static categories, features:
helpdesk_all_stat_categories = helpdesk_train_dataset.all_static_categories

helpdesk_all_stat_categories_cat = helpdesk_all_stat_categories[0]
# print(helpdesk_all_stat_categories_cat)
helpdesk_all_stat_categories_num = helpdesk_all_stat_categories[1]
# print(helpdesk_all_stat_categories_num)
for i, cat in enumerate(helpdesk_all_stat_categories_cat):
     print(f"Helpdesk static categorical feature: {cat[0]}, Index position in categorical data list: {i}")
     print(f"Helpdesk amount of category labels: {cat[1]}")
print('\n')    
for i, num in enumerate(helpdesk_all_stat_categories_num):
     print(f"Helpdesk static numerical feature: {num[0]}, Index position in categorical data list: {i}")
     print(f"Helpdesk amount of numerical: {num[1]}")
# Out:
# Helpdesk dynamic categorical feature: Activity, Index position in categorical data list: 0
# Helpdesk amount of category labels: 16
# Helpdesk dynamic categorical feature: Resource, Index position in categorical data list: 1
# Helpdesk amount of category labels: 24
#
#
# Helpdesk dynamic numerical feature: case_elapsed_time, Index position in categorical data list: 0
# Helpdesk amount of numerical: 1
# Helpdesk dynamic numerical feature: event_elapsed_time, Index position in categorical data list: 1
# Helpdesk amount of numerical: 1
# Helpdesk dynamic numerical feature: day_in_week, Index position in categorical data list: 2
# Helpdesk amount of numerical: 1
# Helpdesk dynamic numerical feature: seconds_in_day, Index position in categorical data list: 3
# Helpdesk amount of numerical: 1
#
#
# Helpdesk static categorical feature: seriousness, Index position in categorical data list: 0
# Helpdesk amount of category labels: 2
# Helpdesk static categorical feature: customer, Index position in categorical data list: 1
# Helpdesk amount of category labels: 363
# Helpdesk static categorical feature: product, Index position in categorical data list: 2
# Helpdesk amount of category labels: 22
# Helpdesk static categorical feature: responsible_section, Index position in categorical data list: 3
# Helpdesk amount of category labels: 8
# Helpdesk static categorical feature: service_level, Index position in categorical data list: 4
# Helpdesk amount of category labels: 5
# Helpdesk static categorical feature: service_type, Index position in categorical data list: 5
# Helpdesk amount of category labels: 5
# Helpdesk static categorical feature: support_section, Index position in categorical data list: 6
# Helpdesk amount of category labels: 7
# Helpdesk static categorical feature: workgroup, Index position in categorical data list: 7
# Helpdesk amount of category labels: 5

# %% [markdown]
# ### Input Features for Encoder and Decoder

# %%
# Create lists with name of Encoder features (input) and decoder features (input & output)
# Encoder features:
enc_feat_cat = []
enc_feat_num = []
for cat in helpdesk_all_categories_cat:
    enc_feat_cat.append(cat[0])
for num in helpdesk_all_categories_num:
    enc_feat_num.append(num[0])
enc_feat = [enc_feat_cat, enc_feat_num]
print("Input features encoder: ", enc_feat)

# Static encoder features:
stat_enc_feat_cat = []
stat_enc_feat_num = []
for cat in helpdesk_all_stat_categories_cat:
     stat_enc_feat_cat.append(cat[0])
for num in helpdesk_all_stat_categories_num:
     stat_enc_feat_num.append(num[0])
stat_enc_feat = [stat_enc_feat_cat, stat_enc_feat_num]
print("Input features static encoder: ", stat_enc_feat)

# Decoder features:
dec_feat_cat = ['Activity']
dec_feat_num = ['case_elapsed_time', 'event_elapsed_time']
dec_feat = [dec_feat_cat, dec_feat_num]
print("Features decoder: ", dec_feat)
# Out:
# Input features encoder:  [['Activity', 'Resource'], ['case_elapsed_time', 'event_elapsed_time', 'day_in_week', 'seconds_in_day']]
# Input features static encoder:  [['seriousness', 'customer', 'product', 'responsible_section', 'service_level', 'service_type', 'support_section', 'workgroup'], []]
# Features decoder:  [['Activity'], ['case_elapsed_time', 'event_elapsed_time']]

# %% [markdown]
# # Model

# %%
import model.dropout_uncertainty_enc_dec_LSTM.dropout_uncertainty_model
importlib.reload(model.dropout_uncertainty_enc_dec_LSTM.dropout_uncertainty_model)
from model.dropout_uncertainty_enc_dec_LSTM.dropout_uncertainty_model import DropoutUncertaintyEncoderDecoderLSTM

# Prediction decoder output sequence length
seq_len_pred = helpdesk_train_dataset.min_suffix_size

# Size hidden layer
hidden_size = 128

# Number of cells
num_layers = 4

# Fixed Dropout probability 
# Experiment with different values but be carefull with exploiting gradients:
dropout = 0.1

# Encoder Decoder model initialization
model = DropoutUncertaintyEncoderDecoderLSTM(data_set_categories=helpdesk_all_categories,
                                             enc_feat=enc_feat,
                                             dec_feat=dec_feat,
                                             seq_len_pred=seq_len_pred,
                                             hidden_size=hidden_size,
                                             num_layers=num_layers,
                                             dropout=dropout,
                                             # static attributes
                                             static_data_set_categories=helpdesk_all_stat_categories,
                                             static_enc_feat=stat_enc_feat
                                             )
# Out:
# Dynamic data set categories:  ([('Activity', 16, {'Assign seriousness': 1, 'Closed': 2, 'Create SW anomaly': 3, 'DUPLICATE': 4, 'EOS': 5, 'INVALID': 6, 'Insert ticket': 7, 'RESOLVED': 8, 'Require upgrade': 9, 'Resolve SW anomaly': 10, 'Resolve ticket': 11, 'Schedule intervention': 12, 'Take in charge ticket': 13, 'VERIFIED': 14, 'Wait': 15}), ('Resource', 24, {'EOS': 1, 'Value 1': 2, 'Value 10': 3, 'Value 11': 4, 'Value 12': 5, 'Value 13': 6, 'Value 14': 7, 'Value 15': 8, 'Value 16': 9, 'Value 17': 10, 'Value 18': 11, 'Value 19': 12, 'Value 2': 13, 'Value 20': 14, 'Value 21': 15, 'Value 22': 16, 'Value 3': 17, 'Value 4': 18, 'Value 5': 19, 'Value 6': 20, 'Value 7': 21, 'Value 8': 22, 'Value 9': 23})], [('case_elapsed_time', 1, {}), ('event_elapsed_time', 1, {}), ('day_in_week', 1, {}), ('seconds_in_day', 1, {})])
# Data set static categories:  ([('seriousness', 2, {'Value 1': 1}), ('customer', 363, {'Value 1': 1, 'Value 10': 2, 'Value 100': 3, 'Value 101': 4, 'Value 102': 5, 'Value 103': 6, 'Value 104': 7, 'Value 105': 8, 'Value 106': 9, 'Value 107': 10, 'Value 108': 11, 'Value 11': 12, 'Value 110': 13, 'Value 111': 14, 'Value 112': 15, 'Value 113': 16, 'Value 114': 17, 'Value 115': 18, 'Value 116': 19, 'Value 117': 20, 'Value 118': 21, 'Value 119': 22, 'Value 12': 23, 'Value 120': 24, 'Value 121': 25, 'Value 122': 26, 'Value 123': 27, 'Value 124': 28, 'Value 125': 29, 'Value 126': 30, 'Value 127': 31, 'Value 129': 32, 'Value 13': 33, 'Value 131': 34, 'Value 132': 35, 'Value 133': 36, 'Value 134': 37, 'Value 135': 38, 'Value 136': 39, 'Value 137': 40, 'Value 138': 41, 'Value 139': 42, 'Value 14': 43, 'Value 140': 44, 'Value 142': 45, 'Value 143': 46, 'Value 144': 47, 'Value 145': 48, 'Value 146': 49, 'Value 147': 50, 'Value 148': 51, 'Value 149': 52, 'Value 15': 53, 'Value 150': 54, 'Value 151': 55, 'Value 152': 56, 'Value 153': 57, 'Value 154': 58, 'Value 155': 59, 'Value 156': 60, 'Value 157': 61, 'Value 158': 62, 'Value 16': 63, 'Value 160': 64, 'Value 161': 65, 'Value 162': 66, 'Value 163': 67, 'Value 164': 68, 'Value 165': 69, 'Value 166': 70, 'Value 167': 71, 'Value 168': 72, 'Value 169': 73, 'Value 17': 74, 'Value 171': 75, 'Value 172': 76, 'Value 173': 77, 'Value 174': 78, 'Value 175': 79, 'Value 176': 80, 'Value 177': 81, 'Value 178': 82, 'Value 179': 83, 'Value 18': 84, 'Value 180': 85, 'Value 181': 86, 'Value 182': 87, 'Value 183': 88, 'Value 184': 89, 'Value 185': 90, 'Value 186': 91, 'Value 187': 92, 'Value 188': 93, 'Value 189': 94, 'Value 19': 95, 'Value 190': 96, 'Value 191': 97, 'Value 192': 98, 'Value 193': 99, 'Value 194': 100, 'Value 195': 101, 'Value 196': 102, 'Value 197': 103, 'Value 198': 104, 'Value 199': 105, 'Value 2': 106, 'Value 20': 107, 'Value 200': 108, 'Value 201': 109, 'Value 202': 110, 'Value 203': 111, 'Value 204': 112, 'Value 205': 113, 'Value 206': 114, 'Value 207': 115, 'Value 208': 116, 'Value 209': 117, 'Value 21': 118, 'Value 210': 119, 'Value 211': 120, 'Value 213': 121, 'Value 214': 122, 'Value 215': 123, 'Value 216': 124, 'Value 217': 125, 'Value 218': 126, 'Value 219': 127, 'Value 22': 128, 'Value 220': 129, 'Value 221': 130, 'Value 222': 131, 'Value 223': 132, 'Value 224': 133, 'Value 225': 134, 'Value 226': 135, 'Value 227': 136, 'Value 228': 137, 'Value 229': 138, 'Value 23': 139, 'Value 230': 140, 'Value 231': 141, 'Value 232': 142, 'Value 233': 143, 'Value 234': 144, 'Value 235': 145, 'Value 236': 146, 'Value 237': 147, 'Value 238': 148, 'Value 239': 149, 'Value 24': 150, 'Value 240': 151, 'Value 241': 152, 'Value 242': 153, 'Value 243': 154, 'Value 244': 155, 'Value 245': 156, 'Value 246': 157, 'Value 247': 158, 'Value 248': 159, 'Value 249': 160, 'Value 25': 161, 'Value 250': 162, 'Value 251': 163, 'Value 252': 164, 'Value 253': 165, 'Value 254': 166, 'Value 255': 167, 'Value 256': 168, 'Value 258': 169, 'Value 259': 170, 'Value 26': 171, 'Value 260': 172, 'Value 261': 173, 'Value 262': 174, 'Value 263': 175, 'Value 264': 176, 'Value 265': 177, 'Value 266': 178, 'Value 267': 179, 'Value 268': 180, 'Value 269': 181, 'Value 27': 182, 'Value 271': 183, 'Value 272': 184, 'Value 273': 185, 'Value 274': 186, 'Value 275': 187, 'Value 276': 188, 'Value 277': 189, 'Value 278': 190, 'Value 279': 191, 'Value 28': 192, 'Value 280': 193, 'Value 281': 194, 'Value 282': 195, 'Value 283': 196, 'Value 284': 197, 'Value 285': 198, 'Value 286': 199, 'Value 287': 200, 'Value 288': 201, 'Value 289': 202, 'Value 29': 203, 'Value 292': 204, 'Value 293': 205, 'Value 294': 206, 'Value 296': 207, 'Value 297': 208, 'Value 298': 209, 'Value 299': 210, 'Value 3': 211, 'Value 30': 212, 'Value 300': 213, 'Value 301': 214, 'Value 302': 215, 'Value 303': 216, 'Value 304': 217, 'Value 305': 218, 'Value 306': 219, 'Value 307': 220, 'Value 308': 221, 'Value 309': 222, 'Value 31': 223, 'Value 310': 224, 'Value 311': 225,  ...
# Encoder dynamic input features:  [['Activity', 'Resource'], ['case_elapsed_time', 'event_elapsed_time', 'day_in_week', 'seconds_in_day']]
# Encoder static input features:  [['seriousness', 'customer', 'product', 'responsible_section', 'service_level', 'service_type', 'support_section', 'workgroup'], []]
# Decoder input and output features:  [['Activity'], ['case_elapsed_time', 'event_elapsed_time']]
# Sequence length of decoder output:  5
#
#
# LSTM cells and FC hidden size:  128
# Number of LSTM layer:  4
# Dropout rate:  0.1
#
#
# Encoder dynamic:
# Encoder number of labels for each input feature (categorical, numerical):  [[16, 24], [1, 1, 1, 1]]
# Encoder indices of tensors in dataset used as input:  [[0, 1], [0, 1, 2, 3]]
# Embeddings encoder:  ModuleList(
#   (0): Embedding(16, 8)
#   (1): Embedding(24, 9)
# )
# Total embedding feature size encoder:  17
# Total numerical feature size encoder:  4
# Input feature size encoder:  21
#
#
# Encoder static:
# Encoder number of labels for each input feature (categorical, numerical):  [[2, 363, 22, 8, 5, 5, 7, 5], []]
# Encoder indices of tensors in dataset used as input (static):  [[0, 1, 2, 3, 4, 5, 6, 7], []]
# Static encoder categorical embeddings:  ModuleList(
#   (0): Embedding(2, 2)
#   (1): Embedding(363, 43)
#   (2): Embedding(22, 9)
#   (3): Embedding(8, 5)
#   (4-5): 2 x Embedding(5, 4)
#   (6): Embedding(7, 5)
#   (7): Embedding(5, 4)
# )
# Total embedding feature size encoder (static):  76
# Total numerical feature size encoder (static):  0
# Static encoder feature size:  76
# Encoder initialized!
#
# Decoder label values size for each categorical input feature:  [16]
# Decoder label values size for each numerical input feature:  [1, 1]
# Decoder indices of tensors in dataset used as input:  [[0], [0, 1]]
# Embeddings decoder:  ModuleList(
#   (0): Embedding(16, 8)
# )
# Total embedding feature size decoder:  8
# Total numerical feature size decoder:  2
# Input feature size decoder:  10
# Output feature list of dicts (featue name, feature output size) of decoder:  [{'Activity': 16}, {'case_elapsed_time': 1, 'event_elapsed_time': 1}]
# Decoder initialized!

# %% [markdown]
# # Loss Object Creation

# %%
import loss.losses
importlib.reload(loss.losses)
from loss.losses import Loss

loss_obj = Loss()

# %% [markdown]
# # Training Configuration

# %%
import trainer.trainer
importlib.reload(trainer.trainer)
from trainer.trainer import Trainer
from torch.optim.lr_scheduler import ReduceLROnPlateau
from torch.utils.tensorboard import SummaryWriter

writer = SummaryWriter(comment="Full_Helpdesk_grad_conf")

# device
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Start learning rate
learning_rate = 1e-5
weight_decay = 0

# Optimizer and Scheduler
optimizer = torch.optim.AdamW(params=model.parameters(), lr=learning_rate, weight_decay=weight_decay)
scheduler = ReduceLROnPlateau(optimizer, mode='min', factor=0.1, patience=15, min_lr=1e-8)

# Epochs
num_epochs = 100

# Batches
batch_size = 128

# lambda for L2 (weight, bias, dropout) regularization
# regularization_term = 1.0/(2.0*batch_size)
regularization_term = 1e-4

# shuffle data
shuffle = True

# teacher forcing
max_teacher_forcing_value = 1.0
min_teacher_forcing_value = 0.0

optimize_values = {"regularization_term":regularization_term,
                   "optimizer":optimizer,
                   "scheduler": scheduler,
                   "epochs":num_epochs,
                   "mini_batches":batch_size,
                   "shuffle": shuffle,
                   "min_teacher_forcing_value":min_teacher_forcing_value,
                   "max_teacher_forcing_value":max_teacher_forcing_value}

suffix_data_split_value = helpdesk_train_dataset.min_suffix_size
print("Train seq length: ", suffix_data_split_value)

"""
GradNorm:
We disable it here to establish a baseline. Complexity (GradNorm) should only be added if the  baseline fails to learn certain tasks.
"""
# GradNorm parameter: 
use_gradnorm = True
# use_gradnorm = False
# task to be balanced for teacher forcing
number_tasks = len(dec_feat[0]) + len(dec_feat[1])
# Grdanorm hyperparams
# alpha: tasks/ alpha value (rule of thumb): 2-3: 1.0-1.5, 4-6: 0.7-1.0, 7-10: 0.4-0.7
# Formula approx: 2/sqrt(tasks)
gn_alpha = 1.5
# learning rate: Adjust relative to model learning rate.
gn_learning_rate = 1e-4

gradNorm = {"use_gradnorm":use_gradnorm,
            "number_tasks": number_tasks,
            "gn_alpha":gn_alpha,
            "gn_learning_rate": gn_learning_rate}
# gradNorm = None

trainer = Trainer(device=device,
                  model=model,
                  data_train=helpdesk_train_dataset,
                  data_val=helpdesk_val_dataset,
                  loss_obj=loss_obj,
                  log_normal_loss_num_feature = [],
                  optimize_values=optimize_values,
                  suffix_data_split_value=suffix_data_split_value,
                  writer=writer,
                  gradnorm_values=gradNorm,
                  save_model_n_th_epoch = 1,
                  saving_path = 'Helpdesk_full_grad_norm_conformal_v2.pkl')

# Train the model:
# - use stattics: (tensor) tensor of seperate encoded static attributes which is merged with dynmaics beforehand
# - use zero padd masking: (True) mask the left padded zeros in the encoder
# - use EOS padd masking: (True) mask the right padded unwanted EOS tokens in the loss
train_attenuated_losses, val_losses, val_attenuated_losses = trainer.train_model(use_statics=True,
                                                                                 use_zero_padd_masking=True,
                                                                                 use_eos_padd_masking=True)
# Out:
# Train seq length:  5
# Device:  cuda
# Model:  DropoutUncertaintyEncoderDecoderLSTM(
#   (embeddings_enc): ModuleList(
#     (0): Embedding(16, 8)
#     (1): Embedding(24, 9)
#   )
#   (embeddings_static_enc): ModuleList(
#     (0): Embedding(2, 2)
#     (1): Embedding(363, 43)
#     (2): Embedding(22, 9)
#     (3): Embedding(8, 5)
#     (4-5): 2 x Embedding(5, 4)
#     (6): Embedding(7, 5)
#     (7): Embedding(5, 4)
#   )
#   (encoder): DropoutUncertaintyLSTMEncoder(
#     (embeddings): ModuleList(
#       (0): Embedding(16, 8)
#       (1): Embedding(24, 9)
#     )
#     (static_embeddings): ModuleList(
#       (0): Embedding(2, 2)
#       (1): Embedding(363, 43)
#       (2): Embedding(22, 9)
#       (3): Embedding(8, 5)
#       (4-5): 2 x Embedding(5, 4)
#       (6): Embedding(7, 5)
#       (7): Embedding(5, 4)
#     )
#     (input_proj): Linear(in_features=97, out_features=128, bias=True)
#     (layernorm): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#     (act): ReLU()
#     (first_layer): DropoutUncertaintyLSTMCell(
#       (Wi): Linear(in_features=128, out_features=128, bias=True)
#       (Ui): Linear(in_features=128, out_features=128, bias=True)
#       (Wf): Linear(in_features=128, out_features=128, bias=True)
#       (Uf): Linear(in_features=128, out_features=128, bias=True)
#       (Wc): Linear(in_features=128, out_features=128, bias=True)
#       (Uc): Linear(in_features=128, out_features=128, bias=True)
#       (Wo): Linear(in_features=128, out_features=128, bias=True)
#       (Uo): Linear(in_features=128, out_features=128, bias=True)
#     )
#     (hidden_layers): ModuleList(
#       (0-2): 3 x DropoutUncertaintyLSTMCell(
#         (Wi): Linear(in_features=128, out_features=128, bias=True)
#         (Ui): Linear(in_features=128, out_features=128, bias=True)
#         (Wf): Linear(in_features=128, out_features=128, bias=True)
#         (Uf): Linear(in_features=128, out_features=128, bias=True)
#         (Wc): Linear(in_features=128, out_features=128, bias=True)
#         (Uc): Linear(in_features=128, out_features=128, bias=True)
#         (Wo): Linear(in_features=128, out_features=128, bias=True)
#         (Uo): Linear(in_features=128, out_features=128, bias=True)
#       )
#     )
#   )
#   (embeddings_dec): ModuleList(
#     (0): Embedding(16, 8)
#   )
#   (decoder): DropoutUncertaintyLSTMDecoder(
#     (embeddings): ModuleList(
#       (0): Embedding(16, 8)
#     )
#     (input_proj): Linear(in_features=10, out_features=128, bias=True)
#     (layernorm): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#     (act): ReLU()
#     (first_layer): DropoutUncertaintyLSTMCell(
#       (Wi): Linear(in_features=128, out_features=128, bias=True)
#       (Ui): Linear(in_features=128, out_features=128, bias=True)
#       (Wf): Linear(in_features=128, out_features=128, bias=True)
#       (Uf): Linear(in_features=128, out_features=128, bias=True)
#       (Wc): Linear(in_features=128, out_features=128, bias=True)
#       (Uc): Linear(in_features=128, out_features=128, bias=True)
#       (Wo): Linear(in_features=128, out_features=128, bias=True)
#       (Uo): Linear(in_features=128, out_features=128, bias=True)
#     )
#     (hidden_layers): ModuleList(
#       (0-2): 3 x DropoutUncertaintyLSTMCell(
#         (Wi): Linear(in_features=128, out_features=128, bias=True)
#         (Ui): Linear(in_features=128, out_features=128, bias=True)
#         (Wf): Linear(in_features=128, out_features=128, bias=True)
#         (Uf): Linear(in_features=128, out_features=128, bias=True)
#         (Wc): Linear(in_features=128, out_features=128, bias=True)
#         (Uc): Linear(in_features=128, out_features=128, bias=True)
#         (Wo): Linear(in_features=128, out_features=128, bias=True)
#         (Uo): Linear(in_features=128, out_features=128, bias=True)
#       )
#     )
#     (output_layers): ModuleDict(
#       (Activity_mean): Linear(in_features=128, out_features=16, bias=True)
#       (Activity_var): Linear(in_features=128, out_features=16, bias=True)
#       (case_elapsed_time_mean): Linear(in_features=128, out_features=1, bias=True)
#       (case_elapsed_time_var): Linear(in_features=128, out_features=1, bias=True)
#       (event_elapsed_time_mean): Linear(in_features=128, out_features=1, bias=True)
#       (event_elapsed_time_var): Linear(in_features=128, out_features=1, bias=True)
#     )
#   )
# )
# Train Dataset:  <event_log_loader.new_event_log_loader_v2.EventLogDataset object at 0x7f707fcdda90>
# Validation Dataset:  <event_log_loader.new_event_log_loader_v2.EventLogDataset object at 0x7f71b42a3590>
# Loss object for method calling:  <loss.losses.Loss object at 0x7f71b455a3c0>
# Num. feautures that follow log-normal PDF:  []
# regularization:  0.0001
# Optimizer:  AdamW (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     capturable: False
#     decoupled_weight_decay: True
#     differentiable: False
#     eps: 1e-08
#     foreach: None
#     fused: None
#     lr: 1e-05
#     maximize: False
#     weight_decay: 0
# )
# Scheduler:  <torch.optim.lr_scheduler.ReduceLROnPlateau object at 0x7f707eeecec0>
# Epochs:  100
# Mini baches:  128
# Shuffle batched dataset:  True
# Use GradNorm:  True
# GradNorm alpha:  1.5
# GradNorm learning rate:  0.0001
# Initial GradNorm loss weights:  Parameter containing:
# tensor([1., 1., 1.], device='cuda:0', requires_grad=True)
# Initial loss values:  None
# GradNorm optimizer:  AdamW (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     capturable: False
#     decoupled_weight_decay: True
#     differentiable: False
#     eps: 1e-08
#     foreach: None
#     fused: None
#     lr: 0.0001
#     maximize: False
#     weight_decay: 0.01
# )
# Epoch [1/100], Learning Rate: 1e-05, Teacher forcing ratio: 1.0
# Training: Avg Attenuated Training Loss: 5.4434
# Validation: Avg Standard Validation Loss: 6.4956
# Validation: Avg Attenuated Validation Loss: 5.0901
# Validation Loss for Scheduler: 6.4956
# saving model
# Epoch [2/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.98
# Training: Avg Attenuated Training Loss: 5.3743
# Validation: Avg Standard Validation Loss: 6.4711
# Validation: Avg Attenuated Validation Loss: 5.0437
# Validation Loss for Scheduler: 6.4711
# saving model
# Epoch [3/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.96
# Training: Avg Attenuated Training Loss: 5.2536
# Validation: Avg Standard Validation Loss: 6.3785
# Validation: Avg Attenuated Validation Loss: 4.9464
# Validation Loss for Scheduler: 6.3785
# saving model
# Epoch [4/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.94
# Training: Avg Attenuated Training Loss: 5.0234
# Validation: Avg Standard Validation Loss: 6.1587
# Validation: Avg Attenuated Validation Loss: 4.7141
# Validation Loss for Scheduler: 6.1587
# saving model
# Epoch [5/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.92
# Training: Avg Attenuated Training Loss: 4.5801
# Validation: Avg Standard Validation Loss: 5.5725
# Validation: Avg Attenuated Validation Loss: 4.2440
# Validation Loss for Scheduler: 5.5725
# saving model
# Epoch [6/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.9
# Training: Avg Attenuated Training Loss: 3.9541
# Validation: Avg Standard Validation Loss: 5.2710
# Validation: Avg Attenuated Validation Loss: 3.7722
# Validation Loss for Scheduler: 5.2710
# saving model
# Epoch [7/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.88
# Training: Avg Attenuated Training Loss: 3.2627
# Validation: Avg Standard Validation Loss: 4.8660
# Validation: Avg Attenuated Validation Loss: 3.4362
# Validation Loss for Scheduler: 4.8660
# saving model
# Epoch [8/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.86
# Training: Avg Attenuated Training Loss: 2.7105
# Validation: Avg Standard Validation Loss: 4.7601
# Validation: Avg Attenuated Validation Loss: 3.4703
# Validation Loss for Scheduler: 4.7601
# saving model
# Epoch [9/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.84
# Training: Avg Attenuated Training Loss: 2.3466
# Validation: Avg Standard Validation Loss: 4.9583
# Validation: Avg Attenuated Validation Loss: 3.7711
# Validation Loss for Scheduler: 4.9583
# saving model
# Epoch [10/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.8200000000000001
# Training: Avg Attenuated Training Loss: 2.0986
# Validation: Avg Standard Validation Loss: 4.9791
# Validation: Avg Attenuated Validation Loss: 4.0909
# Validation Loss for Scheduler: 4.9791
# saving model
# Epoch [11/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.8
# Training: Avg Attenuated Training Loss: 1.9276
# Validation: Avg Standard Validation Loss: 4.9571
# Validation: Avg Attenuated Validation Loss: 4.4305
# Validation Loss for Scheduler: 4.9571
# saving model
# Epoch [12/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.78
# Training: Avg Attenuated Training Loss: 1.7981
# Validation: Avg Standard Validation Loss: 4.9108
# Validation: Avg Attenuated Validation Loss: 4.7963
# Validation Loss for Scheduler: 4.9108
# saving model
# Epoch [13/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.76
# Training: Avg Attenuated Training Loss: 1.9079
# Validation: Avg Standard Validation Loss: 4.8731
# Validation: Avg Attenuated Validation Loss: 4.9573
# Validation Loss for Scheduler: 4.8731
# saving model
# Epoch [14/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.74
# Training: Avg Attenuated Training Loss: 1.9159
# Validation: Avg Standard Validation Loss: 4.8463
# Validation: Avg Attenuated Validation Loss: 5.1223
# Validation Loss for Scheduler: 4.8463
# saving model
# Epoch [15/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.72
# Training: Avg Attenuated Training Loss: 1.8167
# Validation: Avg Standard Validation Loss: 4.5965
# Validation: Avg Attenuated Validation Loss: 4.8194
# Validation Loss for Scheduler: 4.5965
# saving model
# Epoch [16/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.7
# Training: Avg Attenuated Training Loss: 1.8228
# Validation: Avg Standard Validation Loss: 4.1970
# Validation: Avg Attenuated Validation Loss: 4.2912
# Validation Loss for Scheduler: 4.1970
# saving model
# Epoch [17/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.6799999999999999
# Training: Avg Attenuated Training Loss: 1.8677
# Validation: Avg Standard Validation Loss: 3.8810
# Validation: Avg Attenuated Validation Loss: 3.8125
# Validation Loss for Scheduler: 3.8810
# saving model
# Epoch [18/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.6599999999999999
# Training: Avg Attenuated Training Loss: 1.7181
# Validation: Avg Standard Validation Loss: 3.8310
# Validation: Avg Attenuated Validation Loss: 3.6906
# Validation Loss for Scheduler: 3.8310
# saving model
# Epoch [19/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.64
# Training: Avg Attenuated Training Loss: 1.7884
# Validation: Avg Standard Validation Loss: 3.8272
# Validation: Avg Attenuated Validation Loss: 3.4840
# Validation Loss for Scheduler: 3.8272
# saving model
# Epoch [20/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.62
# Training: Avg Attenuated Training Loss: 1.7120
# Validation: Avg Standard Validation Loss: 3.8213
# Validation: Avg Attenuated Validation Loss: 3.7135
# Validation Loss for Scheduler: 3.8213
# saving model
# Epoch [21/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.6
# Training: Avg Attenuated Training Loss: 1.7445
# Validation: Avg Standard Validation Loss: 3.8276
# Validation: Avg Attenuated Validation Loss: 3.6163
# Validation Loss for Scheduler: 3.8276
# saving model
# Epoch [22/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.5800000000000001
# Training: Avg Attenuated Training Loss: 1.8138
# Validation: Avg Standard Validation Loss: 3.7816
# Validation: Avg Attenuated Validation Loss: 3.5019
# Validation Loss for Scheduler: 3.7816
# saving model
# Epoch [23/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.56
# Training: Avg Attenuated Training Loss: 1.9390
# Validation: Avg Standard Validation Loss: 3.7316
# Validation: Avg Attenuated Validation Loss: 2.8909
# Validation Loss for Scheduler: 3.7316
# saving model
# Epoch [24/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.54
# Training: Avg Attenuated Training Loss: 1.7711
# Validation: Avg Standard Validation Loss: 3.6446
# Validation: Avg Attenuated Validation Loss: 2.7011
# Validation Loss for Scheduler: 3.6446
# saving model
# Epoch [25/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.52
# Training: Avg Attenuated Training Loss: 1.7761
# Validation: Avg Standard Validation Loss: 3.6069
# Validation: Avg Attenuated Validation Loss: 2.5529
# Validation Loss for Scheduler: 3.6069
# saving model
# Epoch [26/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.5
# Training: Avg Attenuated Training Loss: 1.6952
# Validation: Avg Standard Validation Loss: 3.5880
# Validation: Avg Attenuated Validation Loss: 2.5762
# Validation Loss for Scheduler: 3.5880
# saving model
# Epoch [27/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.48
# Training: Avg Attenuated Training Loss: 1.7419
# Validation: Avg Standard Validation Loss: 3.5346
# Validation: Avg Attenuated Validation Loss: 2.2644
# Validation Loss for Scheduler: 3.5346
# saving model
# Epoch [28/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.45999999999999996
# Training: Avg Attenuated Training Loss: 1.7024
# Validation: Avg Standard Validation Loss: 3.4746
# Validation: Avg Attenuated Validation Loss: 2.1955
# Validation Loss for Scheduler: 3.4746
# saving model
# Epoch [29/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.43999999999999995
# Training: Avg Attenuated Training Loss: 1.6764
# Validation: Avg Standard Validation Loss: 3.4933
# Validation: Avg Attenuated Validation Loss: 2.1974
# Validation Loss for Scheduler: 3.4933
# saving model
# Epoch [30/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.42000000000000004
# Training: Avg Attenuated Training Loss: 1.6959
# Validation: Avg Standard Validation Loss: 3.4590
# Validation: Avg Attenuated Validation Loss: 2.0949
# Validation Loss for Scheduler: 3.4590
# saving model
# Epoch [31/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.4
# Training: Avg Attenuated Training Loss: 1.6809
# Validation: Avg Standard Validation Loss: 3.4985
# Validation: Avg Attenuated Validation Loss: 2.0519
# Validation Loss for Scheduler: 3.4985
# saving model
# Epoch [32/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.38
# Training: Avg Attenuated Training Loss: 1.6502
# Validation: Avg Standard Validation Loss: 3.4710
# Validation: Avg Attenuated Validation Loss: 2.0460
# Validation Loss for Scheduler: 3.4710
# saving model
# Epoch [33/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.36
# Training: Avg Attenuated Training Loss: 1.6765
# Validation: Avg Standard Validation Loss: 3.5183
# Validation: Avg Attenuated Validation Loss: 1.9991
# Validation Loss for Scheduler: 3.5183
# saving model
# Epoch [34/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.33999999999999997
# Training: Avg Attenuated Training Loss: 1.6530
# Validation: Avg Standard Validation Loss: 3.5624
# Validation: Avg Attenuated Validation Loss: 2.0019
# Validation Loss for Scheduler: 3.5624
# saving model
# Epoch [35/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.31999999999999995
# Training: Avg Attenuated Training Loss: 1.6511
# Validation: Avg Standard Validation Loss: 3.6025
# Validation: Avg Attenuated Validation Loss: 2.0124
# Validation Loss for Scheduler: 3.6025
# saving model
# Epoch [36/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.30000000000000004
# Training: Avg Attenuated Training Loss: 1.6006
# Validation: Avg Standard Validation Loss: 3.6117
# Validation: Avg Attenuated Validation Loss: 1.9916
# Validation Loss for Scheduler: 3.6117
# saving model
# Epoch [37/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.28
# Training: Avg Attenuated Training Loss: 1.6678
# Validation: Avg Standard Validation Loss: 3.7494
# Validation: Avg Attenuated Validation Loss: 2.0263
# Validation Loss for Scheduler: 3.7494
# saving model
# Epoch [38/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.26
# Training: Avg Attenuated Training Loss: 1.6719
# Validation: Avg Standard Validation Loss: 3.7399
# Validation: Avg Attenuated Validation Loss: 2.0161
# Validation Loss for Scheduler: 3.7399
# saving model
# Epoch [39/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.24
# Training: Avg Attenuated Training Loss: 1.6434
# Validation: Avg Standard Validation Loss: 3.7486
# Validation: Avg Attenuated Validation Loss: 2.0123
# Validation Loss for Scheduler: 3.7486
# saving model
# Epoch [40/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.21999999999999997
# Training: Avg Attenuated Training Loss: 1.6336
# Validation: Avg Standard Validation Loss: 3.7879
# Validation: Avg Attenuated Validation Loss: 2.0056
# Validation Loss for Scheduler: 3.7879
# saving model
# Epoch [41/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.19999999999999996
# Training: Avg Attenuated Training Loss: 1.6768
# Validation: Avg Standard Validation Loss: 3.7894
# Validation: Avg Attenuated Validation Loss: 2.0127
# Validation Loss for Scheduler: 3.7894
# saving model
# Epoch [42/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.18000000000000005
# Training: Avg Attenuated Training Loss: 1.6589
# Validation: Avg Standard Validation Loss: 3.8691
# Validation: Avg Attenuated Validation Loss: 2.0738
# Validation Loss for Scheduler: 3.8691
# saving model
# Epoch [43/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.16000000000000003
# Training: Avg Attenuated Training Loss: 1.6271
# Validation: Avg Standard Validation Loss: 3.8420
# Validation: Avg Attenuated Validation Loss: 2.0412
# Validation Loss for Scheduler: 3.8420
# saving model
# Epoch [44/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.14
# Training: Avg Attenuated Training Loss: 1.6188
# Validation: Avg Standard Validation Loss: 3.8689
# Validation: Avg Attenuated Validation Loss: 2.0537
# Validation Loss for Scheduler: 3.8689
# saving model
# Epoch [45/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.12
# Training: Avg Attenuated Training Loss: 1.6408
# Validation: Avg Standard Validation Loss: 3.9139
# Validation: Avg Attenuated Validation Loss: 2.1022
# Validation Loss for Scheduler: 3.9139
# saving model
# Epoch [46/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.09999999999999998
# Training: Avg Attenuated Training Loss: 1.6545
# Validation: Avg Standard Validation Loss: 3.9190
# Validation: Avg Attenuated Validation Loss: 2.1109
# Validation Loss for Scheduler: 3.9190
# saving model
# Epoch [47/100], Learning Rate: 1.0000000000000002e-06, Teacher forcing ratio: 0.07999999999999996
# Training: Avg Attenuated Training Loss: 1.6476
# Validation: Avg Standard Validation Loss: 3.9294
# Validation: Avg Attenuated Validation Loss: 2.1102
# Validation Loss for Scheduler: 3.9294
# saving model
# Epoch [48/100], Learning Rate: 1.0000000000000002e-06, Teacher forcing ratio: 0.06000000000000005
# Training: Avg Attenuated Training Loss: 1.6705
# Validation: Avg Standard Validation Loss: 3.9550
# Validation: Avg Attenuated Validation Loss: 2.1270
# Validation Loss for Scheduler: 3.9550
# saving model
# Epoch [49/100], Learning Rate: 1.0000000000000002e-06, Teacher forcing ratio: 0.040000000000000036
# Training: Avg Attenuated Training Loss: 1.6819
# Validation: Avg Standard Validation Loss: 3.9310
# Validation: Avg Attenuated Validation Loss: 2.1302
# Validation Loss for Scheduler: 3.9310
# saving model
# Epoch [50/100], Learning Rate: 1.0000000000000002e-06, Teacher forcing ratio: 0.020000000000000018
# Training: Avg Attenuated Training Loss: 1.6989
# Validation: Avg Standard Validation Loss: 3.9514
# Validation: Avg Attenuated Validation Loss: 2.1306
# Validation Loss for Scheduler: 3.9514
# saving model
# Epoch [51/100], Learning Rate: 1.0000000000000002e-06, Teacher forcing ratio: 0.0
# Training: Avg Attenuated Training Loss: 1.7127
# Validation: Avg Standard Validation Loss: 3.9739
# Validation: Avg Attenuated Validation Loss: 2.1527
# Validation Loss for Scheduler: 3.9739
# saving model
# Epoch [52/100], Learning Rate: 1.0000000000000002e-06, Teacher forcing ratio: 0.0
# Training: Avg Attenuated Training Loss: 1.7173
# Validation: Avg Standard Validation Loss: 3.9766
# Validation: Avg Attenuated Validation Loss: 2.1585
# Validation Loss for Scheduler: 3.9766
# saving model
# Epoch [53/100], Learning Rate: 1.0000000000000002e-06, Teacher forcing ratio: 0.0
# Training: Avg Attenuated Training Loss: 1.7131
# Validation: Avg Standard Validation Loss: 3.9843
# Validation: Avg Attenuated Validation Loss: 2.1708
# Validation Loss for Scheduler: 3.9843
# saving model
# Epoch [54/100], Learning Rate: 1.0000000000000002e-06, Teacher forcing ratio: 0.0
# Training: Avg Attenuated Training Loss: 1.7090
# Validation: Avg Standard Validation Loss: 3.9742
# Validation: Avg Attenuated Validation Loss: 2.1468
# Validation Loss for Scheduler: 3.9742
# saving model
# Epoch [55/100], Learning Rate: 1.0000000000000002e-06, Teacher forcing ratio: 0.0
# Training: Avg Attenuated Training Loss: 1.7217
# Validation: Avg Standard Validation Loss: 3.9668
# Validation: Avg Attenuated Validation Loss: 2.1464
# Validation Loss for Scheduler: 3.9668
# saving model
# Epoch [56/100], Learning Rate: 1.0000000000000002e-06, Teacher forcing ratio: 0.0
# Training: Avg Attenuated Training Loss: 1.7131
# Validation: Avg Standard Validation Loss: 3.9892
# Validation: Avg Attenuated Validation Loss: 2.1602
# Validation Loss for Scheduler: 3.9892
# saving model
# Epoch [57/100], Learning Rate: 1.0000000000000002e-06, Teacher forcing ratio: 0.0
# Training: Avg Attenuated Training Loss: 1.7181
# Validation: Avg Standard Validation Loss: 3.9980
# Validation: Avg Attenuated Validation Loss: 2.1636
# Validation Loss for Scheduler: 3.9980
# saving model
# Epoch [58/100], Learning Rate: 1.0000000000000002e-06, Teacher forcing ratio: 0.0
# Training: Avg Attenuated Training Loss: 1.7207
# Validation: Avg Standard Validation Loss: 3.9924
# Validation: Avg Attenuated Validation Loss: 2.1619
# Validation Loss for Scheduler: 3.9924
# saving model
# Epoch [59/100], Learning Rate: 1.0000000000000002e-06, Teacher forcing ratio: 0.0
# Training: Avg Attenuated Training Loss: 1.7235
# Validation: Avg Standard Validation Loss: 3.9824
# Validation: Avg Attenuated Validation Loss: 2.1534
# Validation Loss for Scheduler: 3.9824
# saving model
# Epoch [60/100], Learning Rate: 1.0000000000000002e-06, Teacher forcing ratio: 0.0
# Training: Avg Attenuated Training Loss: 1.7170
# Validation: Avg Standard Validation Loss: 3.9808
# Validation: Avg Attenuated Validation Loss: 2.1628
# Validation Loss for Scheduler: 3.9808
# saving model
# Epoch [61/100], Learning Rate: 1.0000000000000002e-06, Teacher forcing ratio: 0.0
# Training: Avg Attenuated Training Loss: 1.7245
# Validation: Avg Standard Validation Loss: 4.0025
# Validation: Avg Attenuated Validation Loss: 2.2029
# Validation Loss for Scheduler: 4.0025
# saving model
# Epoch [62/100], Learning Rate: 1.0000000000000002e-06, Teacher forcing ratio: 0.0
# Training: Avg Attenuated Training Loss: 1.7230
# Validation: Avg Standard Validation Loss: 3.9985
# Validation: Avg Attenuated Validation Loss: 2.1681
# Validation Loss for Scheduler: 3.9985
# saving model
# Epoch [63/100], Learning Rate: 1.0000000000000002e-07, Teacher forcing ratio: 0.0
# Training: Avg Attenuated Training Loss: 1.7303
# Validation: Avg Standard Validation Loss: 4.0044
# Validation: Avg Attenuated Validation Loss: 2.1712
# Validation Loss for Scheduler: 4.0044
# saving model
# Epoch [64/100], Learning Rate: 1.0000000000000002e-07, Teacher forcing ratio: 0.0
# Training: Avg Attenuated Training Loss: 1.7350
# Validation: Avg Standard Validation Loss: 3.9788
# Validation: Avg Attenuated Validation Loss: 2.1536
# Validation Loss for Scheduler: 3.9788
# saving model
# Epoch [65/100], Learning Rate: 1.0000000000000002e-07, Teacher forcing ratio: 0.0
# Training: Avg Attenuated Training Loss: 1.7306
# Validation: Avg Standard Validation Loss: 3.9906
# Validation: Avg Attenuated Validation Loss: 2.1468
# Validation Loss for Scheduler: 3.9906
# saving model
# Epoch [66/100], Learning Rate: 1.0000000000000002e-07, Teacher forcing ratio: 0.0
# Training: Avg Attenuated Training Loss: 1.7376
# Validation: Avg Standard Validation Loss: 3.9959
# Validation: Avg Attenuated Validation Loss: 2.1604
# Validation Loss for Scheduler: 3.9959
# saving model
# Epoch [67/100], Learning Rate: 1.0000000000000002e-07, Teacher forcing ratio: 0.0
# Training: Avg Attenuated Training Loss: 1.7378
# Validation: Avg Standard Validation Loss: 3.9921
# Validation: Avg Attenuated Validation Loss: 2.1748
# Validation Loss for Scheduler: 3.9921
# saving model
# Epoch [68/100], Learning Rate: 1.0000000000000002e-07, Teacher forcing ratio: 0.0
# Training: Avg Attenuated Training Loss: 1.7469
# Validation: Avg Standard Validation Loss: 3.9808
# Validation: Avg Attenuated Validation Loss: 2.1634
# Validation Loss for Scheduler: 3.9808
# saving model
# Epoch [69/100], Learning Rate: 1.0000000000000002e-07, Teacher forcing ratio: 0.0
# Training: Avg Attenuated Training Loss: 1.7452
# Validation: Avg Standard Validation Loss: 3.9942
# Validation: Avg Attenuated Validation Loss: 2.1688
# Validation Loss for Scheduler: 3.9942
# saving model
# Epoch [70/100], Learning Rate: 1.0000000000000002e-07, Teacher forcing ratio: 0.0
# Training: Avg Attenuated Training Loss: 1.7502
# Validation: Avg Standard Validation Loss: 4.0018
# Validation: Avg Attenuated Validation Loss: 2.1708
# Validation Loss for Scheduler: 4.0018
# saving model
# Epoch [71/100], Learning Rate: 1.0000000000000002e-07, Teacher forcing ratio: 0.0
# Training: Avg Attenuated Training Loss: 1.7589
# Validation: Avg Standard Validation Loss: 3.9887
# Validation: Avg Attenuated Validation Loss: 2.1616
# Validation Loss for Scheduler: 3.9887
# saving model
# Epoch [72/100], Learning Rate: 1.0000000000000002e-07, Teacher forcing ratio: 0.0
# Training: Avg Attenuated Training Loss: 1.7531
# Validation: Avg Standard Validation Loss: 4.0000
# Validation: Avg Attenuated Validation Loss: 2.1684
# Validation Loss for Scheduler: 4.0000
# saving model
# Epoch [73/100], Learning Rate: 1.0000000000000002e-07, Teacher forcing ratio: 0.0
# Training: Avg Attenuated Training Loss: 1.7592
# Validation: Avg Standard Validation Loss: 3.9931
# Validation: Avg Attenuated Validation Loss: 2.1687
# Validation Loss for Scheduler: 3.9931
# saving model
# Epoch [74/100], Learning Rate: 1.0000000000000002e-07, Teacher forcing ratio: 0.0
# Training: Avg Attenuated Training Loss: 1.7593
# Validation: Avg Standard Validation Loss: 4.0055
# Validation: Avg Attenuated Validation Loss: 2.1722
# Validation Loss for Scheduler: 4.0055
# saving model
# Epoch [75/100], Learning Rate: 1.0000000000000002e-07, Teacher forcing ratio: 0.0
# Training: Avg Attenuated Training Loss: 1.7576
# Validation: Avg Standard Validation Loss: 4.0193
# Validation: Avg Attenuated Validation Loss: 2.1814
# Validation Loss for Scheduler: 4.0193
# saving model
# Epoch [76/100], Learning Rate: 1.0000000000000002e-07, Teacher forcing ratio: 0.0
# Training: Avg Attenuated Training Loss: 1.7609
# Validation: Avg Standard Validation Loss: 3.9982
# Validation: Avg Attenuated Validation Loss: 2.1628
# Validation Loss for Scheduler: 3.9982
# saving model
# Epoch [77/100], Learning Rate: 1.0000000000000002e-07, Teacher forcing ratio: 0.0
# Training: Avg Attenuated Training Loss: 1.7702
# Validation: Avg Standard Validation Loss: 3.9859
# Validation: Avg Attenuated Validation Loss: 2.1641
# Validation Loss for Scheduler: 3.9859
# saving model
# Epoch [78/100], Learning Rate: 1.0000000000000002e-07, Teacher forcing ratio: 0.0
# Training: Avg Attenuated Training Loss: 1.7705
# Validation: Avg Standard Validation Loss: 3.9992
# Validation: Avg Attenuated Validation Loss: 2.1695
# Validation Loss for Scheduler: 3.9992
# saving model
# Epoch [79/100], Learning Rate: 1.0000000000000004e-08, Teacher forcing ratio: 0.0
# Training: Avg Attenuated Training Loss: 1.7660
# Validation: Avg Standard Validation Loss: 4.0066
# Validation: Avg Attenuated Validation Loss: 2.1726
# Validation Loss for Scheduler: 4.0066
# saving model
# Epoch [80/100], Learning Rate: 1.0000000000000004e-08, Teacher forcing ratio: 0.0
# Training: Avg Attenuated Training Loss: 1.7629
# Validation: Avg Standard Validation Loss: 4.0081
# Validation: Avg Attenuated Validation Loss: 2.1700
# Validation Loss for Scheduler: 4.0081
# saving model
# Epoch [81/100], Learning Rate: 1.0000000000000004e-08, Teacher forcing ratio: 0.0
# Training: Avg Attenuated Training Loss: 1.7757
# Validation: Avg Standard Validation Loss: 4.0002
# Validation: Avg Attenuated Validation Loss: 2.1918
# Validation Loss for Scheduler: 4.0002
# saving model
# Epoch [82/100], Learning Rate: 1.0000000000000004e-08, Teacher forcing ratio: 0.0
# Training: Avg Attenuated Training Loss: 1.7811
# Validation: Avg Standard Validation Loss: 4.0111
# Validation: Avg Attenuated Validation Loss: 2.1748
# Validation Loss for Scheduler: 4.0111
# saving model
# Epoch [83/100], Learning Rate: 1.0000000000000004e-08, Teacher forcing ratio: 0.0
# Training: Avg Attenuated Training Loss: 1.7823
# Validation: Avg Standard Validation Loss: 4.0071
# Validation: Avg Attenuated Validation Loss: 2.1812
# Validation Loss for Scheduler: 4.0071
# saving model
# Epoch [84/100], Learning Rate: 1.0000000000000004e-08, Teacher forcing ratio: 0.0
# Training: Avg Attenuated Training Loss: 1.7788
# Validation: Avg Standard Validation Loss: 4.0100
# Validation: Avg Attenuated Validation Loss: 2.1661
# Validation Loss for Scheduler: 4.0100
# saving model
# Epoch [85/100], Learning Rate: 1.0000000000000004e-08, Teacher forcing ratio: 0.0
# Training: Avg Attenuated Training Loss: 1.7871
# Validation: Avg Standard Validation Loss: 4.0062
# Validation: Avg Attenuated Validation Loss: 2.1679
# Validation Loss for Scheduler: 4.0062
# saving model
# Epoch [86/100], Learning Rate: 1.0000000000000004e-08, Teacher forcing ratio: 0.0
# Training: Avg Attenuated Training Loss: 1.7908
# Validation: Avg Standard Validation Loss: 4.0103
# Validation: Avg Attenuated Validation Loss: 2.1822
# Validation Loss for Scheduler: 4.0103
# saving model
# Epoch [87/100], Learning Rate: 1.0000000000000004e-08, Teacher forcing ratio: 0.0
# Training: Avg Attenuated Training Loss: 1.7831
# Validation: Avg Standard Validation Loss: 3.9907
# Validation: Avg Attenuated Validation Loss: 2.1859
# Validation Loss for Scheduler: 3.9907
# saving model
# Epoch [88/100], Learning Rate: 1.0000000000000004e-08, Teacher forcing ratio: 0.0
# Training: Avg Attenuated Training Loss: 1.7879
# Validation: Avg Standard Validation Loss: 4.0041
# Validation: Avg Attenuated Validation Loss: 2.1651
# Validation Loss for Scheduler: 4.0041
# saving model
# Epoch [89/100], Learning Rate: 1.0000000000000004e-08, Teacher forcing ratio: 0.0
# Training: Avg Attenuated Training Loss: 1.7917
# Validation: Avg Standard Validation Loss: 4.0004
# Validation: Avg Attenuated Validation Loss: 2.1746
# Validation Loss for Scheduler: 4.0004
# saving model
# Epoch [90/100], Learning Rate: 1.0000000000000004e-08, Teacher forcing ratio: 0.0
# Training: Avg Attenuated Training Loss: 1.7990
# Validation: Avg Standard Validation Loss: 3.9985
# Validation: Avg Attenuated Validation Loss: 2.1603
# Validation Loss for Scheduler: 3.9985
# saving model
# Epoch [91/100], Learning Rate: 1.0000000000000004e-08, Teacher forcing ratio: 0.0
# Training: Avg Attenuated Training Loss: 1.8011
# Validation: Avg Standard Validation Loss: 4.0056
# Validation: Avg Attenuated Validation Loss: 2.1757
# Validation Loss for Scheduler: 4.0056
# saving model
# Epoch [92/100], Learning Rate: 1.0000000000000004e-08, Teacher forcing ratio: 0.0
# Training: Avg Attenuated Training Loss: 1.8032
# Validation: Avg Standard Validation Loss: 4.0006
# Validation: Avg Attenuated Validation Loss: 2.1755
# Validation Loss for Scheduler: 4.0006
# saving model
# Epoch [93/100], Learning Rate: 1.0000000000000004e-08, Teacher forcing ratio: 0.0
# Training: Avg Attenuated Training Loss: 1.8064
# Validation: Avg Standard Validation Loss: 4.0191
# Validation: Avg Attenuated Validation Loss: 2.1746
# Validation Loss for Scheduler: 4.0191
# saving model
# Epoch [94/100], Learning Rate: 1.0000000000000004e-08, Teacher forcing ratio: 0.0
# Training: Avg Attenuated Training Loss: 1.8010
# Validation: Avg Standard Validation Loss: 4.0228
# Validation: Avg Attenuated Validation Loss: 2.1792
# Validation Loss for Scheduler: 4.0228
# saving model
# Epoch [95/100], Learning Rate: 1.0000000000000004e-08, Teacher forcing ratio: 0.0
# Training: Avg Attenuated Training Loss: 1.8107
# Validation: Avg Standard Validation Loss: 4.0058
# Validation: Avg Attenuated Validation Loss: 2.1793
# Validation Loss for Scheduler: 4.0058
# saving model
# Epoch [96/100], Learning Rate: 1.0000000000000004e-08, Teacher forcing ratio: 0.0
# Training: Avg Attenuated Training Loss: 1.8127
# Validation: Avg Standard Validation Loss: 4.0074
# Validation: Avg Attenuated Validation Loss: 2.1807
# Validation Loss for Scheduler: 4.0074
# saving model
# Epoch [97/100], Learning Rate: 1.0000000000000004e-08, Teacher forcing ratio: 0.0
# Training: Avg Attenuated Training Loss: 1.8055
# Validation: Avg Standard Validation Loss: 4.0080
# Validation: Avg Attenuated Validation Loss: 2.1605
# Validation Loss for Scheduler: 4.0080
# saving model
# Epoch [98/100], Learning Rate: 1.0000000000000004e-08, Teacher forcing ratio: 0.0
# Training: Avg Attenuated Training Loss: 1.8163
# Validation: Avg Standard Validation Loss: 4.0065
# Validation: Avg Attenuated Validation Loss: 2.1660
# Validation Loss for Scheduler: 4.0065
# saving model
# Epoch [99/100], Learning Rate: 1.0000000000000004e-08, Teacher forcing ratio: 0.0
# Training: Avg Attenuated Training Loss: 1.8175
# Validation: Avg Standard Validation Loss: 4.0244
# Validation: Avg Attenuated Validation Loss: 2.1768
# Validation Loss for Scheduler: 4.0244
# saving model
# Epoch [100/100], Learning Rate: 1.0000000000000004e-08, Teacher forcing ratio: 0.0
# Training: Avg Attenuated Training Loss: 1.8194
# Validation: Avg Standard Validation Loss: 4.0028
# Validation: Avg Attenuated Validation Loss: 2.1565
# Validation Loss for Scheduler: 4.0028
# saving model
# Training complete.
# Model saved to path: Helpdesk_full_grad_norm_conformal_v2.pkl

# %% [markdown]
# # Training Visualization

# %%
import matplotlib.pyplot as plt

# After training is finished, plot the loss curves
plt.plot(range(1, num_epochs+1), train_attenuated_losses, label='Training Attenuated Loss', color='blue')
plt.plot(range(1, num_epochs+1), val_losses, label='Validation Loss', color='orange')
plt.plot(range(1, num_epochs+1), val_attenuated_losses, label='Validation Attenuated Loss', color='green')
# Labeling x and y axes
plt.xlabel('Epochs', fontsize=12)
plt.ylabel('Loss', fontsize=12)
# Adding title
plt.title('Training and Validation Loss Curve', fontsize=14)
# Adding legend
plt.legend()
# Show the plot
plt.show()
