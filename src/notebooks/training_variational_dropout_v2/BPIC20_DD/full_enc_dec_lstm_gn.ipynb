# %% [markdown]
# # Imports

# %%
import importlib
import sys

# performance imports for torch: torch kernel uses one core only.
import os
os.environ["OMP_NUM_THREADS"] = "1"
os.environ["MKL_NUM_THREADS"] = "1"
os.environ["TORCH_NUM_THREADS"] = "1" 

import torch

sys.path.insert(0, '..')
sys.path.insert(0, '../..')
sys.path.insert(0, '../../..')

# %% [markdown]
# # Data

# %% [markdown]
# ### Load Data Files

# %%
# Path to your pickle file (saved with torch.save)
file_path_train = '../../../../encoded_data_conformal/BPIC20_DD/bpic20_DD_all_5_train.pkl'
# Load the dataset using torch.load
bpic20_DD_train_dataset = torch.load(file_path_train, weights_only=False)

# Path to your pickle file (saved with torch.save)
file_path_val = '../../../../encoded_data_conformal/BPIC20_DD/bpic20_DD_all_5_val.pkl'
# Load the dataset using torch.load
bpic20_DD_val_dataset = torch.load(file_path_val, weights_only=False)

# %% [markdown]
# ### Train Data Insights

# %%
# Helpdesk dataset dynamic categories, features:
bpic20_DD_all_categories = bpic20_DD_train_dataset.all_categories

bpic20_DD_all_categories_cat = bpic20_DD_all_categories[0]
# print(helpdesk_all_categories_cat)
bpic20_DD_all_categories_num = bpic20_DD_all_categories[1]
# print(helpdesk_all_categories_num)
for i, cat in enumerate(bpic20_DD_all_categories_cat):
     print(f"BPIC20_DD dynamic categorical feature: {cat[0]}, Index position in categorical data list: {i}")
     print(f"BPIC20_DD amount of category labels: {cat[1]}")
print('\n')    
for i, num in enumerate(bpic20_DD_all_categories_num):
     print(f"BPIC20_DD dynamic numerical feature: {num[0]}, Index position in categorical data list: {i}")
     print(f"BPIC20_DD amount of numerical: {num[1]}")
print('\n')
     
# Helpdesk dataset static categories, features:
bpic20_DD_all_stat_categories = bpic20_DD_train_dataset.all_static_categories

bpic20_DD_all_stat_categories_cat = bpic20_DD_all_stat_categories[0]
# print(helpdesk_all_stat_categories_cat)
bpic20_DD_all_stat_categories_num = bpic20_DD_all_stat_categories[1]
# print(helpdesk_all_stat_categories_num)
for i, cat in enumerate(bpic20_DD_all_stat_categories_cat):
     print(f"BPIC20_DD static categorical feature: {cat[0]}, Index position in categorical data list: {i}")
     print(f"BPIC20_DD amount of category labels: {cat[1]}")
print('\n')    
for i, num in enumerate(bpic20_DD_all_stat_categories_num):
     print(f"BPIC20_DD static numerical feature: {num[0]}, Index position in categorical data list: {i}")
     print(f"BPIC20_DD amount of numerical: {num[1]}")
# Out:
# BPIC20_DD dynamic categorical feature: concept:name, Index position in categorical data list: 0
# BPIC20_DD amount of category labels: 18
# BPIC20_DD dynamic categorical feature: org:resource, Index position in categorical data list: 1
# BPIC20_DD amount of category labels: 4
# BPIC20_DD dynamic categorical feature: org:role, Index position in categorical data list: 2
# BPIC20_DD amount of category labels: 9
#
#
# BPIC20_DD dynamic numerical feature: case_elapsed_time, Index position in categorical data list: 0
# BPIC20_DD amount of numerical: 1
# BPIC20_DD dynamic numerical feature: event_elapsed_time, Index position in categorical data list: 1
# BPIC20_DD amount of numerical: 1
# BPIC20_DD dynamic numerical feature: day_in_week, Index position in categorical data list: 2
# BPIC20_DD amount of numerical: 1
# BPIC20_DD dynamic numerical feature: seconds_in_day, Index position in categorical data list: 3
# BPIC20_DD amount of numerical: 1
#
#
#
#
# BPIC20_DD static numerical feature: case:Amount, Index position in categorical data list: 0
# BPIC20_DD amount of numerical: 1

# %% [markdown]
# ### Input Features for Encoder and Decoder

# %%
# Create lists with name of Encoder features (input) and decoder features (input & output)
# Encoder features:
enc_feat_cat = []
enc_feat_num = []
for cat in bpic20_DD_all_categories_cat:
    enc_feat_cat.append(cat[0])
for num in bpic20_DD_all_categories_num:
    enc_feat_num.append(num[0])
enc_feat = [enc_feat_cat, enc_feat_num]
print("Input features encoder: ", enc_feat)

# Static encoder features:
stat_enc_feat_cat = []
stat_enc_feat_num = []
for cat in bpic20_DD_all_stat_categories_cat:
     stat_enc_feat_cat.append(cat[0])
for num in bpic20_DD_all_stat_categories_num:
     stat_enc_feat_num.append(num[0])
stat_enc_feat = [stat_enc_feat_cat, stat_enc_feat_num]
print("Input features static encoder: ", stat_enc_feat)

# Decoder features:
dec_feat_cat = ['concept:name']
dec_feat_num = ['case_elapsed_time', 'event_elapsed_time']
dec_feat = [dec_feat_cat, dec_feat_num]
print("Features decoder: ", dec_feat)
# Out:
# Input features encoder:  [['concept:name', 'org:resource', 'org:role'], ['case_elapsed_time', 'event_elapsed_time', 'day_in_week', 'seconds_in_day']]
# Input features static encoder:  [[], ['case:Amount']]
# Features decoder:  [['concept:name'], ['case_elapsed_time', 'event_elapsed_time']]

# %% [markdown]
# # Model

# %%
import model.dropout_uncertainty_enc_dec_LSTM.dropout_uncertainty_model
importlib.reload(model.dropout_uncertainty_enc_dec_LSTM.dropout_uncertainty_model)
from model.dropout_uncertainty_enc_dec_LSTM.dropout_uncertainty_model import DropoutUncertaintyEncoderDecoderLSTM

# Prediction decoder output sequence length
seq_len_pred = bpic20_DD_train_dataset.min_suffix_size

# Size hidden layer
hidden_size = 128

# Number of cells
num_layers = 4

# Fixed Dropout probability 
# Experiment with different values but be carefull with exploiting gradients:
dropout = 0.1

# Encoder Decoder model initialization
model = DropoutUncertaintyEncoderDecoderLSTM(data_set_categories=bpic20_DD_all_categories,
                                             enc_feat=enc_feat,
                                             dec_feat=dec_feat,
                                             seq_len_pred=seq_len_pred,
                                             hidden_size=hidden_size,
                                             num_layers=num_layers,
                                             dropout=dropout,
                                             # static attributes
                                             static_data_set_categories=bpic20_DD_all_stat_categories,
                                             static_enc_feat=stat_enc_feat
                                             )
# Out:
# Dynamic data set categories:  ([('concept:name', 18, {'Declaration APPROVED by ADMINISTRATION': 1, 'Declaration APPROVED by BUDGET OWNER': 2, 'Declaration APPROVED by PRE_APPROVER': 3, 'Declaration FINAL_APPROVED by SUPERVISOR': 4, 'Declaration FOR_APPROVAL by ADMINISTRATION': 5, 'Declaration FOR_APPROVAL by SUPERVISOR': 6, 'Declaration REJECTED by ADMINISTRATION': 7, 'Declaration REJECTED by BUDGET OWNER': 8, 'Declaration REJECTED by EMPLOYEE': 9, 'Declaration REJECTED by MISSING': 10, 'Declaration REJECTED by PRE_APPROVER': 11, 'Declaration REJECTED by SUPERVISOR': 12, 'Declaration SAVED by EMPLOYEE': 13, 'Declaration SUBMITTED by EMPLOYEE': 14, 'EOS': 15, 'Payment Handled': 16, 'Request Payment': 17}), ('org:resource', 4, {'EOS': 1, 'STAFF MEMBER': 2, 'SYSTEM': 3}), ('org:role', 9, {'ADMINISTRATION': 1, 'BUDGET OWNER': 2, 'EMPLOYEE': 3, 'EOS': 4, 'MISSING': 5, 'PRE_APPROVER': 6, 'SUPERVISOR': 7, 'UNDEFINED': 8})], [('case_elapsed_time', 1, {}), ('event_elapsed_time', 1, {}), ('day_in_week', 1, {}), ('seconds_in_day', 1, {})])
# Data set static categories:  ([], [('case:Amount', 1, {})])
# Encoder dynamic input features:  [['concept:name', 'org:resource', 'org:role'], ['case_elapsed_time', 'event_elapsed_time', 'day_in_week', 'seconds_in_day']]
# Encoder static input features:  [[], ['case:Amount']]
# Decoder input and output features:  [['concept:name'], ['case_elapsed_time', 'event_elapsed_time']]
# Sequence length of decoder output:  5
#
#
# LSTM cells and FC hidden size:  128
# Number of LSTM layer:  4
# Dropout rate:  0.1
#
#
# Encoder dynamic:
# Encoder number of labels for each input feature (categorical, numerical):  [[18, 4, 9], [1, 1, 1, 1]]
# Encoder indices of tensors in dataset used as input:  [[0, 1, 2], [0, 1, 2, 3]]
# Embeddings encoder:  ModuleList(
#   (0): Embedding(18, 8)
#   (1): Embedding(4, 3)
#   (2): Embedding(9, 5)
# )
# Total embedding feature size encoder:  16
# Total numerical feature size encoder:  4
# Input feature size encoder:  20
#
#
# Encoder static:
# Encoder number of labels for each input feature (categorical, numerical):  [[], [1]]
# Encoder indices of tensors in dataset used as input (static):  [[], [0]]
# Total embedding feature size encoder (static):  0
# Total numerical feature size encoder (static):  1
# Static encoder feature size:  1
# Encoder initialized!
#
# Decoder label values size for each categorical input feature:  [18]
# Decoder label values size for each numerical input feature:  [1, 1]
# Decoder indices of tensors in dataset used as input:  [[0], [0, 1]]
# Embeddings decoder:  ModuleList(
#   (0): Embedding(18, 8)
# )
# Total embedding feature size decoder:  8
# Total numerical feature size decoder:  2
# Input feature size decoder:  10
# Output feature list of dicts (featue name, feature output size) of decoder:  [{'concept:name': 18}, {'case_elapsed_time': 1, 'event_elapsed_time': 1}]
# Decoder initialized!

# %% [markdown]
# # Loss Object Creation

# %%
import loss.losses
importlib.reload(loss.losses)
from loss.losses import Loss

loss_obj = Loss()

# %% [markdown]
# # Training Configuration

# %%
import trainer.trainer
importlib.reload(trainer.trainer)
from trainer.trainer import Trainer
from torch.optim.lr_scheduler import ReduceLROnPlateau
from torch.utils.tensorboard import SummaryWriter

writer = SummaryWriter(comment="Full_BPIC20_grad_conformal")

# device
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Start learning rate
learning_rate = 1e-5
weight_decay = 0

# Optimizer and Scheduler
optimizer = torch.optim.AdamW(params=model.parameters(), lr=learning_rate, weight_decay=weight_decay)
scheduler = ReduceLROnPlateau(optimizer, mode='min', factor=0.1, patience=15, min_lr=1e-8)

# Epochs
num_epochs = 100

# Batches
batch_size = 128

# lambda for L2 (weight, bias, dropout) regularization
# regularization_term = 1.0/(2.0*batch_size)
regularization_term = 1e-4

# shuffle data
shuffle = True

# teacher forcing
max_teacher_forcing_value = 1.0
min_teacher_forcing_value = 0.0

optimize_values = {"regularization_term":regularization_term,
                   "optimizer":optimizer,
                   "scheduler": scheduler,
                   "epochs":num_epochs,
                   "mini_batches":batch_size,
                   "shuffle": shuffle,
                   "min_teacher_forcing_value":min_teacher_forcing_value,
                   "max_teacher_forcing_value":max_teacher_forcing_value}

suffix_data_split_value = bpic20_DD_train_dataset.min_suffix_size
print("Train seq length: ", suffix_data_split_value)

# GradNorm parameter: 
use_gradnorm = True
# use_gradnorm = False
# task to be balanced for teacher forcing
number_tasks = len(dec_feat[0]) + len(dec_feat[1])
# Grdanorm hyperparams
# alpha: tasks/ alpha value (rule of thumb): 2-3: 1.0-1.5, 4-6: 0.7-1.0, 7-10: 0.4-0.7
# Formula approx: 2/sqrt(tasks)
gn_alpha = 1.5
# learning rate: Adjust relative to model learning rate.
gn_learning_rate = 1e-4

gradNorm = {"use_gradnorm":use_gradnorm,
            "number_tasks": number_tasks,
            "gn_alpha":gn_alpha,
            "gn_learning_rate": gn_learning_rate}
# gradNorm = None

trainer = Trainer(device=device,
                  model=model,
                  data_train=bpic20_DD_train_dataset,
                  data_val=bpic20_DD_val_dataset,
                  loss_obj=loss_obj,
                  log_normal_loss_num_feature = [],
                  optimize_values=optimize_values,
                  suffix_data_split_value=suffix_data_split_value,
                  writer=writer,
                  gradnorm_values=gradNorm,
                  save_model_n_th_epoch = 1,
                  saving_path = 'BPIC20_DD_full_grad_norm_conformal_v2.pkl')

# Train the model:
# - use stattics: (tensor) tensor of seperate encoded static attributes which is merged with dynmaics beforehand
# - use zero padd masking: (True) mask the left padded zeros in the encoder
# - use EOS padd masking: (True) mask the right padded unwanted EOS tokens in the loss
train_attenuated_losses, val_losses, val_attenuated_losses = trainer.train_model(use_statics=True,
                                                                                 use_zero_padd_masking=True,
                                                                                 use_eos_padd_masking=True)
# Out:
# Train seq length:  5
# Device:  cuda
# Model:  DropoutUncertaintyEncoderDecoderLSTM(
#   (embeddings_enc): ModuleList(
#     (0): Embedding(18, 8)
#     (1): Embedding(4, 3)
#     (2): Embedding(9, 5)
#   )
#   (encoder): DropoutUncertaintyLSTMEncoder(
#     (embeddings): ModuleList(
#       (0): Embedding(18, 8)
#       (1): Embedding(4, 3)
#       (2): Embedding(9, 5)
#     )
#     (input_proj): Linear(in_features=21, out_features=128, bias=True)
#     (layernorm): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#     (act): ReLU()
#     (first_layer): DropoutUncertaintyLSTMCell(
#       (Wi): Linear(in_features=128, out_features=128, bias=True)
#       (Ui): Linear(in_features=128, out_features=128, bias=True)
#       (Wf): Linear(in_features=128, out_features=128, bias=True)
#       (Uf): Linear(in_features=128, out_features=128, bias=True)
#       (Wc): Linear(in_features=128, out_features=128, bias=True)
#       (Uc): Linear(in_features=128, out_features=128, bias=True)
#       (Wo): Linear(in_features=128, out_features=128, bias=True)
#       (Uo): Linear(in_features=128, out_features=128, bias=True)
#     )
#     (hidden_layers): ModuleList(
#       (0-2): 3 x DropoutUncertaintyLSTMCell(
#         (Wi): Linear(in_features=128, out_features=128, bias=True)
#         (Ui): Linear(in_features=128, out_features=128, bias=True)
#         (Wf): Linear(in_features=128, out_features=128, bias=True)
#         (Uf): Linear(in_features=128, out_features=128, bias=True)
#         (Wc): Linear(in_features=128, out_features=128, bias=True)
#         (Uc): Linear(in_features=128, out_features=128, bias=True)
#         (Wo): Linear(in_features=128, out_features=128, bias=True)
#         (Uo): Linear(in_features=128, out_features=128, bias=True)
#       )
#     )
#   )
#   (embeddings_dec): ModuleList(
#     (0): Embedding(18, 8)
#   )
#   (decoder): DropoutUncertaintyLSTMDecoder(
#     (embeddings): ModuleList(
#       (0): Embedding(18, 8)
#     )
#     (input_proj): Linear(in_features=10, out_features=128, bias=True)
#     (layernorm): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#     (act): ReLU()
#     (first_layer): DropoutUncertaintyLSTMCell(
#       (Wi): Linear(in_features=128, out_features=128, bias=True)
#       (Ui): Linear(in_features=128, out_features=128, bias=True)
#       (Wf): Linear(in_features=128, out_features=128, bias=True)
#       (Uf): Linear(in_features=128, out_features=128, bias=True)
#       (Wc): Linear(in_features=128, out_features=128, bias=True)
#       (Uc): Linear(in_features=128, out_features=128, bias=True)
#       (Wo): Linear(in_features=128, out_features=128, bias=True)
#       (Uo): Linear(in_features=128, out_features=128, bias=True)
#     )
#     (hidden_layers): ModuleList(
#       (0-2): 3 x DropoutUncertaintyLSTMCell(
#         (Wi): Linear(in_features=128, out_features=128, bias=True)
#         (Ui): Linear(in_features=128, out_features=128, bias=True)
#         (Wf): Linear(in_features=128, out_features=128, bias=True)
#         (Uf): Linear(in_features=128, out_features=128, bias=True)
#         (Wc): Linear(in_features=128, out_features=128, bias=True)
#         (Uc): Linear(in_features=128, out_features=128, bias=True)
#         (Wo): Linear(in_features=128, out_features=128, bias=True)
#         (Uo): Linear(in_features=128, out_features=128, bias=True)
#       )
#     )
#     (output_layers): ModuleDict(
#       (concept:name_mean): Linear(in_features=128, out_features=18, bias=True)
#       (concept:name_var): Linear(in_features=128, out_features=18, bias=True)
#       (case_elapsed_time_mean): Linear(in_features=128, out_features=1, bias=True)
#       (case_elapsed_time_var): Linear(in_features=128, out_features=1, bias=True)
#       (event_elapsed_time_mean): Linear(in_features=128, out_features=1, bias=True)
#       (event_elapsed_time_var): Linear(in_features=128, out_features=1, bias=True)
#     )
#   )
# )
# Train Dataset:  <event_log_loader.new_event_log_loader_v2.EventLogDataset object at 0x7fcabcf56630>
# Validation Dataset:  <event_log_loader.new_event_log_loader_v2.EventLogDataset object at 0x7fc985f02960>
# Loss object for method calling:  <loss.losses.Loss object at 0x7fc985f02e10>
# Num. feautures that follow log-normal PDF:  []
# regularization:  0.0001
# Optimizer:  AdamW (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     capturable: False
#     decoupled_weight_decay: True
#     differentiable: False
#     eps: 1e-08
#     foreach: None
#     fused: None
#     lr: 1e-05
#     maximize: False
#     weight_decay: 0
# )
# Scheduler:  <torch.optim.lr_scheduler.ReduceLROnPlateau object at 0x7fc97f6c4950>
# Epochs:  100
# Mini baches:  128
# Shuffle batched dataset:  True
# Use GradNorm:  True
# GradNorm alpha:  1.5
# GradNorm learning rate:  0.0001
# Initial GradNorm loss weights:  Parameter containing:
# tensor([1., 1., 1.], device='cuda:0', requires_grad=True)
# Initial loss values:  None
# GradNorm optimizer:  AdamW (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     capturable: False
#     decoupled_weight_decay: True
#     differentiable: False
#     eps: 1e-08
#     foreach: None
#     fused: None
#     lr: 0.0001
#     maximize: False
#     weight_decay: 0.01
# )
# Epoch [1/100], Learning Rate: 1e-05, Teacher forcing ratio: 1.0
# Training: Avg Attenuated Training Loss: 5.2423
# Validation: Avg Standard Validation Loss: 5.2279
# Validation: Avg Attenuated Validation Loss: 4.4758
# Validation Loss for Scheduler: 5.2279
# saving model
# Epoch [2/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.98
# Training: Avg Attenuated Training Loss: 5.0066
# Validation: Avg Standard Validation Loss: 4.9885
# Validation: Avg Attenuated Validation Loss: 4.1895
# Validation Loss for Scheduler: 4.9885
# saving model
# Epoch [3/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.96
# Training: Avg Attenuated Training Loss: 4.0129
# Validation: Avg Standard Validation Loss: 4.1508
# Validation: Avg Attenuated Validation Loss: 3.2068
# Validation Loss for Scheduler: 4.1508
# saving model
# Epoch [4/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.94
# Training: Avg Attenuated Training Loss: 2.9568
# Validation: Avg Standard Validation Loss: 3.9689
# Validation: Avg Attenuated Validation Loss: 3.3197
# Validation Loss for Scheduler: 3.9689
# saving model
# Epoch [5/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.92
# Training: Avg Attenuated Training Loss: 2.1975
# Validation: Avg Standard Validation Loss: 3.7983
# Validation: Avg Attenuated Validation Loss: 3.9918
# Validation Loss for Scheduler: 3.7983
# saving model
# Epoch [6/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.9
# Training: Avg Attenuated Training Loss: 1.7908
# Validation: Avg Standard Validation Loss: 3.7387
# Validation: Avg Attenuated Validation Loss: 5.1171
# Validation Loss for Scheduler: 3.7387
# saving model
# Epoch [7/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.88
# Training: Avg Attenuated Training Loss: 1.4492
# Validation: Avg Standard Validation Loss: 3.6034
# Validation: Avg Attenuated Validation Loss: 5.9058
# Validation Loss for Scheduler: 3.6034
# saving model
# Epoch [8/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.86
# Training: Avg Attenuated Training Loss: 1.0580
# Validation: Avg Standard Validation Loss: 3.5015
# Validation: Avg Attenuated Validation Loss: 6.8926
# Validation Loss for Scheduler: 3.5015
# saving model
# Epoch [9/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.84
# Training: Avg Attenuated Training Loss: 0.8458
# Validation: Avg Standard Validation Loss: 3.5185
# Validation: Avg Attenuated Validation Loss: 8.7610
# Validation Loss for Scheduler: 3.5185
# saving model
# Epoch [10/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.8200000000000001
# Training: Avg Attenuated Training Loss: 0.6639
# Validation: Avg Standard Validation Loss: 3.4283
# Validation: Avg Attenuated Validation Loss: 9.6028
# Validation Loss for Scheduler: 3.4283
# saving model
# Epoch [11/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.8
# Training: Avg Attenuated Training Loss: 0.6504
# Validation: Avg Standard Validation Loss: 3.4400
# Validation: Avg Attenuated Validation Loss: 11.7533
# Validation Loss for Scheduler: 3.4400
# saving model
# Epoch [12/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.78
# Training: Avg Attenuated Training Loss: 0.6336
# Validation: Avg Standard Validation Loss: 3.4200
# Validation: Avg Attenuated Validation Loss: 13.6960
# Validation Loss for Scheduler: 3.4200
# saving model
# Epoch [13/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.76
# Training: Avg Attenuated Training Loss: 0.4466
# Validation: Avg Standard Validation Loss: 3.2933
# Validation: Avg Attenuated Validation Loss: 12.5976
# Validation Loss for Scheduler: 3.2933
# saving model
# Epoch [14/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.74
# Training: Avg Attenuated Training Loss: 0.3404
# Validation: Avg Standard Validation Loss: 3.2122
# Validation: Avg Attenuated Validation Loss: 13.1007
# Validation Loss for Scheduler: 3.2122
# saving model
# Epoch [15/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.72
# Training: Avg Attenuated Training Loss: 0.2271
# Validation: Avg Standard Validation Loss: 3.2033
# Validation: Avg Attenuated Validation Loss: 14.3784
# Validation Loss for Scheduler: 3.2033
# saving model
# Epoch [16/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.7
# Training: Avg Attenuated Training Loss: 0.3380
# Validation: Avg Standard Validation Loss: 3.2014
# Validation: Avg Attenuated Validation Loss: 15.2975
# Validation Loss for Scheduler: 3.2014
# saving model
# Epoch [17/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.6799999999999999
# Training: Avg Attenuated Training Loss: 0.3722
# Validation: Avg Standard Validation Loss: 3.2109
# Validation: Avg Attenuated Validation Loss: 17.4586
# Validation Loss for Scheduler: 3.2109
# saving model
# Epoch [18/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.6599999999999999
# Training: Avg Attenuated Training Loss: 0.1974
# Validation: Avg Standard Validation Loss: 3.1759
# Validation: Avg Attenuated Validation Loss: 18.0335
# Validation Loss for Scheduler: 3.1759
# saving model
# Epoch [19/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.64
# Training: Avg Attenuated Training Loss: 0.0434
# Validation: Avg Standard Validation Loss: 3.1861
# Validation: Avg Attenuated Validation Loss: 20.0303
# Validation Loss for Scheduler: 3.1861
# saving model
# Epoch [20/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.62
# Training: Avg Attenuated Training Loss: 0.2442
# Validation: Avg Standard Validation Loss: 3.1737
# Validation: Avg Attenuated Validation Loss: 21.7929
# Validation Loss for Scheduler: 3.1737
# saving model
# Epoch [21/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.6
# Training: Avg Attenuated Training Loss: 0.0283
# Validation: Avg Standard Validation Loss: 3.1607
# Validation: Avg Attenuated Validation Loss: 23.4636
# Validation Loss for Scheduler: 3.1607
# saving model
# Epoch [22/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.5800000000000001
# Training: Avg Attenuated Training Loss: 0.4775
# Validation: Avg Standard Validation Loss: 3.1623
# Validation: Avg Attenuated Validation Loss: 24.9496
# Validation Loss for Scheduler: 3.1623
# saving model
# Epoch [23/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.56
# Training: Avg Attenuated Training Loss: 0.5467
# Validation: Avg Standard Validation Loss: 3.1794
# Validation: Avg Attenuated Validation Loss: 25.8913
# Validation Loss for Scheduler: 3.1794
# saving model
# Epoch [24/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.54
# Training: Avg Attenuated Training Loss: 0.5110
# Validation: Avg Standard Validation Loss: 3.1155
# Validation: Avg Attenuated Validation Loss: 23.4629
# Validation Loss for Scheduler: 3.1155
# saving model
# Epoch [25/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.52
# Training: Avg Attenuated Training Loss: 0.8092
# Validation: Avg Standard Validation Loss: 3.1754
# Validation: Avg Attenuated Validation Loss: 27.2786
# Validation Loss for Scheduler: 3.1754
# saving model
# Epoch [26/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.5
# Training: Avg Attenuated Training Loss: 2.3661
# Validation: Avg Standard Validation Loss: 3.1263
# Validation: Avg Attenuated Validation Loss: 25.1944
# Validation Loss for Scheduler: 3.1263
# saving model
# Epoch [27/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.48
# Training: Avg Attenuated Training Loss: 1.7871
# Validation: Avg Standard Validation Loss: 3.1094
# Validation: Avg Attenuated Validation Loss: 23.9889
# Validation Loss for Scheduler: 3.1094
# saving model
# Epoch [28/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.45999999999999996
# Training: Avg Attenuated Training Loss: 0.7567
# Validation: Avg Standard Validation Loss: 3.1040
# Validation: Avg Attenuated Validation Loss: 24.2841
# Validation Loss for Scheduler: 3.1040
# saving model
# Epoch [29/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.43999999999999995
# Training: Avg Attenuated Training Loss: 1.1681
# Validation: Avg Standard Validation Loss: 3.0902
# Validation: Avg Attenuated Validation Loss: 24.6564
# Validation Loss for Scheduler: 3.0902
# saving model
# Epoch [30/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.42000000000000004
# Training: Avg Attenuated Training Loss: 0.9807
# Validation: Avg Standard Validation Loss: 3.0962
# Validation: Avg Attenuated Validation Loss: 22.4032
# Validation Loss for Scheduler: 3.0962
# saving model
# Epoch [31/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.4
# Training: Avg Attenuated Training Loss: 1.0008
# Validation: Avg Standard Validation Loss: 3.0833
# Validation: Avg Attenuated Validation Loss: 22.9600
# Validation Loss for Scheduler: 3.0833
# saving model
# Epoch [32/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.38
# Training: Avg Attenuated Training Loss: 0.8626
# Validation: Avg Standard Validation Loss: 3.0340
# Validation: Avg Attenuated Validation Loss: 16.9530
# Validation Loss for Scheduler: 3.0340
# saving model
# Epoch [33/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.36
# Training: Avg Attenuated Training Loss: 0.7158
# Validation: Avg Standard Validation Loss: 3.0573
# Validation: Avg Attenuated Validation Loss: 21.9118
# Validation Loss for Scheduler: 3.0573
# saving model
# Epoch [34/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.33999999999999997
# Training: Avg Attenuated Training Loss: 0.9442
# Validation: Avg Standard Validation Loss: 3.0238
# Validation: Avg Attenuated Validation Loss: 19.1223
# Validation Loss for Scheduler: 3.0238
# saving model
# Epoch [35/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.31999999999999995
# Training: Avg Attenuated Training Loss: 0.8567
# Validation: Avg Standard Validation Loss: 2.9996
# Validation: Avg Attenuated Validation Loss: 15.3229
# Validation Loss for Scheduler: 2.9996
# saving model
# Epoch [36/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.30000000000000004
# Training: Avg Attenuated Training Loss: 2.1564
# Validation: Avg Standard Validation Loss: 2.9926
# Validation: Avg Attenuated Validation Loss: 16.7453
# Validation Loss for Scheduler: 2.9926
# saving model
# Epoch [37/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.28
# Training: Avg Attenuated Training Loss: 1.2212
# Validation: Avg Standard Validation Loss: 2.9798
# Validation: Avg Attenuated Validation Loss: 13.6641
# Validation Loss for Scheduler: 2.9798
# saving model
# Epoch [38/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.26
# Training: Avg Attenuated Training Loss: 1.0093
# Validation: Avg Standard Validation Loss: 2.9140
# Validation: Avg Attenuated Validation Loss: 8.9499
# Validation Loss for Scheduler: 2.9140
# saving model
# Epoch [39/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.24
# Training: Avg Attenuated Training Loss: 0.9513
# Validation: Avg Standard Validation Loss: 2.9574
# Validation: Avg Attenuated Validation Loss: 16.0089
# Validation Loss for Scheduler: 2.9574
# saving model
# Epoch [40/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.21999999999999997
# Training: Avg Attenuated Training Loss: 0.9639
# Validation: Avg Standard Validation Loss: 2.8998
# Validation: Avg Attenuated Validation Loss: 7.5414
# Validation Loss for Scheduler: 2.8998
# saving model
# Epoch [41/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.19999999999999996
# Training: Avg Attenuated Training Loss: 0.9185
# Validation: Avg Standard Validation Loss: 2.9009
# Validation: Avg Attenuated Validation Loss: 8.1203
# Validation Loss for Scheduler: 2.9009
# saving model
# Epoch [42/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.18000000000000005
# Training: Avg Attenuated Training Loss: 0.7813
# Validation: Avg Standard Validation Loss: 2.8869
# Validation: Avg Attenuated Validation Loss: 9.0225
# Validation Loss for Scheduler: 2.8869
# saving model
# Epoch [43/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.16000000000000003
# Training: Avg Attenuated Training Loss: 0.8842
# Validation: Avg Standard Validation Loss: 2.8748
# Validation: Avg Attenuated Validation Loss: 8.2076
# Validation Loss for Scheduler: 2.8748
# saving model
# Epoch [44/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.14
# Training: Avg Attenuated Training Loss: 0.9605
# Validation: Avg Standard Validation Loss: 2.8730
# Validation: Avg Attenuated Validation Loss: 9.0436
# Validation Loss for Scheduler: 2.8730
# saving model
# Epoch [45/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.12
# Training: Avg Attenuated Training Loss: 0.9299
# Validation: Avg Standard Validation Loss: 2.8940
# Validation: Avg Attenuated Validation Loss: 8.3070
# Validation Loss for Scheduler: 2.8940
# saving model
# Epoch [46/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.09999999999999998
# Training: Avg Attenuated Training Loss: 0.8692
# Validation: Avg Standard Validation Loss: 2.8730
# Validation: Avg Attenuated Validation Loss: 8.9737
# Validation Loss for Scheduler: 2.8730
# saving model
# Epoch [47/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.07999999999999996
# Training: Avg Attenuated Training Loss: 1.0569
# Validation: Avg Standard Validation Loss: 2.8510
# Validation: Avg Attenuated Validation Loss: 5.1594
# Validation Loss for Scheduler: 2.8510
# saving model
# Epoch [48/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.06000000000000005
# Training: Avg Attenuated Training Loss: 0.9594
# Validation: Avg Standard Validation Loss: 2.8314
# Validation: Avg Attenuated Validation Loss: 6.2173
# Validation Loss for Scheduler: 2.8314
# saving model
# Epoch [49/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.040000000000000036
# Training: Avg Attenuated Training Loss: 1.0177
# Validation: Avg Standard Validation Loss: 2.8233
# Validation: Avg Attenuated Validation Loss: 7.6703
# Validation Loss for Scheduler: 2.8233
# saving model
# Epoch [50/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.020000000000000018
# Training: Avg Attenuated Training Loss: 1.1992
# Validation: Avg Standard Validation Loss: 2.8384
# Validation: Avg Attenuated Validation Loss: 7.3318
# Validation Loss for Scheduler: 2.8384
# saving model
# Epoch [51/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.0
# Training: Avg Attenuated Training Loss: 1.1156
# Validation: Avg Standard Validation Loss: 2.8242
# Validation: Avg Attenuated Validation Loss: 6.1046
# Validation Loss for Scheduler: 2.8242
# saving model
# Epoch [52/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.0
# Training: Avg Attenuated Training Loss: 1.1667
# Validation: Avg Standard Validation Loss: 2.8091
# Validation: Avg Attenuated Validation Loss: 7.8037
# Validation Loss for Scheduler: 2.8091
# saving model
# Epoch [53/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.0
# Training: Avg Attenuated Training Loss: 1.0810
# Validation: Avg Standard Validation Loss: 2.8359
# Validation: Avg Attenuated Validation Loss: 7.6728
# Validation Loss for Scheduler: 2.8359
# saving model
# Epoch [54/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.0
# Training: Avg Attenuated Training Loss: 1.3766
# Validation: Avg Standard Validation Loss: 2.8286
# Validation: Avg Attenuated Validation Loss: 9.1279
# Validation Loss for Scheduler: 2.8286
# saving model
# Epoch [55/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.0
# Training: Avg Attenuated Training Loss: 1.1290
# Validation: Avg Standard Validation Loss: 2.8036
# Validation: Avg Attenuated Validation Loss: 6.8425
# Validation Loss for Scheduler: 2.8036
# saving model
# Epoch [56/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.0
# Training: Avg Attenuated Training Loss: 1.1605
# Validation: Avg Standard Validation Loss: 2.8116
# Validation: Avg Attenuated Validation Loss: 8.1975
# Validation Loss for Scheduler: 2.8116
# saving model
# Epoch [57/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.0
# Training: Avg Attenuated Training Loss: 1.3369
# Validation: Avg Standard Validation Loss: 2.7763
# Validation: Avg Attenuated Validation Loss: 8.1443
# Validation Loss for Scheduler: 2.7763
# saving model
# Epoch [58/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.0
# Training: Avg Attenuated Training Loss: 1.2159
# Validation: Avg Standard Validation Loss: 2.7885
# Validation: Avg Attenuated Validation Loss: 7.7444
# Validation Loss for Scheduler: 2.7885
# saving model
# Epoch [59/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.0
# Training: Avg Attenuated Training Loss: 1.3119
# Validation: Avg Standard Validation Loss: 2.7831
# Validation: Avg Attenuated Validation Loss: 7.5896
# Validation Loss for Scheduler: 2.7831
# saving model
# Epoch [60/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.0
# Training: Avg Attenuated Training Loss: 1.1802
# Validation: Avg Standard Validation Loss: 2.7997
# Validation: Avg Attenuated Validation Loss: 9.5598
# Validation Loss for Scheduler: 2.7997
# saving model
# Epoch [61/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.0
# Training: Avg Attenuated Training Loss: 1.1232
# Validation: Avg Standard Validation Loss: 2.7783
# Validation: Avg Attenuated Validation Loss: 8.6665
# Validation Loss for Scheduler: 2.7783
# saving model
# Epoch [62/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.0
# Training: Avg Attenuated Training Loss: 1.2717
# Validation: Avg Standard Validation Loss: 2.7762
# Validation: Avg Attenuated Validation Loss: 10.1092
# Validation Loss for Scheduler: 2.7762
# saving model
# Epoch [63/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.0
# Training: Avg Attenuated Training Loss: 1.3552
# Validation: Avg Standard Validation Loss: 2.7915
# Validation: Avg Attenuated Validation Loss: 8.8001
# Validation Loss for Scheduler: 2.7915
# saving model
# Epoch [64/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.0
# Training: Avg Attenuated Training Loss: 1.3932
# Validation: Avg Standard Validation Loss: 2.7846
# Validation: Avg Attenuated Validation Loss: 8.8645
# Validation Loss for Scheduler: 2.7846
# saving model
# Epoch [65/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.0
# Training: Avg Attenuated Training Loss: 1.1466
# Validation: Avg Standard Validation Loss: 2.7515
# Validation: Avg Attenuated Validation Loss: 9.4029
# Validation Loss for Scheduler: 2.7515
# saving model
# Epoch [66/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.0
# Training: Avg Attenuated Training Loss: 1.1953
# Validation: Avg Standard Validation Loss: 2.7328
# Validation: Avg Attenuated Validation Loss: 6.6849
# Validation Loss for Scheduler: 2.7328
# saving model
# Epoch [67/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.0
# Training: Avg Attenuated Training Loss: 1.2148
# Validation: Avg Standard Validation Loss: 2.7546
# Validation: Avg Attenuated Validation Loss: 9.7892
# Validation Loss for Scheduler: 2.7546
# saving model
# Epoch [68/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.0
# Training: Avg Attenuated Training Loss: 1.1554
# Validation: Avg Standard Validation Loss: 2.7447
# Validation: Avg Attenuated Validation Loss: 7.1094
# Validation Loss for Scheduler: 2.7447
# saving model
# Epoch [69/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.0
# Training: Avg Attenuated Training Loss: 1.1872
# Validation: Avg Standard Validation Loss: 2.7248
# Validation: Avg Attenuated Validation Loss: 6.6659
# Validation Loss for Scheduler: 2.7248
# saving model
# Epoch [70/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.0
# Training: Avg Attenuated Training Loss: 1.1183
# Validation: Avg Standard Validation Loss: 2.7319
# Validation: Avg Attenuated Validation Loss: 7.4870
# Validation Loss for Scheduler: 2.7319
# saving model
# Epoch [71/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.0
# Training: Avg Attenuated Training Loss: 1.1216
# Validation: Avg Standard Validation Loss: 2.7087
# Validation: Avg Attenuated Validation Loss: 9.3451
# Validation Loss for Scheduler: 2.7087
# saving model
# Epoch [72/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.0
# Training: Avg Attenuated Training Loss: 1.1408
# Validation: Avg Standard Validation Loss: 2.7026
# Validation: Avg Attenuated Validation Loss: 8.6555
# Validation Loss for Scheduler: 2.7026
# saving model
# Epoch [73/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.0
# Training: Avg Attenuated Training Loss: 1.1787
# Validation: Avg Standard Validation Loss: 2.7037
# Validation: Avg Attenuated Validation Loss: 10.4261
# Validation Loss for Scheduler: 2.7037
# saving model
# Epoch [74/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.0
# Training: Avg Attenuated Training Loss: 1.1561
# Validation: Avg Standard Validation Loss: 2.6877
# Validation: Avg Attenuated Validation Loss: 7.8093
# Validation Loss for Scheduler: 2.6877
# saving model
# Epoch [75/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.0
# Training: Avg Attenuated Training Loss: 1.1357
# Validation: Avg Standard Validation Loss: 2.7142
# Validation: Avg Attenuated Validation Loss: 8.1831
# Validation Loss for Scheduler: 2.7142
# saving model
# Epoch [76/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.0
# Training: Avg Attenuated Training Loss: 1.1427
# Validation: Avg Standard Validation Loss: 2.7419
# Validation: Avg Attenuated Validation Loss: 8.5748
# Validation Loss for Scheduler: 2.7419
# saving model
# Epoch [77/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.0
# Training: Avg Attenuated Training Loss: 1.3580
# Validation: Avg Standard Validation Loss: 2.6968
# Validation: Avg Attenuated Validation Loss: 9.4402
# Validation Loss for Scheduler: 2.6968
# saving model
# Epoch [78/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.0
# Training: Avg Attenuated Training Loss: 1.0901
# Validation: Avg Standard Validation Loss: 2.6863
# Validation: Avg Attenuated Validation Loss: 8.0739
# Validation Loss for Scheduler: 2.6863
# saving model
# Epoch [79/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.0
# Training: Avg Attenuated Training Loss: 1.1352
# Validation: Avg Standard Validation Loss: 2.6723
# Validation: Avg Attenuated Validation Loss: 7.3443
# Validation Loss for Scheduler: 2.6723
# saving model
# Epoch [80/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.0
# Training: Avg Attenuated Training Loss: 1.2835
# Validation: Avg Standard Validation Loss: 2.6672
# Validation: Avg Attenuated Validation Loss: 8.8552
# Validation Loss for Scheduler: 2.6672
# saving model
# Epoch [81/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.0
# Training: Avg Attenuated Training Loss: 1.2264
# Validation: Avg Standard Validation Loss: 2.6838
# Validation: Avg Attenuated Validation Loss: 9.2531
# Validation Loss for Scheduler: 2.6838
# saving model
# Epoch [82/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.0
# Training: Avg Attenuated Training Loss: 1.1757
# Validation: Avg Standard Validation Loss: 2.6590
# Validation: Avg Attenuated Validation Loss: 9.5751
# Validation Loss for Scheduler: 2.6590
# saving model
# Epoch [83/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.0
# Training: Avg Attenuated Training Loss: 1.2797
# Validation: Avg Standard Validation Loss: 2.6719
# Validation: Avg Attenuated Validation Loss: 8.2563
# Validation Loss for Scheduler: 2.6719
# saving model
# Epoch [84/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.0
# Training: Avg Attenuated Training Loss: 1.2705
# Validation: Avg Standard Validation Loss: 2.6742
# Validation: Avg Attenuated Validation Loss: 9.6965
# Validation Loss for Scheduler: 2.6742
# saving model
# Epoch [85/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.0
# Training: Avg Attenuated Training Loss: 1.3507
# Validation: Avg Standard Validation Loss: 2.6502
# Validation: Avg Attenuated Validation Loss: 9.7212
# Validation Loss for Scheduler: 2.6502
# saving model
# Epoch [86/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.0
# Training: Avg Attenuated Training Loss: 1.2329
# Validation: Avg Standard Validation Loss: 2.6693
# Validation: Avg Attenuated Validation Loss: 8.5646
# Validation Loss for Scheduler: 2.6693
# saving model
# Epoch [87/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.0
# Training: Avg Attenuated Training Loss: 1.3236
# Validation: Avg Standard Validation Loss: 2.6324
# Validation: Avg Attenuated Validation Loss: 9.6053
# Validation Loss for Scheduler: 2.6324
# saving model
# Epoch [88/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.0
# Training: Avg Attenuated Training Loss: 1.3134
# Validation: Avg Standard Validation Loss: 2.6093
# Validation: Avg Attenuated Validation Loss: 7.4788
# Validation Loss for Scheduler: 2.6093
# saving model
# Epoch [89/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.0
# Training: Avg Attenuated Training Loss: 1.2639
# Validation: Avg Standard Validation Loss: 2.6482
# Validation: Avg Attenuated Validation Loss: 9.8303
# Validation Loss for Scheduler: 2.6482
# saving model
# Epoch [90/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.0
# Training: Avg Attenuated Training Loss: 1.3032
# Validation: Avg Standard Validation Loss: 2.6146
# Validation: Avg Attenuated Validation Loss: 9.0504
# Validation Loss for Scheduler: 2.6146
# saving model
# Epoch [91/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.0
# Training: Avg Attenuated Training Loss: 1.2924
# Validation: Avg Standard Validation Loss: 2.6425
# Validation: Avg Attenuated Validation Loss: 8.4606
# Validation Loss for Scheduler: 2.6425
# saving model
# Epoch [92/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.0
# Training: Avg Attenuated Training Loss: 1.2990
# Validation: Avg Standard Validation Loss: 2.6330
# Validation: Avg Attenuated Validation Loss: 8.6807
# Validation Loss for Scheduler: 2.6330
# saving model
# Epoch [93/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.0
# Training: Avg Attenuated Training Loss: 1.3109
# Validation: Avg Standard Validation Loss: 2.6468
# Validation: Avg Attenuated Validation Loss: 8.6354
# Validation Loss for Scheduler: 2.6468
# saving model
# Epoch [94/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.0
# Training: Avg Attenuated Training Loss: 1.3443
# Validation: Avg Standard Validation Loss: 2.6190
# Validation: Avg Attenuated Validation Loss: 8.9152
# Validation Loss for Scheduler: 2.6190
# saving model
# Epoch [95/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.0
# Training: Avg Attenuated Training Loss: 1.3446
# Validation: Avg Standard Validation Loss: 2.6182
# Validation: Avg Attenuated Validation Loss: 8.2667
# Validation Loss for Scheduler: 2.6182
# saving model
# Epoch [96/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.0
# Training: Avg Attenuated Training Loss: 1.2704
# Validation: Avg Standard Validation Loss: 2.6274
# Validation: Avg Attenuated Validation Loss: 8.6009
# Validation Loss for Scheduler: 2.6274
# saving model
# Epoch [97/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.0
# Training: Avg Attenuated Training Loss: 1.3401
# Validation: Avg Standard Validation Loss: 2.6215
# Validation: Avg Attenuated Validation Loss: 8.1033
# Validation Loss for Scheduler: 2.6215
# saving model
# Epoch [98/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.0
# Training: Avg Attenuated Training Loss: 1.2971
# Validation: Avg Standard Validation Loss: 2.6104
# Validation: Avg Attenuated Validation Loss: 8.1997
# Validation Loss for Scheduler: 2.6104
# saving model
# Epoch [99/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.0
# Training: Avg Attenuated Training Loss: 1.3904
# Validation: Avg Standard Validation Loss: 2.6183
# Validation: Avg Attenuated Validation Loss: 8.1478
# Validation Loss for Scheduler: 2.6183
# saving model
# Epoch [100/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.0
# Training: Avg Attenuated Training Loss: 1.3448
# Validation: Avg Standard Validation Loss: 2.6176
# Validation: Avg Attenuated Validation Loss: 6.5425
# Validation Loss for Scheduler: 2.6176
# saving model
# Training complete.
# Model saved to path: BPIC20_DD_full_grad_norm_conformal_v2.pkl

# %% [markdown]
# # Training Visualization

# %%
import matplotlib.pyplot as plt

# After training is finished, plot the loss curves
plt.plot(range(1, num_epochs+1), train_attenuated_losses, label='Training Attenuated Loss', color='blue')
plt.plot(range(1, num_epochs+1), val_losses, label='Validation Loss', color='orange')
plt.plot(range(1, num_epochs+1), val_attenuated_losses, label='Validation Attenuated Loss', color='green')
# Labeling x and y axes
plt.xlabel('Epochs', fontsize=12)
plt.ylabel('Loss', fontsize=12)
# Adding title
plt.title('Training and Validation Loss Curve', fontsize=14)
# Adding legend
plt.legend()
# Show the plot
plt.show()
