# %% [markdown]
# # Imports

# %%
import importlib
import sys

# performance imports for torch: torch kernel uses one core only.
import os
os.environ["OMP_NUM_THREADS"] = "1"
os.environ["MKL_NUM_THREADS"] = "1"
os.environ["TORCH_NUM_THREADS"] = "1" 

import torch

sys.path.insert(0, '..')
sys.path.insert(0, '../..')
sys.path.insert(0, '../../..')

# %% [markdown]
# # Data

# %% [markdown]
# ### Load Data Files

# %%
# Path to your pickle file (saved with torch.save)
file_path_train = '../../../../encoded_data_v2/BPIC20_DD/bpic20_DD_all_5_train.pkl'
# Load the dataset using torch.load
bpic20_DD_train_dataset = torch.load(file_path_train, weights_only=False)

# Path to your pickle file (saved with torch.save)
file_path_val = '../../../../encoded_data_v2/BPIC20_DD/bpic20_DD_all_5_val.pkl'
# Load the dataset using torch.load
bpic20_DD_val_dataset = torch.load(file_path_val, weights_only=False)

# %% [markdown]
# ### Train Data Insights

# %%
# Helpdesk dataset dynamic categories, features:
bpic20_DD_all_categories = bpic20_DD_train_dataset.all_categories

bpic20_DD_all_categories_cat = bpic20_DD_all_categories[0]
# print(helpdesk_all_categories_cat)
bpic20_DD_all_categories_num = bpic20_DD_all_categories[1]
# print(helpdesk_all_categories_num)
for i, cat in enumerate(bpic20_DD_all_categories_cat):
     print(f"BPIC20_DD dynamic categorical feature: {cat[0]}, Index position in categorical data list: {i}")
     print(f"BPIC20_DD amount of category labels: {cat[1]}")
print('\n')    
for i, num in enumerate(bpic20_DD_all_categories_num):
     print(f"BPIC20_DD dynamic numerical feature: {num[0]}, Index position in categorical data list: {i}")
     print(f"BPIC20_DD amount of numerical: {num[1]}")
print('\n')
     
# Helpdesk dataset static categories, features:
bpic20_DD_all_stat_categories = bpic20_DD_train_dataset.all_static_categories

bpic20_DD_all_stat_categories_cat = bpic20_DD_all_stat_categories[0]
# print(helpdesk_all_stat_categories_cat)
bpic20_DD_all_stat_categories_num = bpic20_DD_all_stat_categories[1]
# print(helpdesk_all_stat_categories_num)
for i, cat in enumerate(bpic20_DD_all_stat_categories_cat):
     print(f"BPIC20_DD static categorical feature: {cat[0]}, Index position in categorical data list: {i}")
     print(f"BPIC20_DD amount of category labels: {cat[1]}")
print('\n')    
for i, num in enumerate(bpic20_DD_all_stat_categories_num):
     print(f"BPIC20_DD static numerical feature: {num[0]}, Index position in categorical data list: {i}")
     print(f"BPIC20_DD amount of numerical: {num[1]}")
# Out:
# BPIC20_DD dynamic categorical feature: concept:name, Index position in categorical data list: 0
# BPIC20_DD amount of category labels: 18
# BPIC20_DD dynamic categorical feature: org:resource, Index position in categorical data list: 1
# BPIC20_DD amount of category labels: 4
# BPIC20_DD dynamic categorical feature: org:role, Index position in categorical data list: 2
# BPIC20_DD amount of category labels: 9
#
#
# BPIC20_DD dynamic numerical feature: case_elapsed_time, Index position in categorical data list: 0
# BPIC20_DD amount of numerical: 1
# BPIC20_DD dynamic numerical feature: event_elapsed_time, Index position in categorical data list: 1
# BPIC20_DD amount of numerical: 1
# BPIC20_DD dynamic numerical feature: day_in_week, Index position in categorical data list: 2
# BPIC20_DD amount of numerical: 1
# BPIC20_DD dynamic numerical feature: seconds_in_day, Index position in categorical data list: 3
# BPIC20_DD amount of numerical: 1
#
#
#
#
# BPIC20_DD static numerical feature: case:Amount, Index position in categorical data list: 0
# BPIC20_DD amount of numerical: 1

# %% [markdown]
# ### Input Features for Encoder and Decoder

# %%
# Create lists with name of Encoder features (input) and decoder features (input & output)
# Encoder features:
enc_feat_cat = []
enc_feat_num = []
for cat in bpic20_DD_all_categories_cat:
    enc_feat_cat.append(cat[0])
for num in bpic20_DD_all_categories_num:
    enc_feat_num.append(num[0])
enc_feat = [enc_feat_cat, enc_feat_num]
print("Input features encoder: ", enc_feat)

# Static encoder features:
stat_enc_feat_cat = []
stat_enc_feat_num = []
for cat in bpic20_DD_all_stat_categories_cat:
     stat_enc_feat_cat.append(cat[0])
for num in bpic20_DD_all_stat_categories_num:
     stat_enc_feat_num.append(num[0])
stat_enc_feat = [stat_enc_feat_cat, stat_enc_feat_num]
print("Input features static encoder: ", stat_enc_feat)

# Decoder features:
dec_feat_cat = ['concept:name']
dec_feat_num = ['case_elapsed_time', 'event_elapsed_time']
dec_feat = [dec_feat_cat, dec_feat_num]
print("Features decoder: ", dec_feat)
# Out:
# Input features encoder:  [['concept:name', 'org:resource', 'org:role'], ['case_elapsed_time', 'event_elapsed_time', 'day_in_week', 'seconds_in_day']]
# Input features static encoder:  [[], ['case:Amount']]
# Features decoder:  [['concept:name'], ['case_elapsed_time', 'event_elapsed_time']]

# %% [markdown]
# # Model

# %%
import model.dropout_uncertainty_enc_dec_LSTM.dropout_uncertainty_model
importlib.reload(model.dropout_uncertainty_enc_dec_LSTM.dropout_uncertainty_model)
from model.dropout_uncertainty_enc_dec_LSTM.dropout_uncertainty_model import DropoutUncertaintyEncoderDecoderLSTM

# Prediction decoder output sequence length
seq_len_pred = bpic20_DD_train_dataset.min_suffix_size

# Size hidden layer
hidden_size = 128

# Number of cells
num_layers = 4

# Fixed Dropout probability 
# Experiment with different values but be carefull with exploiting gradients:
dropout = 0.1

# Encoder Decoder model initialization
model = DropoutUncertaintyEncoderDecoderLSTM(data_set_categories=bpic20_DD_all_categories,
                                             enc_feat=enc_feat,
                                             dec_feat=dec_feat,
                                             seq_len_pred=seq_len_pred,
                                             hidden_size=hidden_size,
                                             num_layers=num_layers,
                                             dropout=dropout,
                                             # static attributes
                                             static_data_set_categories=bpic20_DD_all_stat_categories,
                                             static_enc_feat=stat_enc_feat
                                             )
# Out:
# Dynamic data set categories:  ([('concept:name', 18, {'Declaration APPROVED by ADMINISTRATION': 1, 'Declaration APPROVED by BUDGET OWNER': 2, 'Declaration APPROVED by PRE_APPROVER': 3, 'Declaration FINAL_APPROVED by SUPERVISOR': 4, 'Declaration FOR_APPROVAL by ADMINISTRATION': 5, 'Declaration FOR_APPROVAL by SUPERVISOR': 6, 'Declaration REJECTED by ADMINISTRATION': 7, 'Declaration REJECTED by BUDGET OWNER': 8, 'Declaration REJECTED by EMPLOYEE': 9, 'Declaration REJECTED by MISSING': 10, 'Declaration REJECTED by PRE_APPROVER': 11, 'Declaration REJECTED by SUPERVISOR': 12, 'Declaration SAVED by EMPLOYEE': 13, 'Declaration SUBMITTED by EMPLOYEE': 14, 'EOS': 15, 'Payment Handled': 16, 'Request Payment': 17}), ('org:resource', 4, {'EOS': 1, 'STAFF MEMBER': 2, 'SYSTEM': 3}), ('org:role', 9, {'ADMINISTRATION': 1, 'BUDGET OWNER': 2, 'EMPLOYEE': 3, 'EOS': 4, 'MISSING': 5, 'PRE_APPROVER': 6, 'SUPERVISOR': 7, 'UNDEFINED': 8})], [('case_elapsed_time', 1, {}), ('event_elapsed_time', 1, {}), ('day_in_week', 1, {}), ('seconds_in_day', 1, {})])
# Data set static categories:  ([], [('case:Amount', 1, {})])
# Encoder dynamic input features:  [['concept:name', 'org:resource', 'org:role'], ['case_elapsed_time', 'event_elapsed_time', 'day_in_week', 'seconds_in_day']]
# Encoder static input features:  [[], ['case:Amount']]
# Decoder input and output features:  [['concept:name'], ['case_elapsed_time', 'event_elapsed_time']]
# Sequence length of decoder output:  5
#
#
# LSTM cells and FC hidden size:  128
# Number of LSTM layer:  4
# Dropout rate:  0.1
#
#
# Encoder dynamic:
# Encoder number of labels for each input feature (categorical, numerical):  [[18, 4, 9], [1, 1, 1, 1]]
# Encoder indices of tensors in dataset used as input:  [[0, 1, 2], [0, 1, 2, 3]]
# Embeddings encoder:  ModuleList(
#   (0): Embedding(18, 8)
#   (1): Embedding(4, 3)
#   (2): Embedding(9, 5)
# )
# Total embedding feature size encoder:  16
# Total numerical feature size encoder:  4
# Input feature size encoder:  20
#
#
# Encoder static:
# Encoder number of labels for each input feature (categorical, numerical):  [[], [1]]
# Encoder indices of tensors in dataset used as input (static):  [[], [0]]
# Total embedding feature size encoder (static):  0
# Total numerical feature size encoder (static):  1
# Static encoder feature size:  1
# Encoder initialized!
#
# Decoder label values size for each categorical input feature:  [18]
# Decoder label values size for each numerical input feature:  [1, 1]
# Decoder indices of tensors in dataset used as input:  [[0], [0, 1]]
# Embeddings decoder:  ModuleList(
#   (0): Embedding(18, 8)
# )
# Total embedding feature size decoder:  8
# Total numerical feature size decoder:  2
# Input feature size decoder:  10
# Output feature list of dicts (featue name, feature output size) of decoder:  [{'concept:name': 18}, {'case_elapsed_time': 1, 'event_elapsed_time': 1}]
# Decoder initialized!

# %% [markdown]
# # Loss Object Creation

# %%
import loss.losses
importlib.reload(loss.losses)
from loss.losses import Loss

loss_obj = Loss()

# %% [markdown]
# # Training Configuration

# %%
import trainer.trainer
importlib.reload(trainer.trainer)
from trainer.trainer import Trainer
from torch.optim.lr_scheduler import ReduceLROnPlateau
from torch.utils.tensorboard import SummaryWriter

writer = SummaryWriter(comment="Full_BPIC20_grad")

# device
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Start learning rate
learning_rate = 1e-5
weight_decay = 0

# Optimizer and Scheduler
optimizer = torch.optim.AdamW(params=model.parameters(), lr=learning_rate, weight_decay=weight_decay)
scheduler = ReduceLROnPlateau(optimizer, mode='min', factor=0.1, patience=15, min_lr=1e-8)

# Epochs
num_epochs = 100

# Batches
batch_size = 128

# lambda for L2 (weight, bias, dropout) regularization
# regularization_term = 1.0/(2.0*batch_size)
regularization_term = 1e-4

# shuffle data
shuffle = True

# teacher forcing
max_teacher_forcing_value = 1.0
min_teacher_forcing_value = 0.0

optimize_values = {"regularization_term":regularization_term,
                   "optimizer":optimizer,
                   "scheduler": scheduler,
                   "epochs":num_epochs,
                   "mini_batches":batch_size,
                   "shuffle": shuffle,
                   "min_teacher_forcing_value":min_teacher_forcing_value,
                   "max_teacher_forcing_value":max_teacher_forcing_value}

suffix_data_split_value = bpic20_DD_train_dataset.min_suffix_size
print("Train seq length: ", suffix_data_split_value)

# GradNorm parameter: 
use_gradnorm = True
# use_gradnorm = False
# task to be balanced for teacher forcing
number_tasks = len(dec_feat[0]) + len(dec_feat[1])
# Grdanorm hyperparams
# alpha: tasks/ alpha value (rule of thumb): 2-3: 1.0-1.5, 4-6: 0.7-1.0, 7-10: 0.4-0.7
# Formula approx: 2/sqrt(tasks)
gn_alpha = 1.5
# learning rate: Adjust relative to model learning rate.
gn_learning_rate = 1e-4

gradNorm = {"use_gradnorm":use_gradnorm,
            "number_tasks": number_tasks,
            "gn_alpha":gn_alpha,
            "gn_learning_rate": gn_learning_rate}
# gradNorm = None

trainer = Trainer(device=device,
                  model=model,
                  data_train=bpic20_DD_train_dataset,
                  data_val=bpic20_DD_val_dataset,
                  loss_obj=loss_obj,
                  log_normal_loss_num_feature = [],
                  optimize_values=optimize_values,
                  suffix_data_split_value=suffix_data_split_value,
                  writer=writer,
                  gradnorm_values=gradNorm,
                  save_model_n_th_epoch = 1,
                  saving_path = 'BPIC20_DD_full_grad_norm_new_v2.pkl')

# Train the model:
# - use stattics: (tensor) tensor of seperate encoded static attributes which is merged with dynmaics beforehand
# - use zero padd masking: (True) mask the left padded zeros in the encoder
# - use EOS padd masking: (True) mask the right padded unwanted EOS tokens in the loss
train_attenuated_losses, val_losses, val_attenuated_losses = trainer.train_model(use_statics=True,
                                                                                 use_zero_padd_masking=True,
                                                                                 use_eos_padd_masking=True)
# Out:
# Train seq length:  5
# Device:  cuda
# Model:  DropoutUncertaintyEncoderDecoderLSTM(
#   (embeddings_enc): ModuleList(
#     (0): Embedding(18, 8)
#     (1): Embedding(4, 3)
#     (2): Embedding(9, 5)
#   )
#   (encoder): DropoutUncertaintyLSTMEncoder(
#     (embeddings): ModuleList(
#       (0): Embedding(18, 8)
#       (1): Embedding(4, 3)
#       (2): Embedding(9, 5)
#     )
#     (input_proj): Linear(in_features=21, out_features=128, bias=True)
#     (layernorm): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#     (act): ReLU()
#     (first_layer): DropoutUncertaintyLSTMCell(
#       (Wi): Linear(in_features=128, out_features=128, bias=True)
#       (Ui): Linear(in_features=128, out_features=128, bias=True)
#       (Wf): Linear(in_features=128, out_features=128, bias=True)
#       (Uf): Linear(in_features=128, out_features=128, bias=True)
#       (Wc): Linear(in_features=128, out_features=128, bias=True)
#       (Uc): Linear(in_features=128, out_features=128, bias=True)
#       (Wo): Linear(in_features=128, out_features=128, bias=True)
#       (Uo): Linear(in_features=128, out_features=128, bias=True)
#     )
#     (hidden_layers): ModuleList(
#       (0-2): 3 x DropoutUncertaintyLSTMCell(
#         (Wi): Linear(in_features=128, out_features=128, bias=True)
#         (Ui): Linear(in_features=128, out_features=128, bias=True)
#         (Wf): Linear(in_features=128, out_features=128, bias=True)
#         (Uf): Linear(in_features=128, out_features=128, bias=True)
#         (Wc): Linear(in_features=128, out_features=128, bias=True)
#         (Uc): Linear(in_features=128, out_features=128, bias=True)
#         (Wo): Linear(in_features=128, out_features=128, bias=True)
#         (Uo): Linear(in_features=128, out_features=128, bias=True)
#       )
#     )
#   )
#   (embeddings_dec): ModuleList(
#     (0): Embedding(18, 8)
#   )
#   (decoder): DropoutUncertaintyLSTMDecoder(
#     (embeddings): ModuleList(
#       (0): Embedding(18, 8)
#     )
#     (input_proj): Linear(in_features=10, out_features=128, bias=True)
#     (layernorm): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#     (act): ReLU()
#     (first_layer): DropoutUncertaintyLSTMCell(
#       (Wi): Linear(in_features=128, out_features=128, bias=True)
#       (Ui): Linear(in_features=128, out_features=128, bias=True)
#       (Wf): Linear(in_features=128, out_features=128, bias=True)
#       (Uf): Linear(in_features=128, out_features=128, bias=True)
#       (Wc): Linear(in_features=128, out_features=128, bias=True)
#       (Uc): Linear(in_features=128, out_features=128, bias=True)
#       (Wo): Linear(in_features=128, out_features=128, bias=True)
#       (Uo): Linear(in_features=128, out_features=128, bias=True)
#     )
#     (hidden_layers): ModuleList(
#       (0-2): 3 x DropoutUncertaintyLSTMCell(
#         (Wi): Linear(in_features=128, out_features=128, bias=True)
#         (Ui): Linear(in_features=128, out_features=128, bias=True)
#         (Wf): Linear(in_features=128, out_features=128, bias=True)
#         (Uf): Linear(in_features=128, out_features=128, bias=True)
#         (Wc): Linear(in_features=128, out_features=128, bias=True)
#         (Uc): Linear(in_features=128, out_features=128, bias=True)
#         (Wo): Linear(in_features=128, out_features=128, bias=True)
#         (Uo): Linear(in_features=128, out_features=128, bias=True)
#       )
#     )
#     (output_layers): ModuleDict(
#       (concept:name_mean): Linear(in_features=128, out_features=18, bias=True)
#       (concept:name_var): Linear(in_features=128, out_features=18, bias=True)
#       (case_elapsed_time_mean): Linear(in_features=128, out_features=1, bias=True)
#       (case_elapsed_time_var): Linear(in_features=128, out_features=1, bias=True)
#       (event_elapsed_time_mean): Linear(in_features=128, out_features=1, bias=True)
#       (event_elapsed_time_var): Linear(in_features=128, out_features=1, bias=True)
#     )
#   )
# )
# Train Dataset:  <event_log_loader.new_event_log_loader_v2.EventLogDataset object at 0x7f17b9eeb9b0>
# Validation Dataset:  <event_log_loader.new_event_log_loader_v2.EventLogDataset object at 0x7f17a9afd9d0>
# Loss object for method calling:  <loss.losses.Loss object at 0x7f17b9e1a3c0>
# Num. feautures that follow log-normal PDF:  []
# regularization:  0.0001
# Optimizer:  AdamW (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     capturable: False
#     decoupled_weight_decay: True
#     differentiable: False
#     eps: 1e-08
#     foreach: None
#     fused: None
#     lr: 1e-05
#     maximize: False
#     weight_decay: 0
# )
# Scheduler:  <torch.optim.lr_scheduler.ReduceLROnPlateau object at 0x7f17a8802480>
# Epochs:  100
# Mini baches:  128
# Shuffle batched dataset:  True
# Use GradNorm:  True
# GradNorm alpha:  1.5
# GradNorm learning rate:  0.0001
# Initial GradNorm loss weights:  Parameter containing:
# tensor([1., 1., 1.], device='cuda:0', requires_grad=True)
# Initial loss values:  None
# GradNorm optimizer:  AdamW (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     capturable: False
#     decoupled_weight_decay: True
#     differentiable: False
#     eps: 1e-08
#     foreach: None
#     fused: None
#     lr: 0.0001
#     maximize: False
#     weight_decay: 0.01
# )
# Epoch [1/100], Learning Rate: 1e-05, Teacher forcing ratio: 1.0
# Training: Avg Attenuated Training Loss: 5.2054
# Validation: Avg Standard Validation Loss: 4.9592
# Validation: Avg Attenuated Validation Loss: 4.3688
# Validation Loss for Scheduler: 4.9592
# saving model
# Epoch [2/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.98
# Training: Avg Attenuated Training Loss: 4.9990
# Validation: Avg Standard Validation Loss: 4.7162
# Validation: Avg Attenuated Validation Loss: 4.1443
# Validation Loss for Scheduler: 4.7162
# saving model
# Epoch [3/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.96
# Training: Avg Attenuated Training Loss: 4.1143
# Validation: Avg Standard Validation Loss: 3.8035
# Validation: Avg Attenuated Validation Loss: 3.0327
# Validation Loss for Scheduler: 3.8035
# saving model
# Epoch [4/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.94
# Training: Avg Attenuated Training Loss: 3.0660
# Validation: Avg Standard Validation Loss: 3.6265
# Validation: Avg Attenuated Validation Loss: 2.8733
# Validation Loss for Scheduler: 3.6265
# saving model
# Epoch [5/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.92
# Training: Avg Attenuated Training Loss: 2.3481
# Validation: Avg Standard Validation Loss: 3.4667
# Validation: Avg Attenuated Validation Loss: 3.2744
# Validation Loss for Scheduler: 3.4667
# saving model
# Epoch [6/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.9
# Training: Avg Attenuated Training Loss: 1.8412
# Validation: Avg Standard Validation Loss: 3.3788
# Validation: Avg Attenuated Validation Loss: 3.9535
# Validation Loss for Scheduler: 3.3788
# saving model
# Epoch [7/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.88
# Training: Avg Attenuated Training Loss: 1.4768
# Validation: Avg Standard Validation Loss: 3.2939
# Validation: Avg Attenuated Validation Loss: 4.6640
# Validation Loss for Scheduler: 3.2939
# saving model
# Epoch [8/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.86
# Training: Avg Attenuated Training Loss: 1.2218
# Validation: Avg Standard Validation Loss: 3.3790
# Validation: Avg Attenuated Validation Loss: 5.4999
# Validation Loss for Scheduler: 3.3790
# saving model
# Epoch [9/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.84
# Training: Avg Attenuated Training Loss: 1.0127
# Validation: Avg Standard Validation Loss: 3.0331
# Validation: Avg Attenuated Validation Loss: 5.9730
# Validation Loss for Scheduler: 3.0331
# saving model
# Epoch [10/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.8200000000000001
# Training: Avg Attenuated Training Loss: 0.7662
# Validation: Avg Standard Validation Loss: 3.0777
# Validation: Avg Attenuated Validation Loss: 7.1768
# Validation Loss for Scheduler: 3.0777
# saving model
# Epoch [11/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.8
# Training: Avg Attenuated Training Loss: 0.5965
# Validation: Avg Standard Validation Loss: 3.0274
# Validation: Avg Attenuated Validation Loss: 8.6539
# Validation Loss for Scheduler: 3.0274
# saving model
# Epoch [12/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.78
# Training: Avg Attenuated Training Loss: 0.4929
# Validation: Avg Standard Validation Loss: 2.9974
# Validation: Avg Attenuated Validation Loss: 10.0929
# Validation Loss for Scheduler: 2.9974
# saving model
# Epoch [13/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.76
# Training: Avg Attenuated Training Loss: 0.5397
# Validation: Avg Standard Validation Loss: 2.9759
# Validation: Avg Attenuated Validation Loss: 11.5119
# Validation Loss for Scheduler: 2.9759
# saving model
# Epoch [14/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.74
# Training: Avg Attenuated Training Loss: 0.3485
# Validation: Avg Standard Validation Loss: 2.9813
# Validation: Avg Attenuated Validation Loss: 12.7575
# Validation Loss for Scheduler: 2.9813
# saving model
# Epoch [15/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.72
# Training: Avg Attenuated Training Loss: 0.4333
# Validation: Avg Standard Validation Loss: 2.9687
# Validation: Avg Attenuated Validation Loss: 14.0936
# Validation Loss for Scheduler: 2.9687
# saving model
# Epoch [16/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.7
# Training: Avg Attenuated Training Loss: 0.3542
# Validation: Avg Standard Validation Loss: 2.9745
# Validation: Avg Attenuated Validation Loss: 16.6040
# Validation Loss for Scheduler: 2.9745
# saving model
# Epoch [17/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.6799999999999999
# Training: Avg Attenuated Training Loss: 0.4375
# Validation: Avg Standard Validation Loss: 2.9087
# Validation: Avg Attenuated Validation Loss: 15.9411
# Validation Loss for Scheduler: 2.9087
# saving model
# Epoch [18/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.6599999999999999
# Training: Avg Attenuated Training Loss: 1.3826
# Validation: Avg Standard Validation Loss: 2.7320
# Validation: Avg Attenuated Validation Loss: 12.8047
# Validation Loss for Scheduler: 2.7320
# saving model
# Epoch [19/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.64
# Training: Avg Attenuated Training Loss: 0.0789
# Validation: Avg Standard Validation Loss: 2.7435
# Validation: Avg Attenuated Validation Loss: 15.1220
# Validation Loss for Scheduler: 2.7435
# saving model
# Epoch [20/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.62
# Training: Avg Attenuated Training Loss: 0.7431
# Validation: Avg Standard Validation Loss: 2.7483
# Validation: Avg Attenuated Validation Loss: 15.8252
# Validation Loss for Scheduler: 2.7483
# saving model
# Epoch [21/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.6
# Training: Avg Attenuated Training Loss: 0.5381
# Validation: Avg Standard Validation Loss: 2.7229
# Validation: Avg Attenuated Validation Loss: 17.0759
# Validation Loss for Scheduler: 2.7229
# saving model
# Epoch [22/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.5800000000000001
# Training: Avg Attenuated Training Loss: 0.4183
# Validation: Avg Standard Validation Loss: 2.6771
# Validation: Avg Attenuated Validation Loss: 17.8521
# Validation Loss for Scheduler: 2.6771
# saving model
# Epoch [23/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.56
# Training: Avg Attenuated Training Loss: 0.2911
# Validation: Avg Standard Validation Loss: 2.6834
# Validation: Avg Attenuated Validation Loss: 18.8729
# Validation Loss for Scheduler: 2.6834
# saving model
# Epoch [24/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.54
# Training: Avg Attenuated Training Loss: 0.6588
# Validation: Avg Standard Validation Loss: 2.7002
# Validation: Avg Attenuated Validation Loss: 19.5803
# Validation Loss for Scheduler: 2.7002
# saving model
# Epoch [25/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.52
# Training: Avg Attenuated Training Loss: 0.5258
# Validation: Avg Standard Validation Loss: 2.6844
# Validation: Avg Attenuated Validation Loss: 19.1713
# Validation Loss for Scheduler: 2.6844
# saving model
# Epoch [26/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.5
# Training: Avg Attenuated Training Loss: 0.5283
# Validation: Avg Standard Validation Loss: 2.6770
# Validation: Avg Attenuated Validation Loss: 19.9231
# Validation Loss for Scheduler: 2.6770
# saving model
# Epoch [27/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.48
# Training: Avg Attenuated Training Loss: 0.5894
# Validation: Avg Standard Validation Loss: 2.6886
# Validation: Avg Attenuated Validation Loss: 22.3316
# Validation Loss for Scheduler: 2.6886
# saving model
# Epoch [28/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.45999999999999996
# Training: Avg Attenuated Training Loss: 2.8255
# Validation: Avg Standard Validation Loss: 2.6779
# Validation: Avg Attenuated Validation Loss: 20.0076
# Validation Loss for Scheduler: 2.6779
# saving model
# Epoch [29/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.43999999999999995
# Training: Avg Attenuated Training Loss: 0.6924
# Validation: Avg Standard Validation Loss: 2.7796
# Validation: Avg Attenuated Validation Loss: 20.9128
# Validation Loss for Scheduler: 2.7796
# saving model
# Epoch [30/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.42000000000000004
# Training: Avg Attenuated Training Loss: 3.2958
# Validation: Avg Standard Validation Loss: 2.6677
# Validation: Avg Attenuated Validation Loss: 18.5579
# Validation Loss for Scheduler: 2.6677
# saving model
# Epoch [31/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.4
# Training: Avg Attenuated Training Loss: 3.3495
# Validation: Avg Standard Validation Loss: 2.6552
# Validation: Avg Attenuated Validation Loss: 18.3798
# Validation Loss for Scheduler: 2.6552
# saving model
# Epoch [32/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.38
# Training: Avg Attenuated Training Loss: 1.2325
# Validation: Avg Standard Validation Loss: 2.6274
# Validation: Avg Attenuated Validation Loss: 16.8894
# Validation Loss for Scheduler: 2.6274
# saving model
# Epoch [33/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.36
# Training: Avg Attenuated Training Loss: 1.3255
# Validation: Avg Standard Validation Loss: 2.6498
# Validation: Avg Attenuated Validation Loss: 15.5228
# Validation Loss for Scheduler: 2.6498
# saving model
# Epoch [34/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.33999999999999997
# Training: Avg Attenuated Training Loss: 0.8316
# Validation: Avg Standard Validation Loss: 2.7069
# Validation: Avg Attenuated Validation Loss: 14.5311
# Validation Loss for Scheduler: 2.7069
# saving model
# Epoch [35/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.31999999999999995
# Training: Avg Attenuated Training Loss: 0.9564
# Validation: Avg Standard Validation Loss: 3.0984
# Validation: Avg Attenuated Validation Loss: 15.7931
# Validation Loss for Scheduler: 3.0984
# saving model
# Epoch [36/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.30000000000000004
# Training: Avg Attenuated Training Loss: 1.0079
# Validation: Avg Standard Validation Loss: 2.5974
# Validation: Avg Attenuated Validation Loss: 14.9103
# Validation Loss for Scheduler: 2.5974
# saving model
# Epoch [37/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.28
# Training: Avg Attenuated Training Loss: 0.9565
# Validation: Avg Standard Validation Loss: 2.5743
# Validation: Avg Attenuated Validation Loss: 10.3206
# Validation Loss for Scheduler: 2.5743
# saving model
# Epoch [38/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.26
# Training: Avg Attenuated Training Loss: 1.0813
# Validation: Avg Standard Validation Loss: 2.5896
# Validation: Avg Attenuated Validation Loss: 11.5664
# Validation Loss for Scheduler: 2.5896
# saving model
# Epoch [39/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.24
# Training: Avg Attenuated Training Loss: 1.2218
# Validation: Avg Standard Validation Loss: 2.6039
# Validation: Avg Attenuated Validation Loss: 11.0124
# Validation Loss for Scheduler: 2.6039
# saving model
# Epoch [40/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.21999999999999997
# Training: Avg Attenuated Training Loss: 1.2105
# Validation: Avg Standard Validation Loss: 2.5354
# Validation: Avg Attenuated Validation Loss: 8.8691
# Validation Loss for Scheduler: 2.5354
# saving model
# Epoch [41/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.19999999999999996
# Training: Avg Attenuated Training Loss: 0.9107
# Validation: Avg Standard Validation Loss: 2.5274
# Validation: Avg Attenuated Validation Loss: 9.2846
# Validation Loss for Scheduler: 2.5274
# saving model
# Epoch [42/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.18000000000000005
# Training: Avg Attenuated Training Loss: 2.5117
# Validation: Avg Standard Validation Loss: 2.5233
# Validation: Avg Attenuated Validation Loss: 7.5376
# Validation Loss for Scheduler: 2.5233
# saving model
# Epoch [43/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.16000000000000003
# Training: Avg Attenuated Training Loss: 1.3002
# Validation: Avg Standard Validation Loss: 2.5026
# Validation: Avg Attenuated Validation Loss: 4.6174
# Validation Loss for Scheduler: 2.5026
# saving model
# Epoch [44/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.14
# Training: Avg Attenuated Training Loss: 2.0779
# Validation: Avg Standard Validation Loss: 2.4747
# Validation: Avg Attenuated Validation Loss: 4.9343
# Validation Loss for Scheduler: 2.4747
# saving model
# Epoch [45/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.12
# Training: Avg Attenuated Training Loss: 0.9470
# Validation: Avg Standard Validation Loss: 2.5101
# Validation: Avg Attenuated Validation Loss: 7.4215
# Validation Loss for Scheduler: 2.5101
# saving model
# Epoch [46/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.09999999999999998
# Training: Avg Attenuated Training Loss: 0.9281
# Validation: Avg Standard Validation Loss: 2.4801
# Validation: Avg Attenuated Validation Loss: 5.9833
# Validation Loss for Scheduler: 2.4801
# saving model
# Epoch [47/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.07999999999999996
# Training: Avg Attenuated Training Loss: 1.1203
# Validation: Avg Standard Validation Loss: 2.4806
# Validation: Avg Attenuated Validation Loss: 5.5324
# Validation Loss for Scheduler: 2.4806
# saving model
# Epoch [48/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.06000000000000005
# Training: Avg Attenuated Training Loss: 0.9738
# Validation: Avg Standard Validation Loss: 2.4631
# Validation: Avg Attenuated Validation Loss: 4.9684
# Validation Loss for Scheduler: 2.4631
# saving model
# Epoch [49/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.040000000000000036
# Training: Avg Attenuated Training Loss: 1.0748
# Validation: Avg Standard Validation Loss: 2.4609
# Validation: Avg Attenuated Validation Loss: 4.3943
# Validation Loss for Scheduler: 2.4609
# saving model
# Epoch [50/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.020000000000000018
# Training: Avg Attenuated Training Loss: 1.1059
# Validation: Avg Standard Validation Loss: 2.4618
# Validation: Avg Attenuated Validation Loss: 4.9200
# Validation Loss for Scheduler: 2.4618
# saving model
# Epoch [51/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.0
# Training: Avg Attenuated Training Loss: 1.2163
# Validation: Avg Standard Validation Loss: 2.4700
# Validation: Avg Attenuated Validation Loss: 5.0455
# Validation Loss for Scheduler: 2.4700
# saving model
# Epoch [52/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.0
# Training: Avg Attenuated Training Loss: 1.0671
# Validation: Avg Standard Validation Loss: 2.4306
# Validation: Avg Attenuated Validation Loss: 3.9667
# Validation Loss for Scheduler: 2.4306
# saving model
# Epoch [53/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.0
# Training: Avg Attenuated Training Loss: 1.1525
# Validation: Avg Standard Validation Loss: 2.4454
# Validation: Avg Attenuated Validation Loss: 5.6423
# Validation Loss for Scheduler: 2.4454
# saving model
# Epoch [54/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.0
# Training: Avg Attenuated Training Loss: 1.1354
# Validation: Avg Standard Validation Loss: 2.4695
# Validation: Avg Attenuated Validation Loss: 5.7636
# Validation Loss for Scheduler: 2.4695
# saving model
# Epoch [55/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.0
# Training: Avg Attenuated Training Loss: 1.1643
# Validation: Avg Standard Validation Loss: 2.4424
# Validation: Avg Attenuated Validation Loss: 4.5260
# Validation Loss for Scheduler: 2.4424
# saving model
# Epoch [56/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.0
# Training: Avg Attenuated Training Loss: 1.2267
# Validation: Avg Standard Validation Loss: 2.4119
# Validation: Avg Attenuated Validation Loss: 6.4003
# Validation Loss for Scheduler: 2.4119
# saving model
# Epoch [57/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.0
# Training: Avg Attenuated Training Loss: 1.2032
# Validation: Avg Standard Validation Loss: 2.4255
# Validation: Avg Attenuated Validation Loss: 6.2809
# Validation Loss for Scheduler: 2.4255
# saving model
# Epoch [58/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.0
# Training: Avg Attenuated Training Loss: 2.2949
# Validation: Avg Standard Validation Loss: 2.4377
# Validation: Avg Attenuated Validation Loss: 6.1355
# Validation Loss for Scheduler: 2.4377
# saving model
# Epoch [59/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.0
# Training: Avg Attenuated Training Loss: 1.1072
# Validation: Avg Standard Validation Loss: 2.4344
# Validation: Avg Attenuated Validation Loss: 6.2233
# Validation Loss for Scheduler: 2.4344
# saving model
# Epoch [60/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.0
# Training: Avg Attenuated Training Loss: 1.1383
# Validation: Avg Standard Validation Loss: 2.4046
# Validation: Avg Attenuated Validation Loss: 6.0267
# Validation Loss for Scheduler: 2.4046
# saving model
# Epoch [61/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.0
# Training: Avg Attenuated Training Loss: 1.1757
# Validation: Avg Standard Validation Loss: 2.4295
# Validation: Avg Attenuated Validation Loss: 6.9046
# Validation Loss for Scheduler: 2.4295
# saving model
# Epoch [62/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.0
# Training: Avg Attenuated Training Loss: 1.3848
# Validation: Avg Standard Validation Loss: 2.3895
# Validation: Avg Attenuated Validation Loss: 5.2797
# Validation Loss for Scheduler: 2.3895
# saving model
# Epoch [63/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.0
# Training: Avg Attenuated Training Loss: 1.1052
# Validation: Avg Standard Validation Loss: 2.3958
# Validation: Avg Attenuated Validation Loss: 6.6196
# Validation Loss for Scheduler: 2.3958
# saving model
# Epoch [64/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.0
# Training: Avg Attenuated Training Loss: 1.6223
# Validation: Avg Standard Validation Loss: 2.3634
# Validation: Avg Attenuated Validation Loss: 4.7613
# Validation Loss for Scheduler: 2.3634
# saving model
# Epoch [65/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.0
# Training: Avg Attenuated Training Loss: 1.1393
# Validation: Avg Standard Validation Loss: 2.3810
# Validation: Avg Attenuated Validation Loss: 6.5440
# Validation Loss for Scheduler: 2.3810
# saving model
# Epoch [66/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.0
# Training: Avg Attenuated Training Loss: 1.0809
# Validation: Avg Standard Validation Loss: 2.3651
# Validation: Avg Attenuated Validation Loss: 6.2984
# Validation Loss for Scheduler: 2.3651
# saving model
# Epoch [67/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.0
# Training: Avg Attenuated Training Loss: 1.0839
# Validation: Avg Standard Validation Loss: 2.3532
# Validation: Avg Attenuated Validation Loss: 5.2197
# Validation Loss for Scheduler: 2.3532
# saving model
# Epoch [68/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.0
# Training: Avg Attenuated Training Loss: 1.2832
# Validation: Avg Standard Validation Loss: 2.3702
# Validation: Avg Attenuated Validation Loss: 7.2364
# Validation Loss for Scheduler: 2.3702
# saving model
# Epoch [69/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.0
# Training: Avg Attenuated Training Loss: 1.1712
# Validation: Avg Standard Validation Loss: 2.3258
# Validation: Avg Attenuated Validation Loss: 5.7960
# Validation Loss for Scheduler: 2.3258
# saving model
# Epoch [70/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.0
# Training: Avg Attenuated Training Loss: 1.0280
# Validation: Avg Standard Validation Loss: 2.3299
# Validation: Avg Attenuated Validation Loss: 6.4670
# Validation Loss for Scheduler: 2.3299
# saving model
# Epoch [71/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.0
# Training: Avg Attenuated Training Loss: 1.0690
# Validation: Avg Standard Validation Loss: 2.3417
# Validation: Avg Attenuated Validation Loss: 7.2989
# Validation Loss for Scheduler: 2.3417
# saving model
# Epoch [72/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.0
# Training: Avg Attenuated Training Loss: 1.1037
# Validation: Avg Standard Validation Loss: 2.3328
# Validation: Avg Attenuated Validation Loss: 7.1295
# Validation Loss for Scheduler: 2.3328
# saving model
# Epoch [73/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.0
# Training: Avg Attenuated Training Loss: 3.0749
# Validation: Avg Standard Validation Loss: 2.3327
# Validation: Avg Attenuated Validation Loss: 5.4928
# Validation Loss for Scheduler: 2.3327
# saving model
# Epoch [74/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.0
# Training: Avg Attenuated Training Loss: 1.0914
# Validation: Avg Standard Validation Loss: 2.3286
# Validation: Avg Attenuated Validation Loss: 6.1161
# Validation Loss for Scheduler: 2.3286
# saving model
# Epoch [75/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.0
# Training: Avg Attenuated Training Loss: 1.0782
# Validation: Avg Standard Validation Loss: 2.3091
# Validation: Avg Attenuated Validation Loss: 6.6066
# Validation Loss for Scheduler: 2.3091
# saving model
# Epoch [76/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.0
# Training: Avg Attenuated Training Loss: 1.2075
# Validation: Avg Standard Validation Loss: 2.3129
# Validation: Avg Attenuated Validation Loss: 5.6910
# Validation Loss for Scheduler: 2.3129
# saving model
# Epoch [77/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.0
# Training: Avg Attenuated Training Loss: 1.0582
# Validation: Avg Standard Validation Loss: 2.3175
# Validation: Avg Attenuated Validation Loss: 6.3472
# Validation Loss for Scheduler: 2.3175
# saving model
# Epoch [78/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.0
# Training: Avg Attenuated Training Loss: 1.2137
# Validation: Avg Standard Validation Loss: 2.3326
# Validation: Avg Attenuated Validation Loss: 6.5035
# Validation Loss for Scheduler: 2.3326
# saving model
# Epoch [79/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.0
# Training: Avg Attenuated Training Loss: 1.0627
# Validation: Avg Standard Validation Loss: 2.3558
# Validation: Avg Attenuated Validation Loss: 6.8008
# Validation Loss for Scheduler: 2.3558
# saving model
# Epoch [80/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.0
# Training: Avg Attenuated Training Loss: 1.0649
# Validation: Avg Standard Validation Loss: 2.3019
# Validation: Avg Attenuated Validation Loss: 6.0259
# Validation Loss for Scheduler: 2.3019
# saving model
# Epoch [81/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.0
# Training: Avg Attenuated Training Loss: 1.1709
# Validation: Avg Standard Validation Loss: 2.2892
# Validation: Avg Attenuated Validation Loss: 5.8799
# Validation Loss for Scheduler: 2.2892
# saving model
# Epoch [82/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.0
# Training: Avg Attenuated Training Loss: 1.2922
# Validation: Avg Standard Validation Loss: 2.2813
# Validation: Avg Attenuated Validation Loss: 7.8088
# Validation Loss for Scheduler: 2.2813
# saving model
# Epoch [83/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.0
# Training: Avg Attenuated Training Loss: 1.2552
# Validation: Avg Standard Validation Loss: 2.2928
# Validation: Avg Attenuated Validation Loss: 7.0309
# Validation Loss for Scheduler: 2.2928
# saving model
# Epoch [84/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.0
# Training: Avg Attenuated Training Loss: 1.0481
# Validation: Avg Standard Validation Loss: 2.3731
# Validation: Avg Attenuated Validation Loss: 6.1119
# Validation Loss for Scheduler: 2.3731
# saving model
# Epoch [85/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.0
# Training: Avg Attenuated Training Loss: 1.1364
# Validation: Avg Standard Validation Loss: 2.2638
# Validation: Avg Attenuated Validation Loss: 5.6775
# Validation Loss for Scheduler: 2.2638
# saving model
# Epoch [86/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.0
# Training: Avg Attenuated Training Loss: 1.2736
# Validation: Avg Standard Validation Loss: 2.2591
# Validation: Avg Attenuated Validation Loss: 5.7358
# Validation Loss for Scheduler: 2.2591
# saving model
# Epoch [87/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.0
# Training: Avg Attenuated Training Loss: 1.1547
# Validation: Avg Standard Validation Loss: 2.2442
# Validation: Avg Attenuated Validation Loss: 6.3116
# Validation Loss for Scheduler: 2.2442
# saving model
# Epoch [88/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.0
# Training: Avg Attenuated Training Loss: 1.0621
# Validation: Avg Standard Validation Loss: 2.2639
# Validation: Avg Attenuated Validation Loss: 6.4479
# Validation Loss for Scheduler: 2.2639
# saving model
# Epoch [89/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.0
# Training: Avg Attenuated Training Loss: 1.1874
# Validation: Avg Standard Validation Loss: 2.2417
# Validation: Avg Attenuated Validation Loss: 5.8797
# Validation Loss for Scheduler: 2.2417
# saving model
# Epoch [90/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.0
# Training: Avg Attenuated Training Loss: 1.2012
# Validation: Avg Standard Validation Loss: 2.2575
# Validation: Avg Attenuated Validation Loss: 5.7710
# Validation Loss for Scheduler: 2.2575
# saving model
# Epoch [91/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.0
# Training: Avg Attenuated Training Loss: 0.9851
# Validation: Avg Standard Validation Loss: 2.2463
# Validation: Avg Attenuated Validation Loss: 5.8041
# Validation Loss for Scheduler: 2.2463
# saving model
# Epoch [92/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.0
# Training: Avg Attenuated Training Loss: 1.1599
# Validation: Avg Standard Validation Loss: 2.2282
# Validation: Avg Attenuated Validation Loss: 5.8498
# Validation Loss for Scheduler: 2.2282
# saving model
# Epoch [93/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.0
# Training: Avg Attenuated Training Loss: 1.2654
# Validation: Avg Standard Validation Loss: 2.2451
# Validation: Avg Attenuated Validation Loss: 4.5284
# Validation Loss for Scheduler: 2.2451
# saving model
# Epoch [94/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.0
# Training: Avg Attenuated Training Loss: 1.2790
# Validation: Avg Standard Validation Loss: 2.2294
# Validation: Avg Attenuated Validation Loss: 4.6992
# Validation Loss for Scheduler: 2.2294
# saving model
# Epoch [95/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.0
# Training: Avg Attenuated Training Loss: 1.4952
# Validation: Avg Standard Validation Loss: 2.2291
# Validation: Avg Attenuated Validation Loss: 6.0529
# Validation Loss for Scheduler: 2.2291
# saving model
# Epoch [96/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.0
# Training: Avg Attenuated Training Loss: 1.0630
# Validation: Avg Standard Validation Loss: 2.2339
# Validation: Avg Attenuated Validation Loss: 4.7791
# Validation Loss for Scheduler: 2.2339
# saving model
# Epoch [97/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.0
# Training: Avg Attenuated Training Loss: 1.2083
# Validation: Avg Standard Validation Loss: 2.2545
# Validation: Avg Attenuated Validation Loss: 5.5876
# Validation Loss for Scheduler: 2.2545
# saving model
# Epoch [98/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.0
# Training: Avg Attenuated Training Loss: 0.9553
# Validation: Avg Standard Validation Loss: 2.2318
# Validation: Avg Attenuated Validation Loss: 7.1032
# Validation Loss for Scheduler: 2.2318
# saving model
# Epoch [99/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.0
# Training: Avg Attenuated Training Loss: 1.1665
# Validation: Avg Standard Validation Loss: 2.2271
# Validation: Avg Attenuated Validation Loss: 5.9116
# Validation Loss for Scheduler: 2.2271
# saving model
# Epoch [100/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.0
# Training: Avg Attenuated Training Loss: 1.1110
# Validation: Avg Standard Validation Loss: 2.2228
# Validation: Avg Attenuated Validation Loss: 5.9016
# Validation Loss for Scheduler: 2.2228
# saving model
# Training complete.
# Model saved to path: BPIC20_DD_full_grad_norm_new_v2.pkl

# %% [markdown]
# # Training Visualization

# %%
import matplotlib.pyplot as plt

# After training is finished, plot the loss curves
plt.plot(range(1, num_epochs+1), train_attenuated_losses, label='Training Attenuated Loss', color='blue')
plt.plot(range(1, num_epochs+1), val_losses, label='Validation Loss', color='orange')
plt.plot(range(1, num_epochs+1), val_attenuated_losses, label='Validation Attenuated Loss', color='green')
# Labeling x and y axes
plt.xlabel('Epochs', fontsize=12)
plt.ylabel('Loss', fontsize=12)
# Adding title
plt.title('Training and Validation Loss Curve', fontsize=14)
# Adding legend
plt.legend()
# Show the plot
plt.show()
