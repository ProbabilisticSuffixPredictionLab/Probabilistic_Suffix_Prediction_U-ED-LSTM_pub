# %%
import importlib
import sys
import torch

sys.path.insert(0, '..')
sys.path.insert(0, '../..')
sys.path.insert(0, '../../..')

# %%
# !ls ../../../../encoded_data_v2/helpdesk_all_5_test.pkl
# !ls ../../../../encoded_data_v1/helpdesk_all_5_test.pkl
# Out:
# ../../../../encoded_data_v2/helpdesk_all_5_test.pkl
# ../../../../encoded_data_v1/helpdesk_all_5_test.pkl

# %%
# Path to your pickle file (saved with torch.save)
file_path_train = '../../../../encoded_data_v2/helpdesk_all_5_test.pkl'
helpdesk_test_v2 = torch.load(file_path_train, weights_only=False)

# Path to your pickle file (saved with torch.save)
file_path_val = '../../../../encoded_data_v1/helpdesk_all_5_test.pkl'
helpdesk_test_v1 = torch.load(file_path_val, weights_only=False)

# %%
test_v2 = helpdesk_test_v2

test_v1 = helpdesk_test_v1

test=0
