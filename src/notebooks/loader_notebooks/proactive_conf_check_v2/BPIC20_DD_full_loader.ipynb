# %%
import importlib
import sys
import numpy as np
from collections import Counter
import pandas as pd
import pickle

# performance imports for torch: torch kernel uses one core only.
import os
os.environ["OMP_NUM_THREADS"] = "1"
os.environ["MKL_NUM_THREADS"] = "1"
os.environ["TORCH_NUM_THREADS"] = "1" 

import torch

sys.path.insert(0, '..')
sys.path.insert(0, '../..')
sys.path.insert(0, '../../..')

# %%
# Preprocess for BPIC20 DD:
# Remove role suffix in activity names (e.g., "[Declaration SUBMITTED by EMPLOYEE]" -> "[Declaration SUBMITTED]")
# Remove exact duplicate rows

import re

event_log_location = '../../../../../../data/data/DomesticDeclarations.csv'
df_raw = pd.read_csv(event_log_location)
activity_col = "concept:name"

def _strip_by_suffix(value):
    if pd.isna(value):
        return value
    s = str(value)
    if s == "EOS":
        return s
    # If the activity is bracketed, remove " by ..." before the closing bracket
    s = re.sub(r"\s+by\s+[^\]]+(?=\])", "", s)
    # General fallback: remove " by ..." at end of string
    s = re.sub(r"\s+by\s+.*$", "", s)
    return s

df_raw[activity_col] = df_raw[activity_col].map(_strip_by_suffix)

root, ext = os.path.splitext(event_log_location)
cleaned_event_log_location = f"{root}_cleaned{ext or '.csv'}"
df_raw.to_csv(cleaned_event_log_location, index=False)

# Use the cleaned log for the rest of this notebook
print("Wrote cleaned log to:", cleaned_event_log_location)
# Out:
# Wrote cleaned log to: ../../../../../../data/data/DomesticDeclarations_cleaned.csv

# %%
import event_log_loader.new_event_log_loader_v2
importlib.reload(event_log_loader.new_event_log_loader_v2)
from event_log_loader.new_event_log_loader_v2 import PrefixesDataFrameLoader, EventLogLoader

import warnings
warnings.filterwarnings("ignore", category=FutureWarning)

np.random.seed(17)

event_log_location = cleaned_event_log_location

result_name = 'bpic20_DD_all'

# dynamic categorical attributes
cat_dynamic = ['concept:name',
               'org:resource',
               'org:role'
              ]

# static categorical attributes
cat_static = ['case:BudgetNumber',
              'case:DeclarationNumber'
             ]

# dynamic numerical attributes
num_dynamic = ['case_elapsed_time',
               'event_elapsed_time',
               'day_in_week',
               'seconds_in_day',
               ]

# dynamic log-normal encoded numerical attributes 
num_dyn_log = []

# static numeric attributes
num_static = ['case:Amount']

min_suffix_size = 5

train_validation_size = 0.3
# 15% test size:
test_validation_size = 0.15

event_log_properties = {# case id
                        'case_name' : 'case:concept:name',
                        # activity
                        'concept_name' : 'concept:name',
                        # time values and computaitons
                        'timestamp_name' : 'time:timestamp',
                        'time_since_case_start_column' : 'case_elapsed_time',
                        'time_since_last_event_column' : 'event_elapsed_time',
                        'day_in_week_column' : 'day_in_week',
                        'seconds_in_day_column' : 'seconds_in_day',
                        # min suffix size for eos padding right
                        'min_suffix_size' : min_suffix_size,
                        # trian and test split
                        'train_validation_size' : train_validation_size,
                        'test_validation_size' :test_validation_size,
                        # window size for padding
                        'window_size' : 'auto',
                        # dynamic and static values
                        'categorical_columns' : cat_dynamic,
                        'static_categorical_columns' : cat_static,
                        'continuous_columns' : num_dynamic,
                        'continuous_positive_columns' : num_dyn_log,
                        'static_continuous_columns' : num_static}

# %% [markdown]
# ## Create dataframes of prefixes

# %%
# object to create datframe of prefixes for petri-net repaly marking computation
pref_adopt_dataframe = PrefixesDataFrameLoader(event_log_location=event_log_location, event_log_properties=event_log_properties)

# %%
# output if necessary the raw dataframe: dynamic are lists, static values
raw_data = pref_adopt_dataframe.get_raw_dataframe()
raw_data

unique_vals = (
    pd.Series(raw_data["concept:name"])
      .explode()
      .dropna()
      .unique()
      .tolist()
)

print(unique_vals)
# Out:
# ['Declaration SUBMITTED', 'Declaration FINAL_APPROVED', 'Request Payment', 'Payment Handled', 'Declaration APPROVED', 'Declaration REJECTED', 'Declaration SAVED', 'Declaration FOR_APPROVAL']

# %%
# outputs for perturbations:
# train_df, val_df, test_df = pref_adopt_dataframe.get_all_datasets()
# categories = pref_adopt_dataframe.extract_feature_info()

# %%
# prefix dataset for potential marking computation
train_pref_df = pref_adopt_dataframe.get_dataset('train')
train_pref_df
# Out:
#         case:concept:name  prefix_length  \
# 0       declaration 86795              1
# 1       declaration 86795              2
# 2       declaration 86795              3
# 3       declaration 86795              4
# 4       declaration 86795              5
# ...                   ...            ...
# 31019  declaration 138359              1
# 31020  declaration 138359              2
# 31021  declaration 138359              3
# 31022  declaration 138359              4
# 31023  declaration 138359              5
#
#                                             concept:name  \
# 0                                [Declaration SUBMITTED]
# 1          [Declaration SUBMITTED, Declaration APPROVED]
# 2      [Declaration SUBMITTED, Declaration APPROVED, ...
# 3      [Declaration SUBMITTED, Declaration APPROVED, ...
# 4      [Declaration SUBMITTED, Declaration APPROVED, ...
# ...                                                  ...
# 31019                            [Declaration SUBMITTED]
# 31020      [Declaration SUBMITTED, Declaration APPROVED]
# 31021  [Declaration SUBMITTED, Declaration APPROVED, ...
# 31022  [Declaration SUBMITTED, Declaration APPROVED, ...
# 31023  [Declaration SUBMITTED, Declaration APPROVED, ...
#
#                                             org:resource  \
# 0                                         [STAFF MEMBER]
# 1                           [STAFF MEMBER, STAFF MEMBER]
# 2             [STAFF MEMBER, STAFF MEMBER, STAFF MEMBER]
# 3      [STAFF MEMBER, STAFF MEMBER, STAFF MEMBER, SYS...
# 4      [STAFF MEMBER, STAFF MEMBER, STAFF MEMBER, SYS...
# ...                                                  ...
# 31019                                     [STAFF MEMBER]
# 31020                       [STAFF MEMBER, STAFF MEMBER]
# 31021         [STAFF MEMBER, STAFF MEMBER, STAFF MEMBER]
# 31022  [STAFF MEMBER, STAFF MEMBER, STAFF MEMBER, SYS...
# 31023  [STAFF MEMBER, STAFF MEMBER, STAFF MEMBER, SYS...
#
#                                                 org:role  \
# 0                                             [EMPLOYEE]
# 1                               [EMPLOYEE, PRE_APPROVER]
# 2                   [EMPLOYEE, PRE_APPROVER, SUPERVISOR]
# 3        [EMPLOYEE, PRE_APPROVER, SUPERVISOR, UNDEFINED]
# 4      [EMPLOYEE, PRE_APPROVER, SUPERVISOR, UNDEFINED...
# ...                                                  ...
# 31019                                         [EMPLOYEE]
# 31020                         [EMPLOYEE, ADMINISTRATION]
# 31021             [EMPLOYEE, ADMINISTRATION, SUPERVISOR]
# 31022  [EMPLOYEE, ADMINISTRATION, SUPERVISOR, UNDEFINED]
# 31023  [EMPLOYEE, ADMINISTRATION, SUPERVISOR, UNDEFIN...
#
#                                        case_elapsed_time  \
# 0                                                  [0.0]
# 1                                       [0.0, 3801787.0]
# 2                            [0.0, 3801787.0, 3880111.0]
# 3                 [0.0, 3801787.0, 3880111.0, 4851671.0]
# 4      [0.0, 3801787.0, 3880111.0, 4851671.0, 5468685.0]
# ...                                                  ...
# 31019                                              [0.0]
# 31020                                       [0.0, 359.0]
# 31021                             [0.0, 359.0, 399938.0]
# 31022                   [0.0, 359.0, 399938.0, 829814.0]
# 31023        [0.0, 359.0, 399938.0, 829814.0, 1035654.0]
#
#                                   event_elapsed_time  \
# 0                                              [nan]
# 1                                   [nan, 3801787.0]
# 2                          [nan, 3801787.0, 78324.0]
# 3                [nan, 3801787.0, 78324.0, 971560.0]
# 4      [nan, 3801787.0, 78324.0, 971560.0, 617014.0]
# ...                                              ...
# 31019                                          [nan]
# 31020                                   [nan, 359.0]
# 31021                         [nan, 359.0, 399579.0]
# 31022               [nan, 359.0, 399579.0, 429876.0]
# 31023     [nan, 359.0, 399579.0, 429876.0, 205840.0]
#
#                      day_in_week  \
# 0                          [0.0]
# 1                     [0.0, 2.0]
# 2                [0.0, 2.0, 3.0]
# 3           [0.0, 2.0, 3.0, 0.0]
# 4      [0.0, 2.0, 3.0, 0.0, 0.0]
# ...                          ...
# 31019                      [5.0]
# 31020                 [5.0, 5.0]
# 31021            [5.0, 5.0, 3.0]
# 31022       [5.0, 5.0, 3.0, 1.0]
# 31023  [5.0, 5.0, 3.0, 1.0, 3.0]
#
#                                       seconds_in_day case:BudgetNumber  \
# 0                                          [37574.0]      budget 86566
# 1                                 [37574.0, 37761.0]      budget 86566
# 2                        [37574.0, 37761.0, 29685.0]      budget 86566
# 3               [37574.0, 37761.0, 29685.0, 50845.0]      budget 86566
# 4      [37574.0, 37761.0, 29685.0, 50845.0, 63059.0]      budget 86566
# ...                                              ...               ...
# 31019                                      [64214.0]      budget 86566
# 31020                             [64214.0, 64573.0]      budget 86566
# 31021                    [64214.0, 64573.0, 32152.0]      budget 86566
# 31022           [64214.0, 64573.0, 32152.0, 30028.0]      budget 86566
# 31023  [64214.0, 64573.0, 32152.0, 30028.0, 63068.0]      budget 86566
#
#           case:DeclarationNumber  case:Amount
# 0       declaration number 86796   182.464172
# 1       declaration number 86796   182.464172
# 2       declaration number 86796   182.464172
# 3       declaration number 86796   182.464172
# 4       declaration number 86796   182.464172
# ...                          ...          ...
# 31019  declaration number 138360   190.404576
# 31020  declaration number 138360   190.404576
# 31021  declaration number 138360   190.404576
# 31022  declaration number 138360   190.404576
# 31023  declaration number 138360   190.404576
#
# [31024 rows x 12 columns]

# %%
train_pref_df.to_csv('../../../../encoded_data_conformance_v2/BPIC20_DD/prefix_for_replay/'+result_name+'_'+str(min_suffix_size)+'_train.csv', index=False)

# %%
# prefix dataset for potential marking computation
val_pref_df = pref_adopt_dataframe.get_dataset('val')
val_pref_df
# Out:
#         case:concept:name  prefix_length  \
# 0       declaration 86791              1
# 1       declaration 86791              2
# 2       declaration 86791              3
# 3       declaration 86791              4
# 4       declaration 86805              1
# ...                   ...            ...
# 16900  declaration 138331              2
# 16901  declaration 138331              3
# 16902  declaration 138331              4
# 16903  declaration 138331              5
# 16904  declaration 138331              6
#
#                                             concept:name  \
# 0                                [Declaration SUBMITTED]
# 1      [Declaration SUBMITTED, Declaration FINAL_APPR...
# 2      [Declaration SUBMITTED, Declaration FINAL_APPR...
# 3      [Declaration SUBMITTED, Declaration FINAL_APPR...
# 4                                [Declaration SUBMITTED]
# ...                                                  ...
# 16900      [Declaration SUBMITTED, Declaration APPROVED]
# 16901  [Declaration SUBMITTED, Declaration APPROVED, ...
# 16902  [Declaration SUBMITTED, Declaration APPROVED, ...
# 16903  [Declaration SUBMITTED, Declaration APPROVED, ...
# 16904  [Declaration SUBMITTED, Declaration APPROVED, ...
#
#                                             org:resource  \
# 0                                         [STAFF MEMBER]
# 1                           [STAFF MEMBER, STAFF MEMBER]
# 2                   [STAFF MEMBER, STAFF MEMBER, SYSTEM]
# 3           [STAFF MEMBER, STAFF MEMBER, SYSTEM, SYSTEM]
# 4                                         [STAFF MEMBER]
# ...                                                  ...
# 16900                       [STAFF MEMBER, STAFF MEMBER]
# 16901         [STAFF MEMBER, STAFF MEMBER, STAFF MEMBER]
# 16902  [STAFF MEMBER, STAFF MEMBER, STAFF MEMBER, STA...
# 16903  [STAFF MEMBER, STAFF MEMBER, STAFF MEMBER, STA...
# 16904  [STAFF MEMBER, STAFF MEMBER, STAFF MEMBER, STA...
#
#                                                 org:role  \
# 0                                             [EMPLOYEE]
# 1                                 [EMPLOYEE, SUPERVISOR]
# 2                      [EMPLOYEE, SUPERVISOR, UNDEFINED]
# 3           [EMPLOYEE, SUPERVISOR, UNDEFINED, UNDEFINED]
# 4                                             [EMPLOYEE]
# ...                                                  ...
# 16900                         [EMPLOYEE, ADMINISTRATION]
# 16901           [EMPLOYEE, ADMINISTRATION, BUDGET OWNER]
# 16902  [EMPLOYEE, ADMINISTRATION, BUDGET OWNER, SUPER...
# 16903  [EMPLOYEE, ADMINISTRATION, BUDGET OWNER, SUPER...
# 16904  [EMPLOYEE, ADMINISTRATION, BUDGET OWNER, SUPER...
#
#                                        case_elapsed_time  \
# 0                                                  [0.0]
# 1                                          [0.0, 5878.0]
# 2                                 [0.0, 5878.0, 85494.0]
# 3                       [0.0, 5878.0, 85494.0, 286892.0]
# 4                                                  [0.0]
# ...                                                  ...
# 16900                                       [0.0, 907.0]
# 16901                             [0.0, 907.0, 863655.0]
# 16902                   [0.0, 907.0, 863655.0, 941264.0]
# 16903        [0.0, 907.0, 863655.0, 941264.0, 1007441.0]
# 16904  [0.0, 907.0, 863655.0, 941264.0, 1007441.0, 11...
#
#                                       event_elapsed_time  \
# 0                                                  [nan]
# 1                                          [nan, 5878.0]
# 2                                 [nan, 5878.0, 79616.0]
# 3                       [nan, 5878.0, 79616.0, 201398.0]
# 4                                                  [nan]
# ...                                                  ...
# 16900                                       [nan, 907.0]
# 16901                             [nan, 907.0, 862748.0]
# 16902                    [nan, 907.0, 862748.0, 77609.0]
# 16903           [nan, 907.0, 862748.0, 77609.0, 66177.0]
# 16904  [nan, 907.0, 862748.0, 77609.0, 66177.0, 11955...
#
#                           day_in_week  \
# 0                               [0.0]
# 1                          [0.0, 0.0]
# 2                     [0.0, 0.0, 1.0]
# 3                [0.0, 0.0, 1.0, 3.0]
# 4                               [0.0]
# ...                               ...
# 16900                      [4.0, 4.0]
# 16901                 [4.0, 4.0, 0.0]
# 16902            [4.0, 4.0, 0.0, 1.0]
# 16903       [4.0, 4.0, 0.0, 1.0, 2.0]
# 16904  [4.0, 4.0, 0.0, 1.0, 2.0, 3.0]
#
#                                           seconds_in_day case:BudgetNumber  \
# 0                                              [35390.0]      budget 86566
# 1                                     [35390.0, 41268.0]      budget 86566
# 2                            [35390.0, 41268.0, 34484.0]      budget 86566
# 3                   [35390.0, 41268.0, 34484.0, 63082.0]      budget 86566
# 4                                              [42047.0]      budget 86566
# ...                                                  ...               ...
# 16900                                 [59270.0, 60177.0]      budget 86566
# 16901                        [59270.0, 60177.0, 58925.0]      budget 86566
# 16902               [59270.0, 60177.0, 58925.0, 50134.0]      budget 86566
# 16903      [59270.0, 60177.0, 58925.0, 50134.0, 29911.0]      budget 86566
# 16904  [59270.0, 60177.0, 58925.0, 50134.0, 29911.0, ...      budget 86566
#
#           case:DeclarationNumber  case:Amount
# 0       declaration number 86792    26.851205
# 1       declaration number 86792    26.851205
# 2       declaration number 86792    26.851205
# 3       declaration number 86792    26.851205
# 4       declaration number 86806   443.585163
# ...                          ...          ...
# 16900  declaration number 138332   161.048342
# 16901  declaration number 138332   161.048342
# 16902  declaration number 138332   161.048342
# 16903  declaration number 138332   161.048342
# 16904  declaration number 138332   161.048342
#
# [16905 rows x 12 columns]

# %%
val_pref_df.to_csv('../../../../encoded_data_conformance_v2/BPIC20_DD/prefix_for_replay/'+result_name+'_'+str(min_suffix_size)+'_val.csv', index=False)

# %%
# prefix dataset for potential marking computation
test_pref_df = pref_adopt_dataframe.get_dataset('test')
test_pref_df
# Out:
#        case:concept:name  prefix_length  \
# 0      declaration 86809              1
# 1      declaration 86809              2
# 2      declaration 86809              3
# 3      declaration 86809              4
# 4      declaration 86809              5
# ...                  ...            ...
# 8503  declaration 138349              1
# 8504  declaration 138349              2
# 8505  declaration 138349              3
# 8506  declaration 138349              4
# 8507  declaration 138349              5
#
#                                            concept:name  \
# 0                               [Declaration SUBMITTED]
# 1     [Declaration SUBMITTED, Declaration FINAL_APPR...
# 2     [Declaration SUBMITTED, Declaration FINAL_APPR...
# 3     [Declaration SUBMITTED, Declaration FINAL_APPR...
# 4     [Declaration SUBMITTED, Declaration FINAL_APPR...
# ...                                                 ...
# 8503                            [Declaration SUBMITTED]
# 8504      [Declaration SUBMITTED, Declaration APPROVED]
# 8505  [Declaration SUBMITTED, Declaration APPROVED, ...
# 8506  [Declaration SUBMITTED, Declaration APPROVED, ...
# 8507  [Declaration SUBMITTED, Declaration APPROVED, ...
#
#                                            org:resource  \
# 0                                        [STAFF MEMBER]
# 1                          [STAFF MEMBER, STAFF MEMBER]
# 2            [STAFF MEMBER, STAFF MEMBER, STAFF MEMBER]
# 3     [STAFF MEMBER, STAFF MEMBER, STAFF MEMBER, STA...
# 4     [STAFF MEMBER, STAFF MEMBER, STAFF MEMBER, STA...
# ...                                                 ...
# 8503                                     [STAFF MEMBER]
# 8504                       [STAFF MEMBER, STAFF MEMBER]
# 8505         [STAFF MEMBER, STAFF MEMBER, STAFF MEMBER]
# 8506  [STAFF MEMBER, STAFF MEMBER, STAFF MEMBER, SYS...
# 8507  [STAFF MEMBER, STAFF MEMBER, STAFF MEMBER, SYS...
#
#                                                org:role  \
# 0                                            [EMPLOYEE]
# 1                                [EMPLOYEE, SUPERVISOR]
# 2                       [EMPLOYEE, SUPERVISOR, MISSING]
# 3             [EMPLOYEE, SUPERVISOR, MISSING, EMPLOYEE]
# 4     [EMPLOYEE, SUPERVISOR, MISSING, EMPLOYEE, SUPE...
# ...                                                 ...
# 8503                                         [EMPLOYEE]
# 8504                         [EMPLOYEE, ADMINISTRATION]
# 8505             [EMPLOYEE, ADMINISTRATION, SUPERVISOR]
# 8506  [EMPLOYEE, ADMINISTRATION, SUPERVISOR, UNDEFINED]
# 8507  [EMPLOYEE, ADMINISTRATION, SUPERVISOR, UNDEFIN...
#
#                                  case_elapsed_time  \
# 0                                            [0.0]
# 1                                      [0.0, 13.0]
# 2                             [0.0, 13.0, 98443.0]
# 3                   [0.0, 13.0, 98443.0, 959331.0]
# 4         [0.0, 13.0, 98443.0, 959331.0, 959407.0]
# ...                                            ...
# 8503                                         [0.0]
# 8504                                 [0.0, 1012.0]
# 8505                       [0.0, 1012.0, 931490.0]
# 8506             [0.0, 1012.0, 931490.0, 997140.0]
# 8507  [0.0, 1012.0, 931490.0, 997140.0, 1116767.0]
#
#                               event_elapsed_time                day_in_week  \
# 0                                          [nan]                      [0.0]
# 1                                    [nan, 13.0]                 [0.0, 0.0]
# 2                           [nan, 13.0, 98430.0]            [0.0, 0.0, 1.0]
# 3                 [nan, 13.0, 98430.0, 860888.0]       [0.0, 0.0, 1.0, 4.0]
# 4           [nan, 13.0, 98430.0, 860888.0, 76.0]  [0.0, 0.0, 1.0, 4.0, 4.0]
# ...                                          ...                        ...
# 8503                                       [nan]                      [4.0]
# 8504                               [nan, 1012.0]                 [4.0, 4.0]
# 8505                     [nan, 1012.0, 930478.0]            [4.0, 4.0, 1.0]
# 8506            [nan, 1012.0, 930478.0, 65650.0]       [4.0, 4.0, 1.0, 2.0]
# 8507  [nan, 1012.0, 930478.0, 65650.0, 119627.0]  [4.0, 4.0, 1.0, 2.0, 3.0]
#
#                                      seconds_in_day case:BudgetNumber  \
# 0                                         [44076.0]      budget 86566
# 1                                [44076.0, 44089.0]      budget 86566
# 2                       [44076.0, 44089.0, 56119.0]      budget 86566
# 3              [44076.0, 44089.0, 56119.0, 53007.0]      budget 86566
# 4     [44076.0, 44089.0, 56119.0, 53007.0, 53083.0]      budget 86566
# ...                                             ...               ...
# 8503                                      [69501.0]      budget 86566
# 8504                             [69501.0, 70513.0]      budget 86566
# 8505                    [69501.0, 70513.0, 50591.0]      budget 86566
# 8506           [69501.0, 70513.0, 50591.0, 29841.0]      budget 86566
# 8507  [69501.0, 70513.0, 50591.0, 29841.0, 63068.0]      budget 86566
#
#          case:DeclarationNumber  case:Amount
# 0      declaration number 86810   333.440910
# 1      declaration number 86810   333.440910
# 2      declaration number 86810   333.440910
# 3      declaration number 86810   333.440910
# 4      declaration number 86810   333.440910
# ...                         ...          ...
# 8503  declaration number 138350   446.667698
# 8504  declaration number 138350   446.667698
# 8505  declaration number 138350   446.667698
# 8506  declaration number 138350   446.667698
# 8507  declaration number 138350   446.667698
#
# [8508 rows x 12 columns]

# %%
test_pref_df.to_csv('../../../../encoded_data_conformance_v2/BPIC20_DD/prefix_for_replay/'+result_name+'_'+str(min_suffix_size)+'_test.csv', index=False)

# %% [markdown]
# ## Optional: Compute Petri Net replay markings of prefixes

# %%
# Optional set list of ids the petri net should be executed:
unique_list_train = train_pref_df["case:concept:name"].dropna().unique().tolist()
unique_list_val = val_pref_df["case:concept:name"].dropna().unique().tolist()

case_ids = list(dict.fromkeys(unique_list_train + unique_list_val))

# %%
# Calculate and store markings:
import event_log_loader.petri_net_replay_markings
importlib.reload(event_log_loader.petri_net_replay_markings)
from event_log_loader.petri_net_replay_markings import InductiveMiner, PNReplayMarkings

# initialize the process 
miner = InductiveMiner(path_to_csv_log=event_log_location, case_id_col="case:concept:name", activity_col="concept:name", timestamp_col="time:timestamp", resource_col="org:resource")
store_loc_file_path ='../../../../encoded_data_conformance_v2/BPIC20_DD/prefix_for_replay/petri_net/bpic20_DD.png'
net, im, fm = miner.discover_petri_net(visulaize=True,
                                       case_ids=case_ids,
                                       store_loc_file_path=store_loc_file_path)

# store discovered petri net objects next to the PNG
pkl_path = os.path.splitext(store_loc_file_path)[0] + '.pkl'
with open(pkl_path, 'wb') as f:
    pickle.dump((net, im, fm), f)

# %%
# train set markings
replayer_train = PNReplayMarkings(discovered_pn=(net, im, fm), prefix_df=train_pref_df, event_label="concept:name")

markings_train = replayer_train.get_markings_token_replay()

print("Amount markings: ", len(markings_train))
markings_counter_train = Counter(tuple(mark) for mark in markings_train)
markings_summary_train = ( pd.DataFrame([(list(mark), count) for mark, count in markings_counter_train.items()], columns=["marking", "count"]).sort_values("count", ascending=False).reset_index(drop=True))
markings_summary_train
# Out:
# Amount markings:  31024
#                     marking  count
# 0   [p_5, p_16, p_20, p_28]   5812
# 1         [p_5, p_18, p_16]   5694
# 2               [p_5, p_11]   4979
# 3               [p_5, p_30]   4975
# 4   [p_5, p_16, p_28, p_23]   4237
# 5         [p_18, p_16, p_8]   1163
# 6   [p_5, p_16, p_25, p_23]    781
# 7               [p_8, p_30]    533
# 8               [p_8, p_11]    533
# 9   [p_8, p_16, p_28, p_23]    500
# 10  [p_8, p_16, p_20, p_28]    497
# 11        [p_18, p_8, p_16]    462
# 12  [p_16, p_20, p_28, p_8]    313
# 13  [p_20, p_8, p_16, p_28]    175
# 14  [p_20, p_28, p_8, p_16]    131
# 15                    [p_4]     81
# 16  [p_16, p_25, p_23, p_8]     33
# 17  [p_25, p_23, p_8, p_16]     26
# 18  [p_25, p_8, p_16, p_23]     21
# 19  [p_8, p_16, p_25, p_23]     16
# 20  [p_23, p_8, p_16, p_28]     13
# 21  [p_16, p_28, p_23, p_8]     11
# 22  [p_20, p_16, p_28, p_8]     10
# 23  [p_20, p_28, p_16, p_8]     10
# 24  [p_28, p_23, p_8, p_16]      9
# 25  [p_25, p_23, p_16, p_8]      4
# 26              [p_11, p_8]      3
# 27              [p_30, p_8]      1
# 28  [p_25, p_16, p_23, p_8]      1

# %%
# validation set markings
replayer_val = PNReplayMarkings(discovered_pn=(net, im, fm), prefix_df=val_pref_df, event_label="concept:name")

markings_val = replayer_val.get_markings_token_replay()

print("Amount markings: ", len(markings_val))
markings_counter_val = Counter(tuple(mark) for mark in markings_val)
markings_summary_val = (pd.DataFrame([(list(mark), count) for mark, count in markings_counter_val.items()], columns=["marking", "count"]).sort_values("count", ascending=False).reset_index(drop=True))
markings_summary_val
# Out:
# Amount markings:  16905
#                     marking  count
# 0         [p_5, p_18, p_16]   3110
# 1   [p_5, p_16, p_20, p_28]   3089
# 2               [p_5, p_11]   2722
# 3               [p_5, p_30]   2719
# 4   [p_5, p_16, p_28, p_23]   2302
# 5         [p_18, p_16, p_8]    636
# 6   [p_5, p_16, p_25, p_23]    448
# 7               [p_8, p_30]    298
# 8               [p_8, p_11]    298
# 9   [p_8, p_16, p_20, p_28]    278
# 10  [p_8, p_16, p_28, p_23]    273
# 11        [p_18, p_8, p_16]    256
# 12  [p_16, p_20, p_28, p_8]    161
# 13  [p_20, p_8, p_16, p_28]     94
# 14  [p_20, p_28, p_8, p_16]     73
# 15                    [p_4]     40
# 16  [p_16, p_25, p_23, p_8]     26
# 17  [p_25, p_23, p_8, p_16]     21
# 18  [p_25, p_8, p_16, p_23]     20
# 19  [p_20, p_28, p_16, p_8]     12
# 20  [p_8, p_16, p_25, p_23]      8
# 21  [p_20, p_16, p_28, p_8]      8
# 22  [p_28, p_23, p_8, p_16]      3
# 23  [p_16, p_28, p_23, p_8]      3
# 24  [p_23, p_8, p_16, p_28]      3
# 25  [p_25, p_23, p_16, p_8]      2
# 26  [p_25, p_16, p_23, p_8]      2

# %%
# test set markings
replayer_test = PNReplayMarkings(discovered_pn=(net, im, fm), prefix_df=test_pref_df, event_label="concept:name")

markings_test = replayer_test.get_markings_token_replay()

print("Amount markings: ", len(markings_test))
markings_counter_test = Counter(tuple(mark) for mark in markings_test)
markings_summary_test = ( pd.DataFrame([(list(mark), count) for mark, count in markings_counter_test.items()], columns=["marking", "count"]).sort_values("count", ascending=False).reset_index(drop=True))
markings_summary_test
# Out:
# Amount markings:  8508
#                           marking  count
# 0               [p_5, p_18, p_16]   1561
# 1         [p_5, p_16, p_20, p_28]   1538
# 2                     [p_5, p_30]   1367
# 3                     [p_5, p_11]   1365
# 4         [p_5, p_16, p_28, p_23]   1144
# 5               [p_18, p_16, p_8]    341
# 6         [p_5, p_16, p_25, p_23]    233
# 7         [p_8, p_16, p_20, p_28]    155
# 8                     [p_8, p_11]    149
# 9                     [p_8, p_30]    146
# 10              [p_18, p_8, p_16]    139
# 11        [p_8, p_16, p_28, p_23]    138
# 12        [p_16, p_20, p_28, p_8]     82
# 13        [p_20, p_8, p_16, p_28]     51
# 14        [p_20, p_28, p_8, p_16]     40
# 15                          [p_4]     14
# 16        [p_20, p_28, p_16, p_8]      9
# 17        [p_16, p_25, p_23, p_8]      9
# 18        [p_25, p_23, p_8, p_16]      5
# 19        [p_25, p_8, p_16, p_23]      5
# 20        [p_8, p_16, p_25, p_23]      4
# 21        [p_20, p_16, p_28, p_8]      3
# 22        [p_8, p_11, p_16, p_28]      2
# 23                    [p_30, p_8]      2
# 24                    [p_4, p_30]      1
# 25        [p_16, p_28, p_23, p_8]      1
# 26              [p_8, p_11, p_16]      1
# 27                    [p_4, p_11]      1
# 28  [p_8, p_11, p_16, p_28, p_23]      1
# 29              [p_8, p_11, p_30]      1

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Process train markings
markings_summary_train['marking_str'] = markings_summary_train['marking'].apply(lambda x: str(sorted([str(i) for i in x])))
markings_summary_train['freq'] = (markings_summary_train['count'] / markings_summary_train['count'].sum()) * 100
markings_summary_train['dataset'] = 'Train'

# Process validation markings
markings_summary_val['marking_str'] = markings_summary_val['marking'].apply(lambda x: str(sorted([str(i) for i in x])))
markings_summary_val['freq'] = (markings_summary_val['count'] / markings_summary_val['count'].sum()) * 100
markings_summary_val['dataset'] = 'Validation'

# Process test markings
markings_summary_test['marking_str'] = markings_summary_test['marking'].apply(lambda x: str(sorted([str(i) for i in x])))
markings_summary_test['freq'] = (markings_summary_test['count'] / markings_summary_test['count'].sum()) * 100
markings_summary_test['dataset'] = 'Test'

# Combine
combined_markings = pd.concat([
    markings_summary_train[['marking_str', 'freq', 'dataset']],
    markings_summary_val[['marking_str', 'freq', 'dataset']], 
    markings_summary_test[['marking_str', 'freq', 'dataset']]
])

# Identify unique markings
train_markings = set(markings_summary_train['marking_str'])
val_markings = set(markings_summary_val['marking_str'])
test_markings = set(markings_summary_test['marking_str'])

def get_category(row):
    m = row['marking_str']
    d = row['dataset']
    unique = False
    if d == 'Train' and m not in val_markings and m not in test_markings:
        unique = True
    elif d == 'Validation' and m not in train_markings and m not in test_markings:
        unique = True
    elif d == 'Test' and m not in train_markings and m not in val_markings:
        unique = True
    
    return f"{d} ({'Unique' if unique else 'Shared'})"

combined_markings['category'] = combined_markings.apply(get_category, axis=1)

# Split into Shared and Unique datasets
shared_data = combined_markings[combined_markings['category'].str.contains('Shared')]
unique_data = combined_markings[combined_markings['category'].str.contains('Unique')]

# Plot 1: Shared Markings
plt.figure(figsize=(24, 8))
palette_shared = {
    'Train (Shared)': 'tab:blue',
    'Validation (Shared)': 'tab:orange', 
    'Test (Shared)': 'tab:green'
}
sns.barplot(data=shared_data, x='marking_str', y='freq', hue='category', palette=palette_shared)
plt.xticks(rotation=90)
plt.title('Comparison of Shared Markings Distributions')
plt.ylabel('Frequency (% of respective dataset)')
plt.xlabel('Marking')
plt.legend(title='Dataset')
plt.tight_layout()
plt.show()

# Unique Markings
plt.figure(figsize=(24, 8))
palette_unique = {
    'Train (Unique)': 'darkblue',
    'Validation (Unique)': 'darkorange',
    'Test (Unique)': 'darkgreen'
}

if not unique_data.empty:
    sns.barplot(data=unique_data, x='marking_str', y='freq', hue='category', palette=palette_unique)
    plt.xticks(rotation=90)
    plt.title('Comparison of Unique Markings Distributions')
    plt.ylabel('Frequency (% of respective dataset)')
    plt.xlabel('Marking')
    plt.legend(title='Dataset')
    plt.tight_layout()
    plt.show()
else:
    print("No unique markings found across datasets.")

# %%
# Remove prefixes whose Petri net marking is unique to one split (Train/Val/Test)
"""
print("All prefixes (train/val/test):", len(train_pref_df), len(val_pref_df), len(test_pref_df))

(train_pref_df,
 val_pref_df,
 test_pref_df,
 markings_train,
 markings_val,
 markings_test,
 (keep_train_ix, keep_val_ix, keep_test_ix))= pref_adopt_dataframe.remove_prefixes_with_unique_markings(train_pref_df,
                                                                                                        val_pref_df,
                                                                                                        test_pref_df,
                                                                                                        markings_train,
                                                                                                        markings_val,
                                                                                                        markings_test)


print("Kept prefixes (train/val/test):", len(train_pref_df), len(val_pref_df), len(test_pref_df))
"""
# Out:
# '\nprint("All prefixes (train/val/test):", len(train_pref_df), len(val_pref_df), len(test_pref_df))\n\n(train_pref_df,\n val_pref_df,\n test_pref_df,\n markings_train,\n markings_val,\n markings_test,\n (keep_train_ix, keep_val_ix, keep_test_ix))= pref_adopt_dataframe.remove_prefixes_with_unique_markings(train_pref_df,\n                                                                                                        val_pref_df,\n                                                                                                        test_pref_df,\n                                                                                                        markings_train,\n                                                                                                        markings_val,\n                                                                                                        markings_test)\n\n\nprint("Kept prefixes (train/val/test):", len(train_pref_df), len(val_pref_df), len(test_pref_df))\n'

# %% [markdown]
# ## Dtore datasets and credentials for Deep-NN

# %%
# object to create the tensors for the dnn models and further credentials
el_loader = EventLogLoader(event_log_location=event_log_location, event_log_properties=event_log_properties, prefix_df=pref_adopt_dataframe)

# %%
# test
test_set = el_loader.get_encoded_dataframe(type='test')
test_set
# Out:
#         case:concept:name               id  org:resource  \
# 0       declaration 86809  st_step 86814_0  STAFF MEMBER
# 1       declaration 86809  st_step 86813_0  STAFF MEMBER
# 2       declaration 86809  st_step 86815_0  STAFF MEMBER
# 3       declaration 86809  st_step 86812_0  STAFF MEMBER
# 4       declaration 86809  st_step 86811_0  STAFF MEMBER
# ...                   ...              ...           ...
# 16378  declaration 138349              NaN           EOS
# 16379  declaration 138349              NaN           EOS
# 16380  declaration 138349              NaN           EOS
# 16381  declaration 138349              NaN           EOS
# 16382  declaration 138349              NaN           EOS
#
#                      concept:name      time:timestamp    org:role  \
# 0           Declaration SUBMITTED 2017-01-09 12:14:36    EMPLOYEE
# 1      Declaration FINAL_APPROVED 2017-01-09 12:14:49  SUPERVISOR
# 2            Declaration REJECTED 2017-01-10 15:35:19     MISSING
# 3           Declaration SUBMITTED 2017-01-20 14:43:27    EMPLOYEE
# 4      Declaration FINAL_APPROVED 2017-01-20 14:44:43  SUPERVISOR
# ...                           ...                 ...         ...
# 16378                         EOS                 NaT         EOS
# 16379                         EOS                 NaT         EOS
# 16380                         EOS                 NaT         EOS
# 16381                         EOS                 NaT         EOS
# 16382                         EOS                 NaT         EOS
#
#                  case:id case:BudgetNumber    case:DeclarationNumber  \
# 0      declaration 86809      budget 86566  declaration number 86810
# 1      declaration 86809      budget 86566  declaration number 86810
# 2      declaration 86809      budget 86566  declaration number 86810
# 3      declaration 86809      budget 86566  declaration number 86810
# 4      declaration 86809      budget 86566  declaration number 86810
# ...                  ...               ...                       ...
# 16378                NaN               NaN                       NaN
# 16379                NaN               NaN                       NaN
# 16380                NaN               NaN                       NaN
# 16381                NaN               NaN                       NaN
# 16382                NaN               NaN                       NaN
#
#        case:Amount  case_elapsed_time  event_elapsed_time  day_in_week  \
# 0        333.44091                0.0                 NaN          0.0
# 1        333.44091               13.0                13.0          0.0
# 2        333.44091            98443.0             98430.0          1.0
# 3        333.44091           959331.0            860888.0          4.0
# 4        333.44091           959407.0                76.0          4.0
# ...            ...                ...                 ...          ...
# 16378          NaN                NaN                 NaN          NaN
# 16379          NaN                NaN                 NaN          NaN
# 16380          NaN                NaN                 NaN          NaN
# 16381          NaN                NaN                 NaN          NaN
# 16382          NaN                NaN                 NaN          NaN
#
#        seconds_in_day
# 0             44076.0
# 1             44089.0
# 2             56119.0
# 3             53007.0
# 4             53083.0
# ...               ...
# 16378             NaN
# 16379             NaN
# 16380             NaN
# 16381             NaN
# 16382             NaN
#
# [16383 rows x 14 columns]

# %%
# train tensor dataset
train_set = el_loader.get_dataset('train')

# add markings to the train dataset credentials:
train_set.set_prefix_markings(markings=markings_train)

# save dataset 
torch.save(train_set, '../../../../encoded_data_conformance_v2/BPIC20_DD/'+result_name+'_'+str(el_loader.encoder_decoder.min_suffix_size)+'_train.pkl')
# Out:
# categorical tensors:   0%|          | 0/3 [00:00<?, ?it/s]
# concept:name:   0%|          | 0/5775 [00:00<?, ?it/s]
# org:resource:   0%|          | 0/5775 [00:00<?, ?it/s]
# org:role:   0%|          | 0/5775 [00:00<?, ?it/s]
# continouous tensors:   0%|          | 0/4 [00:00<?, ?it/s]
# case_elapsed_time:   0%|          | 0/5775 [00:00<?, ?it/s]
# event_elapsed_time:   0%|          | 0/5775 [00:00<?, ?it/s]
# day_in_week:   0%|          | 0/5775 [00:00<?, ?it/s]
# seconds_in_day:   0%|          | 0/5775 [00:00<?, ?it/s]
# static categorical:   0%|          | 0/31024 [00:00<?, ?it/s]
# static continuous:   0%|          | 0/31024 [00:00<?, ?it/s]

# %%
# Test get sizes and others
print("Min suffix size: ", train_set.min_suffix_size)

print("Categories and encoding params for dynamic categorical and continuous values: ", train_set.all_categories)
print("Categories and encoding params for static categorical and continuous values: ", train_set.all_static_categories)

print("Dynamic categorical tensor: ", train_set.categorical_tensors[0].size())
print("Dynamic continuous tensor: ", train_set.continuous_tensors[0].size())

print("Static categorical tensor: ", train_set.static_categorical_tensor.size())
print("Static continuous tensor: ", train_set.static_continuous_tensor.size())

print("Zero padding tensor: ", train_set.zero_padding.size())
print("EOS padding tensor: ",train_set.eos_padding.size())

print("Prefix petri net replay tensor: ", len(train_set.prefixes_petri_net_marking))
print(train_set.prefixes_petri_net_marking[0:3])
# Out:
# Min suffix size:  5
# Categories and encoding params for dynamic categorical and continuous values:  ([('concept:name', 10, {'Declaration APPROVED': 1, 'Declaration FINAL_APPROVED': 2, 'Declaration FOR_APPROVAL': 3, 'Declaration REJECTED': 4, 'Declaration SAVED': 5, 'Declaration SUBMITTED': 6, 'EOS': 7, 'Payment Handled': 8, 'Request Payment': 9}), ('org:resource', 4, {'EOS': 1, 'STAFF MEMBER': 2, 'SYSTEM': 3}), ('org:role', 9, {'ADMINISTRATION': 1, 'BUDGET OWNER': 2, 'EMPLOYEE': 3, 'EOS': 4, 'MISSING': 5, 'PRE_APPROVER': 6, 'SUPERVISOR': 7, 'UNDEFINED': 8})], [('case_elapsed_time', 1, {}), ('event_elapsed_time', 1, {}), ('day_in_week', 1, {}), ('seconds_in_day', 1, {})])
# Categories and encoding params for static categorical and continuous values:  ([('case:BudgetNumber', 2, {'budget 86566': 1}), ('case:DeclarationNumber', 5515, {'UNKNOWN': 1, 'declaration number 100001': 2, 'declaration number 100011': 3, 'declaration number 100016': 4, 'declaration number 100038': 5, 'declaration number 100070': 6, 'declaration number 100075': 7, 'declaration number 100080': 8, 'declaration number 100091': 9, 'declaration number 100112': 10, 'declaration number 100132': 11, 'declaration number 100138': 12, 'declaration number 100144': 13, 'declaration number 100150': 14, 'declaration number 100161': 15, 'declaration number 100173': 16, 'declaration number 100178': 17, 'declaration number 100188': 18, 'declaration number 100198': 19, 'declaration number 100208': 20, 'declaration number 100219': 21, 'declaration number 100224': 22, 'declaration number 100229': 23, 'declaration number 100234': 24, 'declaration number 100240': 25, 'declaration number 100246': 26, 'declaration number 100270': 27, 'declaration number 100275': 28, 'declaration number 100290': 29, 'declaration number 100296': 30, 'declaration number 100307': 31, 'declaration number 100312': 32, 'declaration number 100318': 33, 'declaration number 100324': 34, 'declaration number 100334': 35, 'declaration number 100344': 36, 'declaration number 100366': 37, 'declaration number 100389': 38, 'declaration number 100400': 39, 'declaration number 100413': 40, 'declaration number 100442': 41, 'declaration number 100453': 42, 'declaration number 100458': 43, 'declaration number 100474': 44, 'declaration number 100485': 45, 'declaration number 100491': 46, 'declaration number 100507': 47, 'declaration number 100517': 48, 'declaration number 100522': 49, 'declaration number 100533': 50, 'declaration number 100539': 51, 'declaration number 100554': 52, 'declaration number 100564': 53, 'declaration number 100570': 54, 'declaration number 100575': 55, 'declaration number 100580': 56, 'declaration number 100600': 57, 'declaration number 100605': 58, 'declaration number 100611': 59, 'declaration number 100623': 60, 'declaration number 100638': 61, 'declaration number 100648': 62, 'declaration number 100653': 63, 'declaration number 100658': 64, 'declaration number 100668': 65, 'declaration number 100673': 66, 'declaration number 100678': 67, 'declaration number 100689': 68, 'declaration number 100727': 69, 'declaration number 100754': 70, 'declaration number 100769': 71, 'declaration number 100779': 72, 'declaration number 100795': 73, 'declaration number 100801': 74, 'declaration number 100806': 75, 'declaration number 100812': 76, 'declaration number 100817': 77, 'declaration number 100830': 78, 'declaration number 100841': 79, 'declaration number 100846': 80, 'declaration number 100852': 81, 'declaration number 100858': 82, 'declaration number 100864': 83, 'declaration number 100870': 84, 'declaration number 100875': 85, 'declaration number 100888': 86, 'declaration number 100898': 87, 'declaration number 100909': 88, 'declaration number 100914': 89, 'declaration number 100937': 90, 'declaration number 100942': 91, 'declaration number 100955': 92, 'declaration number 100966': 93, 'declaration number 100989': 94, 'declaration number 100995': 95, 'declaration number 101010': 96, 'declaration number 101036': 97, 'declaration number 101054': 98, 'declaration number 101065': 99, 'declaration number 101071': 100, 'declaration number 101085': 101, 'declaration number 101100': 102, 'declaration number 101106': 103, 'declaration number 101111': 104, 'declaration number 101127': 105, 'declaration number 101133': 106, 'declaration number 101170': 107, 'declaration number 101175': 108, 'declaration number 101183': 109, 'declaration number 101195': 110, 'declaration number 101206': 111, 'declaration number 101216': 112, 'declaration number 101227': 113, 'declaration number 101244': 114, 'declaration number 101249': 115, 'declaration number 101255': 116, 'declaration number 1 ...
# Dynamic categorical tensor:  torch.Size([31024, 20])
# Dynamic continuous tensor:  torch.Size([31024, 20])
# Static categorical tensor:  torch.Size([31024, 2])
# Static continuous tensor:  torch.Size([31024, 1])
# Zero padding tensor:  torch.Size([31024, 20])
# EOS padding tensor:  torch.Size([31024, 20])
# Prefix petri net replay tensor:  31024
# [['p_16:1', 'p_18:1', 'p_5:1'], ['p_16:1', 'p_20:1', 'p_28:1', 'p_5:1'], ['p_16:1', 'p_23:1', 'p_28:1', 'p_5:1']]

# %%
# train tensor dataset
val_set = el_loader.get_dataset('val')

# add markings to the train dataset credentials:
val_set.set_prefix_markings(markings=markings_val)

# save dataset 
torch.save(val_set, '../../../../encoded_data_conformance_v2/BPIC20_DD/'+result_name+'_'+str(el_loader.encoder_decoder.min_suffix_size)+'_val.pkl')
# Out:
# categorical tensors:   0%|          | 0/3 [00:00<?, ?it/s]
# concept:name:   0%|          | 0/3150 [00:00<?, ?it/s]
# org:resource:   0%|          | 0/3150 [00:00<?, ?it/s]
# org:role:   0%|          | 0/3150 [00:00<?, ?it/s]
# continouous tensors:   0%|          | 0/4 [00:00<?, ?it/s]
# case_elapsed_time:   0%|          | 0/3150 [00:00<?, ?it/s]
# event_elapsed_time:   0%|          | 0/3150 [00:00<?, ?it/s]
# day_in_week:   0%|          | 0/3150 [00:00<?, ?it/s]
# seconds_in_day:   0%|          | 0/3150 [00:00<?, ?it/s]
# static categorical:   0%|          | 0/16905 [00:00<?, ?it/s]
# static continuous:   0%|          | 0/16905 [00:00<?, ?it/s]

# %%
# Test get sizes and others
print("Min suffix size: ", val_set.min_suffix_size)

print("Categories and encoding params for dynamic categorical and continuous values: ", val_set.all_categories)
print("Categories and encoding params for static categorical and continuous values: ", val_set.all_static_categories)

print("Dynamic categorical tensor: ", val_set.categorical_tensors[0].size())
print("Dynamic continuous tensor: ", val_set.continuous_tensors[0].size())

print("Static categorical tensor: ", val_set.static_categorical_tensor.size())
print("Static continuous tensor: ", val_set.static_continuous_tensor.size())

print("Zero padding tensor: ", val_set.zero_padding.size())
print("EOS padding tensor: ",val_set.eos_padding.size())

print("Prefix petri net replay tensor: ", len(val_set.prefixes_petri_net_marking))
print(val_set.prefixes_petri_net_marking[0:3])
# Out:
# Min suffix size:  5
# Categories and encoding params for dynamic categorical and continuous values:  ([('concept:name', 10, {'Declaration APPROVED': 1, 'Declaration FINAL_APPROVED': 2, 'Declaration FOR_APPROVAL': 3, 'Declaration REJECTED': 4, 'Declaration SAVED': 5, 'Declaration SUBMITTED': 6, 'EOS': 7, 'Payment Handled': 8, 'Request Payment': 9}), ('org:resource', 4, {'EOS': 1, 'STAFF MEMBER': 2, 'SYSTEM': 3}), ('org:role', 9, {'ADMINISTRATION': 1, 'BUDGET OWNER': 2, 'EMPLOYEE': 3, 'EOS': 4, 'MISSING': 5, 'PRE_APPROVER': 6, 'SUPERVISOR': 7, 'UNDEFINED': 8})], [('case_elapsed_time', 1, {}), ('event_elapsed_time', 1, {}), ('day_in_week', 1, {}), ('seconds_in_day', 1, {})])
# Categories and encoding params for static categorical and continuous values:  ([('case:BudgetNumber', 2, {'budget 86566': 1}), ('case:DeclarationNumber', 5515, {'UNKNOWN': 1, 'declaration number 100001': 2, 'declaration number 100011': 3, 'declaration number 100016': 4, 'declaration number 100038': 5, 'declaration number 100070': 6, 'declaration number 100075': 7, 'declaration number 100080': 8, 'declaration number 100091': 9, 'declaration number 100112': 10, 'declaration number 100132': 11, 'declaration number 100138': 12, 'declaration number 100144': 13, 'declaration number 100150': 14, 'declaration number 100161': 15, 'declaration number 100173': 16, 'declaration number 100178': 17, 'declaration number 100188': 18, 'declaration number 100198': 19, 'declaration number 100208': 20, 'declaration number 100219': 21, 'declaration number 100224': 22, 'declaration number 100229': 23, 'declaration number 100234': 24, 'declaration number 100240': 25, 'declaration number 100246': 26, 'declaration number 100270': 27, 'declaration number 100275': 28, 'declaration number 100290': 29, 'declaration number 100296': 30, 'declaration number 100307': 31, 'declaration number 100312': 32, 'declaration number 100318': 33, 'declaration number 100324': 34, 'declaration number 100334': 35, 'declaration number 100344': 36, 'declaration number 100366': 37, 'declaration number 100389': 38, 'declaration number 100400': 39, 'declaration number 100413': 40, 'declaration number 100442': 41, 'declaration number 100453': 42, 'declaration number 100458': 43, 'declaration number 100474': 44, 'declaration number 100485': 45, 'declaration number 100491': 46, 'declaration number 100507': 47, 'declaration number 100517': 48, 'declaration number 100522': 49, 'declaration number 100533': 50, 'declaration number 100539': 51, 'declaration number 100554': 52, 'declaration number 100564': 53, 'declaration number 100570': 54, 'declaration number 100575': 55, 'declaration number 100580': 56, 'declaration number 100600': 57, 'declaration number 100605': 58, 'declaration number 100611': 59, 'declaration number 100623': 60, 'declaration number 100638': 61, 'declaration number 100648': 62, 'declaration number 100653': 63, 'declaration number 100658': 64, 'declaration number 100668': 65, 'declaration number 100673': 66, 'declaration number 100678': 67, 'declaration number 100689': 68, 'declaration number 100727': 69, 'declaration number 100754': 70, 'declaration number 100769': 71, 'declaration number 100779': 72, 'declaration number 100795': 73, 'declaration number 100801': 74, 'declaration number 100806': 75, 'declaration number 100812': 76, 'declaration number 100817': 77, 'declaration number 100830': 78, 'declaration number 100841': 79, 'declaration number 100846': 80, 'declaration number 100852': 81, 'declaration number 100858': 82, 'declaration number 100864': 83, 'declaration number 100870': 84, 'declaration number 100875': 85, 'declaration number 100888': 86, 'declaration number 100898': 87, 'declaration number 100909': 88, 'declaration number 100914': 89, 'declaration number 100937': 90, 'declaration number 100942': 91, 'declaration number 100955': 92, 'declaration number 100966': 93, 'declaration number 100989': 94, 'declaration number 100995': 95, 'declaration number 101010': 96, 'declaration number 101036': 97, 'declaration number 101054': 98, 'declaration number 101065': 99, 'declaration number 101071': 100, 'declaration number 101085': 101, 'declaration number 101100': 102, 'declaration number 101106': 103, 'declaration number 101111': 104, 'declaration number 101127': 105, 'declaration number 101133': 106, 'declaration number 101170': 107, 'declaration number 101175': 108, 'declaration number 101183': 109, 'declaration number 101195': 110, 'declaration number 101206': 111, 'declaration number 101216': 112, 'declaration number 101227': 113, 'declaration number 101244': 114, 'declaration number 101249': 115, 'declaration number 101255': 116, 'declaration number 1 ...
# Dynamic categorical tensor:  torch.Size([16905, 20])
# Dynamic continuous tensor:  torch.Size([16905, 20])
# Static categorical tensor:  torch.Size([16905, 2])
# Static continuous tensor:  torch.Size([16905, 1])
# Zero padding tensor:  torch.Size([16905, 20])
# EOS padding tensor:  torch.Size([16905, 20])
# Prefix petri net replay tensor:  16905
# [['p_16:1', 'p_18:1', 'p_5:1'], ['p_16:1', 'p_23:1', 'p_25:1', 'p_5:1'], ['p_30:1', 'p_5:1']]

# %%
# train tensor dataset
test_set = el_loader.get_dataset('test')

# add markings to the train dataset credentials:
test_set.set_prefix_markings(markings=markings_test)

# save dataset 
torch.save(test_set, '../../../../encoded_data_conformance_v2/BPIC20_DD/'+result_name+'_'+str(el_loader.encoder_decoder.min_suffix_size)+'_test.pkl')
# Out:
# categorical tensors:   0%|          | 0/3 [00:00<?, ?it/s]
# concept:name:   0%|          | 0/1575 [00:00<?, ?it/s]
# org:resource:   0%|          | 0/1575 [00:00<?, ?it/s]
# org:role:   0%|          | 0/1575 [00:00<?, ?it/s]
# continouous tensors:   0%|          | 0/4 [00:00<?, ?it/s]
# case_elapsed_time:   0%|          | 0/1575 [00:00<?, ?it/s]
# event_elapsed_time:   0%|          | 0/1575 [00:00<?, ?it/s]
# day_in_week:   0%|          | 0/1575 [00:00<?, ?it/s]
# seconds_in_day:   0%|          | 0/1575 [00:00<?, ?it/s]
# static categorical:   0%|          | 0/8508 [00:00<?, ?it/s]
# static continuous:   0%|          | 0/8508 [00:00<?, ?it/s]

# %%
# Test get sizes and others
print("Min suffix size: ", test_set.min_suffix_size)

print("Categories and encoding params for dynamic categorical and continuous values: ", test_set.all_categories)
print("Categories and encoding params for static categorical and continuous values: ", test_set.all_static_categories)

print("Dynamic categorical tensor: ", test_set.categorical_tensors[0].size())
# print("Dynamic categorical tensor examples: ", test_set.categorical_tensors[0][10:55])
print("Dynamic continuous tensor: ", test_set.continuous_tensors[0].size())

print("Static categorical tensor: ", test_set.static_categorical_tensor.size())
print("Static continuous tensor: ", test_set.static_continuous_tensor.size())

print("Zero padding tensor: ", test_set.zero_padding.size())
print("EOS padding tensor: ",test_set.eos_padding.size())
# print("Zero padds: ", test_set.zero_padding[35:41])
# print("EOS padds: ", test_set.eos_padding[35:41])

print("Prefix petri net replay tensor: ", len(test_set.prefixes_petri_net_marking))
print(test_set.prefixes_petri_net_marking[0:3])
# Out:
# Min suffix size:  5
# Categories and encoding params for dynamic categorical and continuous values:  ([('concept:name', 10, {'Declaration APPROVED': 1, 'Declaration FINAL_APPROVED': 2, 'Declaration FOR_APPROVAL': 3, 'Declaration REJECTED': 4, 'Declaration SAVED': 5, 'Declaration SUBMITTED': 6, 'EOS': 7, 'Payment Handled': 8, 'Request Payment': 9}), ('org:resource', 4, {'EOS': 1, 'STAFF MEMBER': 2, 'SYSTEM': 3}), ('org:role', 9, {'ADMINISTRATION': 1, 'BUDGET OWNER': 2, 'EMPLOYEE': 3, 'EOS': 4, 'MISSING': 5, 'PRE_APPROVER': 6, 'SUPERVISOR': 7, 'UNDEFINED': 8})], [('case_elapsed_time', 1, {}), ('event_elapsed_time', 1, {}), ('day_in_week', 1, {}), ('seconds_in_day', 1, {})])
# Categories and encoding params for static categorical and continuous values:  ([('case:BudgetNumber', 2, {'budget 86566': 1}), ('case:DeclarationNumber', 5515, {'UNKNOWN': 1, 'declaration number 100001': 2, 'declaration number 100011': 3, 'declaration number 100016': 4, 'declaration number 100038': 5, 'declaration number 100070': 6, 'declaration number 100075': 7, 'declaration number 100080': 8, 'declaration number 100091': 9, 'declaration number 100112': 10, 'declaration number 100132': 11, 'declaration number 100138': 12, 'declaration number 100144': 13, 'declaration number 100150': 14, 'declaration number 100161': 15, 'declaration number 100173': 16, 'declaration number 100178': 17, 'declaration number 100188': 18, 'declaration number 100198': 19, 'declaration number 100208': 20, 'declaration number 100219': 21, 'declaration number 100224': 22, 'declaration number 100229': 23, 'declaration number 100234': 24, 'declaration number 100240': 25, 'declaration number 100246': 26, 'declaration number 100270': 27, 'declaration number 100275': 28, 'declaration number 100290': 29, 'declaration number 100296': 30, 'declaration number 100307': 31, 'declaration number 100312': 32, 'declaration number 100318': 33, 'declaration number 100324': 34, 'declaration number 100334': 35, 'declaration number 100344': 36, 'declaration number 100366': 37, 'declaration number 100389': 38, 'declaration number 100400': 39, 'declaration number 100413': 40, 'declaration number 100442': 41, 'declaration number 100453': 42, 'declaration number 100458': 43, 'declaration number 100474': 44, 'declaration number 100485': 45, 'declaration number 100491': 46, 'declaration number 100507': 47, 'declaration number 100517': 48, 'declaration number 100522': 49, 'declaration number 100533': 50, 'declaration number 100539': 51, 'declaration number 100554': 52, 'declaration number 100564': 53, 'declaration number 100570': 54, 'declaration number 100575': 55, 'declaration number 100580': 56, 'declaration number 100600': 57, 'declaration number 100605': 58, 'declaration number 100611': 59, 'declaration number 100623': 60, 'declaration number 100638': 61, 'declaration number 100648': 62, 'declaration number 100653': 63, 'declaration number 100658': 64, 'declaration number 100668': 65, 'declaration number 100673': 66, 'declaration number 100678': 67, 'declaration number 100689': 68, 'declaration number 100727': 69, 'declaration number 100754': 70, 'declaration number 100769': 71, 'declaration number 100779': 72, 'declaration number 100795': 73, 'declaration number 100801': 74, 'declaration number 100806': 75, 'declaration number 100812': 76, 'declaration number 100817': 77, 'declaration number 100830': 78, 'declaration number 100841': 79, 'declaration number 100846': 80, 'declaration number 100852': 81, 'declaration number 100858': 82, 'declaration number 100864': 83, 'declaration number 100870': 84, 'declaration number 100875': 85, 'declaration number 100888': 86, 'declaration number 100898': 87, 'declaration number 100909': 88, 'declaration number 100914': 89, 'declaration number 100937': 90, 'declaration number 100942': 91, 'declaration number 100955': 92, 'declaration number 100966': 93, 'declaration number 100989': 94, 'declaration number 100995': 95, 'declaration number 101010': 96, 'declaration number 101036': 97, 'declaration number 101054': 98, 'declaration number 101065': 99, 'declaration number 101071': 100, 'declaration number 101085': 101, 'declaration number 101100': 102, 'declaration number 101106': 103, 'declaration number 101111': 104, 'declaration number 101127': 105, 'declaration number 101133': 106, 'declaration number 101170': 107, 'declaration number 101175': 108, 'declaration number 101183': 109, 'declaration number 101195': 110, 'declaration number 101206': 111, 'declaration number 101216': 112, 'declaration number 101227': 113, 'declaration number 101244': 114, 'declaration number 101249': 115, 'declaration number 101255': 116, 'declaration number 1 ...
# Dynamic categorical tensor:  torch.Size([8508, 20])
# Dynamic continuous tensor:  torch.Size([8508, 20])
# Static categorical tensor:  torch.Size([8508, 2])
# Static continuous tensor:  torch.Size([8508, 1])
# Zero padding tensor:  torch.Size([8508, 20])
# EOS padding tensor:  torch.Size([8508, 20])
# Prefix petri net replay tensor:  8508
# [['p_16:1', 'p_18:1', 'p_5:1'], ['p_16:1', 'p_23:1', 'p_25:1', 'p_5:1'], ['p_16:1', 'p_23:1', 'p_25:1', 'p_8:1']]
