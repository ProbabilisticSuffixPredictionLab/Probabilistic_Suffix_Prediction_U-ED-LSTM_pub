# %%
import sys
import pickle
from pathlib import Path

sys.path.insert(0, '..')
sys.path.insert(0, '../..')
sys.path.insert(0, '../../..')
sys.path.insert(0, '../../../..')

# %%
# Define the directory containing .pkl files
pkl_dir = Path('../../../../../../data/Helpdesk/v2/')

# %%
# Get all .pkl files in the directory
pkl_files = list(pkl_dir.glob('*.pkl'))

# Check if any .pkl files were found
if not pkl_files:
    print("No .pkl files found in the directory.")
else:
    for i, file in enumerate(pkl_files):
        print(file)
        with open(file, 'rb') as f:
            # Dict with key: (Case name, prefix length), value: ()
            data = pickle.load(f)
        
            """
            for (case, pref_len), (prefix, target, pred, pred_samples) in data.items():
                print("Case name: ", case, " with prefix length: ", pref_len), "\n"
                print("Prefix:")
                for event in prefix:
                    print("Activity: ", event['concept:name'], "Case Elapsed Time: ", event['case_elapsed_time'], ", Event Elapsed Time: ", event['event_elapsed_time']), "\n"
                print("Target Suffix:")
                for event in target:
                    print("Activity: ", event['concept:name'], ", Case Elapsed Time: ", event['case_elapsed_time'], ", Event Elapsed Time: ", event['event_elapsed_time']), "\n"
                print("Predicted Suffix")
                for event in pred:
                    print("Activity: ", event['concept:name'], ", Case Elapsed Time: ", event['case_elapsed_time'], ", Event Elapsed Time: ", event['event_elapsed_time'])
                print("\n")
            """
        
            # Helpdesk case:
            for (case, pref_len), (prefix, target, pred, pred_samples) in data.items():
                print("Case name: ", case, " with prefix length: ", pref_len), "\n"
                
                print("Prefix:")
                for event in prefix:
                    # print("Activity: ", event['Activity'], ", Resource: ", event['Resource'], ", Case Elapsed Time: ", event['case_elapsed_time'], ", Event Elapsed Time: ", event['event_elapsed_time']), "\n"
                    print("Activity: ", event['Activity'])
                print("Target Suffix:")
                for event in target:
                    # print("Activity: ", event['Activity'], ", Resource: ", event['Resource'], ", Case Elapsed Time: ", event['case_elapsed_time'], ", Event Elapsed Time: ", event['case_elapsed_time']), "\n"
                    print("Activity: ", event['Activity'])
                print("Predicted Most-likely Suffix")
                for event in pred:
                    # print("Activity: ", event['Activity'], ", Resource: ", event['Resource'], ", Case Elapsed Time: ", event['case_elapsed_time'], ", Event Elapsed Time: ", event['event_elapsed_time'])
                    print("Activity: ", event['Activity'])
                print("\n")
            break
# Out:
# ../../../../../../data/Helpdesk/v2/results_part_450.pkl
# Case name:  Case 2002  with prefix length:  1
# Prefix:
# Activity:  Assign seriousness
# Target Suffix:
# Activity:  Take in charge ticket
# Activity:  Resolve ticket
# Activity:  Closed
# Predicted Most-likely Suffix
#
#
# Case name:  Case 3619  with prefix length:  1
# Prefix:
# Activity:  Assign seriousness
# Target Suffix:
# Activity:  Take in charge ticket
# Activity:  Resolve ticket
# Activity:  Closed
# Predicted Most-likely Suffix
#
#
# Case name:  Case 1058  with prefix length:  3
# Prefix:
# Activity:  Assign seriousness
# Activity:  Take in charge ticket
# Activity:  Wait
# Target Suffix:
# Activity:  Resolve ticket
# Activity:  Closed
# Predicted Most-likely Suffix
# Activity:  Resolve ticket
# Activity:  Closed
# Activity:  Closed
# Activity:  Closed
# Activity:  Closed
# Activity:  Closed
# Activity:  Closed
# Activity:  Closed
# Activity:  Closed
# Activity:  Closed
# Activity:  Closed
#
#
# Case name:  Case 2002  with prefix length:  3
# Prefix:
# Activity:  Assign seriousness
# Activity:  Take in charge ticket
# Activity:  Resolve ticket
# Target Suffix:
# Activity:  Closed
# Predicted Most-likely Suffix
# Activity:  Closed
#
#
# Case name:  Case 3258  with prefix length:  2
# Prefix:
# Activity:  Assign seriousness
# Activity:  Resolve ticket
# Target Suffix:
# Activity:  Closed
# Predicted Most-likely Suffix
# Activity:  Closed
#
#
# Case name:  Case 1058  with prefix length:  4
# Prefix:
# Activity:  Assign seriousness
# Activity:  Take in charge ticket
# Activity:  Wait
# Activity:  Resolve ticket
# Target Suffix:
# Activity:  Closed
# Predicted Most-likely Suffix
# Activity:  Closed
#
#
# Case name:  Case 3258  with prefix length:  1
# Prefix:
# Activity:  Assign seriousness
# Target Suffix:
# Activity:  Resolve ticket
# Activity:  Closed
# Predicted Most-likely Suffix
#
#
# Case name:  Case 2002  with prefix length:  2
# Prefix:
# Activity:  Assign seriousness
# Activity:  Take in charge ticket
# Target Suffix:
# Activity:  Resolve ticket
# Activity:  Closed
# Predicted Most-likely Suffix
# Activity:  Resolve ticket
# Activity:  Closed
#
#
# Case name:  Case 958  with prefix length:  4
# Prefix:
# Activity:  Assign seriousness
# Activity:  Take in charge ticket
# Activity:  Wait
# Activity:  Take in charge ticket
# Target Suffix:
# Activity:  Resolve ticket
# Activity:  Closed
# Predicted Most-likely Suffix
# Activity:  Resolve ticket
# Activity:  Closed
# Activity:  Closed
# Activity:  Closed
# Activity:  Closed
# Activity:  Closed
# Activity:  Closed
# Activity:  Closed
# Activity:  Closed
# Activity:  Closed
#
#
# Case name:  Case 958  with prefix length:  5
# Prefix:
# Activity:  Assign seriousness
# Activity:  Take in charge ticket
# Activity:  Wait
# Activity:  Take in charge ticket
# Activity:  Resolve ticket
# Target Suffix:
# Activity:  Closed
# Predicted Most-likely Suffix
# Activity:  Closed
#
#
# Case name:  Case 958  with prefix length:  2
# Prefix:
# Activity:  Assign seriousness
# Activity:  Take in charge ticket
# Target Suffix:
# Activity:  Wait
# Activity:  Take in charge ticket
# Activity:  Resolve ticket
# Activity:  Closed
# Predicted Most-likely Suffix
# Activity:  Resolve ticket
# Activity:  Closed
# Activity:  Closed
# Activity:  Closed
# Activity:  Closed
# Activity:  Closed
# Activity:  Closed
# Activity:  Closed
# Activity:  Closed
# Activity:  Closed
# Activity:  Closed
# Activity:  Closed
#
#
# Case name:  Case 3619  with prefix length:  3
# Prefix:
# Activity:  Assign seriousness
# Activity:  Take in charge ticket
# Activity:  Resolve ticket
# Target Suffix:
# Activity:  Closed
# Predicted Most-likely Suffix
# Activity:  Closed
#
#
# Case name:  Case 3619  with prefix length:  2
# Prefix:
# Activity:  Assign seriousness
# Activity:  Take in charge ticket
# Target Suffix:
# Activity:  Resolve ticket
# Activity:  Closed
# Predicted Most-likely Suffix
# Activity:  Resolve ticket
# Activity:  Closed
# Activity:  Closed
# Activity:  Closed
# Activity:  Closed
# Activity:  Closed
# Activity:  Closed
# Activity:  Closed
# Activity:  Closed
# Activity:  Closed
# Activity:  Closed
# Activity:  Closed
#
#
# Case name:  Case 958  with prefix length:  3
# Prefix:
# Activity:  Assign seriousness
# Activity:  Take in charge ticket
# Activity:  Wait
# Target Suffix:
# Activity:  Take in charge ticket
# Activity:  Resolve ticket
# Activity:  Closed
# Predicted Most-likely Suffix
# Activity:  Resolve ticket
# Activity:  Closed
# Activity:  Closed
# Activity:  Closed
# Activity:  Closed
# Activity:  Closed
# Activity:  Closed
# Activity:  Closed
# Activity:  Closed
# Activity:  Closed
# Activity:  Closed
#
#
# Case name:  Case 958  with prefix length:  1
# Prefix:
# Activity:  Assign seriousness
# Target Suffix:
# Activity:  Take in charge ticket
# Activity:  Wait
# Activity:  Take in charge ticket
# Activity:  Resolve ticket
# Activity:  Closed
# Predicted Most-likely Suffix
#
#
# Case name:  Case 2936  with prefix length:  1
# Prefix:
# Activity:  Assign seriousness
# Target Suffix:
# Activity:  Take in charge ticket
# Activity:  Wait
# Activity:  Take in charge ticket
# Activity:  Resolve ticket
# Activity:  Take in charge ticket
# Activity:  Resolve ticket
# Activity:  Closed
# Predicted Most-likely Suffix
# Activity:  Resolve ticket
# Activity:  Closed
# Activity:  Closed
# Activity:  Closed
# Activity:  Closed
# Activity:  Closed
# Activity:  Closed
# Activity:  Closed
# Activity:  Closed
# Activity:  Closed
# Activity:  Closed
# Activity:  Closed
# Activity:  Closed
#
#
# Case name:  Case 1205  with prefix length:  1
# Prefix:
# Activity:  Assign seriousness
# Target Suffix:
# Activity:  Take in charge ticket
# Activity:  Resolve ticket
# Activity:  Closed
# Predicted Most-likely Suffix
#
#
# Case name:  Case 2732  with prefix length:  1
# Prefix:
# Activity:  Assign seriousness
# Target Suffix:
# Activity:  Take in charge ticket
# Activity:  Resolve ticket
# Activity:  Closed
# Predicted Most-likely Suffix
#
#
# Case name:  Case 1336  with prefix length:  3
# Prefix:
# Activity:  Assign seriousness
# Activity:  Take in charge ticket
# Activity:  Resolve ticket
# Target Suffix:
# Activity:  Resolve ticket
# Activity:  Closed
# Predicted Most-likely Suffix
# Activity:  Closed
#
#
# Case name:  Case 2732  with prefix length:  3
# Prefix:
# Activity:  Assign seriousness
# Activity:  Take in charge ticket
# Activity:  Resolve ticket
# Target Suffix:
# Activity:  Closed
# Predicted Most-likely Suffix
# Activity:  Closed
#
#
# Case name:  Case 1205  with prefix length:  3
# Prefix:
# Activity:  Assign seriousness
# Activity:  Take in charge ticket
# Activity:  Resolve ticket
# Target Suffix:
# Activity:  Closed
# Predicted Most-likely Suffix
# Activity:  Closed
#
#
# Case name:  Case 2936  with prefix length:  2
# Prefix:
# Activity:  Assign seriousness
# Activity:  Take in charge ticket
# Target Suffix:
# Activity:  Wait
# Activity:  Take in charge ticket
# Activity:  Resolve ticket
# Activity:  Take in charge ticket
# Activity:  Resolve ticket
# Activity:  Closed
# Predicted Most-likely Suffix
# Activity:  Resolve ticket
# Activity:  Closed
# Activity:  Closed
# Activity:  Closed
# Activity:  Closed
# Activity:  Closed
# Activity:  Closed
# Activity:  Closed
# Activity:  Closed
# Activity:  Closed
# Activity:  Closed
# Activity:  Closed
#
#
# Case name:  Case 2936  with prefix length:  3
# Prefix:
# Activity:  Assign seriousness
# Activity:  Take in charge ticket
# Activity:  Wait
# Target Suffix:
# Activity:  Take in charge ticket
# Activity:  Resolve ticket
# Activity:  Take in charge ticket
# Activity:  Resolve ticket
# Activity:  Closed
# Predicted Most-likely Suffix
# Activity:  Resolve ticket
# Activity:  Closed
# Activity:  Closed
# Activity:  Closed
# Activity:  Closed
# Activity:  Closed
# Activity:  Closed
# Activity:  Closed
# Activity:  Closed
# Activity:  Closed
# Activity:  Closed
#
#
# Case name:  Case 2936  with prefix length:  5
# Prefix:
# Activity:  Assign seriousness
# Activity:  Take in charge ticket
# Activity:  Wait
# Activity:  Take in charge ticket
# Activity:  Resolve ticket
# Target Suffix:
# Activity:  Take in charge ticket
# Activity:  Resolve ticket
# Activity:  Closed
# Predicted Most-likely Suffix
# Activity:  Closed
#
#
# Case name:  Case 2936  with prefix length:  6
# Prefix:
# Activity:  Assign seriousness
# Activity:  Take in charge ticket
# Activity:  Wait
# Activity:  Take in charge ticket
# Activity:  Resolve ticket
# Activity:  Take in charge ticket
# Target Suffix:
# Activity:  Resolve ticket
# Activity:  Closed
# Predicted Most-likely Suffix
# Activity:  Resolve ticket
# Activity:  Closed
# Activity:  Closed
# Activity:  Closed
# Activity:  Closed
# Activity:  Closed
# Activity:  Closed
# Activity:  Closed
#
#
# Case name:  Case 2732  with prefix length:  2
# Prefix:
# Activity:  Assign seriousness
# Activity:  Take in charge ticket
# Target Suffix:
# Activity:  Resolve ticket
# Activity:  Closed
# Predicted Most-likely Suffix
# Activity:  Resolve ticket
# Activity:  Closed
# Activity:  Closed
# Activity:  Closed
# Activity:  Closed
# Activity:  Closed
# Activity:  Closed
# Activity:  Closed
# Activity:  Closed
# Activity:  Closed
# Activity:  Closed
# Activity:  Closed
#
#
# Case name:  Case 1336  with prefix length:  2
# Prefix:
# Activity:  Assign seriousness
# Activity:  Take in charge ticket
# Target Suffix:
# Activity:  Resolve ticket
# Activity:  Resolve ticket
# Activity:  Closed
# Predicted Most-likely Suffix
# Activity:  Resolve ticket
# Activity:  Closed
# Activity:  Closed
# Activity:  Closed
# Activity:  Closed
# Activity:  Closed
# Activity:  Closed
# Activity:  Closed
# Activity:  Closed
# Activity:  Closed
# Activity:  Closed
# Activity:  Closed
#
#
# Case name:  Case 1205  with prefix length:  2
# Prefix:
# Activity:  Assign seriousness
# Activity:  Take in charge ticket
# Target Suffix:
# Activity:  Resolve ticket
# Activity:  Closed
# Predicted Most-likely Suffix
# Activity:  Resolve ticket
# Activity:  Closed
#
#
# Case name:  Case 2936  with prefix length:  4
# Prefix:
# Activity:  Assign seriousness
# Activity:  Take in charge ticket
# Activity:  Wait
# Activity:  Take in charge ticket
# Target Suffix:
# Activity:  Resolve ticket
# Activity:  Take in charge ticket
# Activity:  Resolve ticket
# Activity:  Closed
# Predicted Most-likely Suffix
# Activity:  Resolve ticket
# Activity:  Closed
# Activity:  Closed
# Activity:  Closed
# Activity:  Closed
# Activity:  Closed
# Activity:  Closed
# Activity:  Closed
# Activity:  Closed
# Activity:  Closed
#
#
# Case name:  Case 1336  with prefix length:  4
# Prefix:
# Activity:  Assign seriousness
# Activity:  Take in charge ticket
# Activity:  Resolve ticket
# Activity:  Resolve ticket
# Target Suffix:
# Activity:  Closed
# Predicted Most-likely Suffix
# Activity:  Closed
#
#
# Case name:  Case 1336  with prefix length:  1
# Prefix:
# Activity:  Assign seriousness
# Target Suffix:
# Activity:  Take in charge ticket
# Activity:  Resolve ticket
# Activity:  Resolve ticket
# Activity:  Closed
# Predicted Most-likely Suffix
#
#
# Case name:  Case 2936  with prefix length:  7
# Prefix:
# Activity:  Assign seriousness
# Activity:  Take in charge ticket
# Activity:  Wait
# Activity:  Take in charge ticket
# Activity:  Resolve ticket
# Activity:  Take in charge ticket
# Activity:  Resolve ticket
# Target Suffix:
# Activity:  Closed
# Predicted Most-likely Suffix
# Activity:  Closed
#
#
# Case name:  Case 3577  with prefix length:  1
# Prefix:
# Activity:  Assign seriousness
# Target Suffix:
# Activity:  Take in charge ticket
# Activity:  Resolve ticket
# Activity:  Closed
# Predicted Most-likely Suffix
#
#
# Case name:  Case 95  with prefix length:  3
# Prefix:
# Activity:  Assign seriousness
# Activity:  Take in charge ticket
# Activity:  Resolve ticket
# Target Suffix:
# Activity:  Closed
# Predicted Most-likely Suffix
# Activity:  Closed
#
#
# Case name:  Case 1961  with prefix length:  1
# Prefix:
# Activity:  Assign seriousness
# Target Suffix:
# Activity:  Take in charge ticket
# Activity:  Resolve ticket
# Activity:  Closed
# Predicted Most-likely Suffix
#
#
# Case name:  Case 1961  with prefix length:  2
# Prefix:
# Activity:  Assign seriousness
# Activity:  Take in charge ticket
# Target Suffix:
# Activity:  Resolve ticket
# Activity:  Closed
# Predicted Most-likely Suffix
# Activity:  Resolve ticket
# Activity:  Closed
# Activity:  Closed
# Activity:  Closed
# Activity:  Closed
# Activity:  Closed
# Activity:  Closed
# Activity:  Closed
# Activity:  Closed
# Activity:  Closed
# Activity:  Closed
# Activity:  Closed
#
#
# Case name:  Case 4125  with prefix length:  3
# Prefix:
# Activity:  Assign seriousness
# Activity:  Take in charge ticket
# Activity:  Resolve ticket
# Target Suffix:
# Activity:  Closed
# Predicted Most-likely Suffix
# Activity:  Closed
#
#
# Case name:  Case 951  with prefix length:  1
# Prefix:
# Activity:  Assign seriousness
# Target Suffix:
# Activity:  Take in charge ticket
# Activity:  Wait
# Activity:  Resolve ticket
# Activity:  Closed
# Predicted Most-likely Suffix
#
#
# Case name:  Case 95  with prefix length:  1
# Prefix:
# Activity:  Assign seriousness
# Target Suffix:
# Activity:  Take in charge ticket
# Activity:  Resolve ticket
# Activity:  Closed
# Predicted Most-likely Suffix
#
#
# Case name:  Case 4125  with prefix length:  1
# Prefix:
# Activity:  Assign seriousness
# Target Suffix:
# Activity:  Take in charge ticket
# Activity:  Resolve ticket
# Activity:  Closed
# Predicted Most-likely Suffix
#
#
# Case name:  Case 3577  with prefix length:  3
# Prefix:
# Activity:  Assign seriousness
# Activity:  Take in charge ticket
# Activity:  Resolve ticket
# Target Suffix:
# Activity:  Closed
# Predicted Most-likely Suffix
# Activity:  Closed
#
#
# Case name:  Case 951  with prefix length:  2
# Prefix:
# Activity:  Assign seriousness
# Activity:  Take in charge ticket
# Target Suffix:
# Activity:  Wait
# Activity:  Resolve ticket
# Activity:  Closed
# Predicted Most-likely Suffix
# Activity:  Resolve ticket
# Activity:  Closed
# Activity:  Closed
# Activity:  Closed
# Activity:  Closed
# Activity:  Closed
# Activity:  Closed
# Activity:  Closed
# Activity:  Closed
# Activity:  Closed
# Activity:  Closed
# Activity:  Closed
#
#
# Case name:  Case 951  with prefix length:  3
# Prefix:
# Activity:  Assign seriousness
# Activity:  Take in charge ticket
# Activity:  Wait
# Target Suffix:
# Activity:  Resolve ticket
# Activity:  Closed
# Predicted Most-likely Suffix
# Activity:  Resolve ticket
# Activity:  Closed
# Activity:  Closed
# Activity:  Closed
# Activity:  Closed
# Activity:  Closed
# Activity:  Closed
# Activity:  Closed
# Activity:  Closed
# Activity:  Closed
# Activity:  Closed
#
#
# Case name:  Case 4125  with prefix length:  2
# Prefix:
# Activity:  Assign seriousness
# Activity:  Take in charge ticket
# Target Suffix:
# Activity:  Resolve ticket
# Activity:  Closed
# Predicted Most-likely Suffix
# Activity:  Resolve ticket
# Activity:  Closed
#
#
# Case name:  Case 1961  with prefix length:  3
# Prefix:
# Activity:  Assign seriousness
# Activity:  Take in charge ticket
# Activity:  Resolve ticket
# Target Suffix:
# Activity:  Closed
# Predicted Most-likely Suffix
# Activity:  Closed
#
#
# Case name:  Case 3577  with prefix length:  2
# Prefix:
# Activity:  Assign seriousness
# Activity:  Take in charge ticket
# Target Suffix:
# Activity:  Resolve ticket
# Activity:  Closed
# Predicted Most-likely Suffix
# Activity:  Resolve ticket
# Activity:  Closed
#
#
# Case name:  Case 951  with prefix length:  4
# Prefix:
# Activity:  Assign seriousness
# Activity:  Take in charge ticket
# Activity:  Wait
# Activity:  Resolve ticket
# Target Suffix:
# Activity:  Closed
# Predicted Most-likely Suffix
# Activity:  Closed
#
#
# Case name:  Case 95  with prefix length:  2
# Prefix:
# Activity:  Assign seriousness
# Activity:  Take in charge ticket
# Target Suffix:
# Activity:  Resolve ticket
# Activity:  Closed
# Predicted Most-likely Suffix
# Activity:  Resolve ticket
# Activity:  Closed
#
#
# Case name:  Case 772  with prefix length:  1
# Prefix:
# Activity:  Assign seriousness
# Target Suffix:
# Activity:  Take in charge ticket
# Activity:  Resolve ticket
# Activity:  Closed
# Predicted Most-likely Suffix
#
#
# Case name:  Case 2255  with prefix length:  1
# Prefix:
# Activity:  Assign seriousness
# Target Suffix:
# Activity:  Take in charge ticket
# Activity:  Resolve ticket
# Activity:  Closed
# Predicted Most-likely Suffix
